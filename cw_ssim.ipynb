# %%
import os
import subprocess
import json
from pdf2image import convert_from_path
from PIL import Image
from multiprocessing import Pool
import uuid

# 全局路径变量，将在主程序中初始化
table_dir = ""
output_pdf_dir = ""
output_png_dir = ""
extracted_tables_dir = ""
base_dir = ""

# Updated LaTeX preamble with UTF-8 support
latex_preamble = r"""
\documentclass[standalone]{article}
\usepackage[utf8]{inputenc}
\usepackage[T1]{fontenc}
\usepackage{amsmath, amsthm, amssymb, graphicx, geometry, array}
\usepackage{booktabs, multirow,natbib,tabularx, multicol, bm}
\pagenumbering{gobble}
\begin{document}
\begin{table}[htp]
\centering
\resizebox*{0.5\columnwidth}{!}{ 
"""
latex_end = r"}\end{table}\end{document}"

def render_tex_to_pdf(tex_path, output_pdf_path, timeout=20):
    """Render a LaTeX file to PDF with unique temporary files for parallel processing"""
    with open(tex_path, "r") as file:
        tex_content = file.read()
    
    full_tex_content = latex_preamble + tex_content + latex_end
    
    # Generate unique temporary filename using UUID
    temp_tex_filename = f"temp_{uuid.uuid4().hex}.tex"
    temp_tex_path = os.path.join(os.path.dirname(output_pdf_path), temp_tex_filename)
    
    with open(temp_tex_path, "w") as temp_file:
        temp_file.write(full_tex_content)
    
    try:
        result = subprocess.run(
            ["pdflatex", "-interaction=nonstopmode", "-output-directory", os.path.dirname(output_pdf_path), temp_tex_path],
            check=False,
            capture_output=True,
            text=True,
            encoding='latin-1',
            timeout=timeout
        )
        
        # Get the actual output PDF path from LaTeX compilation
        temp_pdf_path = temp_tex_path.replace(".tex", ".pdf")
        
        if os.path.exists(temp_pdf_path):
            os.rename(temp_pdf_path, output_pdf_path)
            print(f"Successfully rendered {tex_path} to PDF at {output_pdf_path}.")
        else:
            print(f"Error: PDF not generated for {tex_path}. LaTeX output:\n{result.stdout}")
    except subprocess.TimeoutExpired:
        print(f"Timeout expired while rendering {tex_path}. Skipping this file.")
    except Exception as e:
        print(f"Unexpected error rendering {tex_path}: {str(e)}")
    finally:
        # Cleanup temporary files
        for ext in [".aux", ".log", ".out", ".tex"]:
            file_path = temp_tex_path.replace(".tex", ext)
            if os.path.exists(file_path):
                try:
                    os.remove(file_path)
                except Exception as e:
                    print(f"Warning: Could not delete temporary file {file_path}: {str(e)}")

def convert_pdf_to_png(pdf_path, png_path, dpi=300):
    """Convert PDF to PNG with error handling"""
    try:
        images = convert_from_path(pdf_path, dpi=dpi)
        if images:
            images[0].save(png_path, "PNG")
            print(f"Converted {pdf_path} to {png_path}")
        else:
            print(f"Error: No pages found in {pdf_path}")
    except Exception as e:
        print(f"Error converting {pdf_path} to PNG: {str(e)}")

def process_entry(entry):
    """Process a single JSON entry with full error handling"""
    try:
        question_id = entry["id"]
        image_path = entry["image"]
        
        # 从image路径中提取原始文件名（带扩展名）
        original_filename = os.path.basename(image_path)
        
        print(f"Processing {question_id} with image {original_filename}...")
        
        # 只处理prediction，忽略reference
        # 使用原始图片名作为基础文件名（不带路径）
        base_name = original_filename.replace('.', '_')
        tex_path = os.path.join(table_dir, f"{base_name}.tex")
        
        # 创建LaTeX文件
        with open(tex_path, "w") as f:
            f.write(entry["prediction"])
        
        # 生成PDF
        pdf_path = os.path.join(output_pdf_dir, f"{base_name}.pdf")
        render_tex_to_pdf(tex_path, pdf_path)
        
        # 转换为PNG并使用原始文件名（带扩展名）
        if os.path.exists(pdf_path):
            png_path = os.path.join(output_png_dir, original_filename)
            convert_pdf_to_png(pdf_path, png_path)
        else:
            print(f"Skipping PNG conversion for {original_filename} - PDF not found")
        
        print(f"Completed processing {question_id}")
        return True
    except Exception as e:
        print(f"Error processing entry {entry.get('id', 'unknown')}: {str(e)}")
        return False

def process_jsonl(json_file):
    """Main processing function with parallel execution"""
    # 读取 JSONL 文件
    data = []
    with open(json_file, "r") as file:
        for line in file:
            if line.strip():  # 跳过空行
                data.append(json.loads(line))
    
    # 创建必要的目录
    os.makedirs(table_dir, exist_ok=True)
    os.makedirs(output_pdf_dir, exist_ok=True)
    os.makedirs(output_png_dir, exist_ok=True)
    
    # 使用半数可用 CPU 进行资源平衡
    num_workers = max(1, os.cpu_count() // 2)
    
    with Pool(processes=num_workers) as pool:
        results = pool.imap_unordered(process_entry, data)
        
        # 监控进度
        success_count = 0
        for i, result in enumerate(results, 1):
            if result:
                success_count += 1
            print(f"Processed {i}/{len(data)} entries ({success_count} successes)")
    
    print(f"\nProcessing complete. Success rate: {success_count}/{len(data)}")

# 用户只需修改这个JSON文件路径
json_file = "/home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/output_fintabnet_SFT.jsonl"  # 修改此处为你的JSON文件路径

# 动态生成所有路径
base_dir = os.path.dirname(json_file)
extracted_tables_dir = os.path.join(base_dir, "extracted_tables_sft")
table_dir = os.path.join(extracted_tables_dir, "latex_tables")
output_pdf_dir = os.path.join(extracted_tables_dir, "pdf_tables_full")
output_png_dir = os.path.join(extracted_tables_dir, "png_tables_full")

# 执行处理流程
process_jsonl(json_file)
print("Rendering and conversion complete!")
# Out:
# Processing 7 with image image_18.png...Processing 0 with image image_1002.png...Processing 14 with image image_224.png...Processing 28 with image image_285.png...Processing 35 with image image_308.png...Processing 56 with image image_369.png...Processing 70 with image image_462.png...Processing 49 with image image_346.png...Processing 21 with image image_271.png...Processing 77 with image image_521.png...Processing 63 with image image_422.png...
# Processing 84 with image image_589.png...Processing 112 with image image_905.png...
# Processing 91 with image image_671.png...
#
#
# Processing 105 with image image_826.png...
# Processing 98 with image image_749.png...
#
#
# Processing 1 with image image_1014.png...
# Processing 8 with image image_19.png...Processing 42 with image image_320.png...
# Processing 119 with image image_986.png...Processing 15 with image image_247.png...Processing 36 with image image_309.png...
#
#
# Processing 43 with image image_334.png...Processing 50 with image image_347.png...Processing 64 with image image_429.png...Processing 57 with image image_370.png...Processing 71 with image image_466.png...
# Processing 85 with image image_603.png...Processing 99 with image image_755.png...Processing 92 with image image_685.png...Processing 2 with image image_1027.png...
# Processing 106 with image image_839.png...
#
# Processing 30 with image image_290.png...Processing 113 with image image_918.png...Processing 23 with image image_277.png...Processing 78 with image image_538.png...
# Processing 51 with image image_348.png...
# Processing 16 with image image_259.png...
# Processing 37 with image image_312.png...
# Processing 44 with image image_338.png...
#
# Processing 9 with image image_193.png...Processing 79 with image image_551.png...
# Processing 65 with image image_431.png...
#
#
# Processing 72 with image image_469.png...
#
#
# Processing 93 with image image_695.png...Processing 86 with image image_612.png...
#
# Processing 58 with image image_371.png...
#
# Processing 100 with image image_766.png...Processing 114 with image image_929.png...Processing 107 with image image_852.png...Processing 3 with image image_120.png...
#
# Processing 10 with image image_207.png...Processing 17 with image image_264.png...
# Processing 24 with image image_280.png...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing 29 with image image_288.png...
# Processing 22 with image image_276.png...
# Error: PDF not generated for /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_1014_png.tex. LaTeX output:
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
#
# (/home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_s
# ft/pdf_tables_full/temp_c388f549c971466fb393cccfd4a226c8.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amscls/amsthm.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/amssymb.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def)))
# (/usr/share/texlive/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/share/texlive/texmf-dist/tex/latex/tools/array.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/booktabs/booktabs.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/multirow/multirow.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/natbib/natbib.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tools/tabularx.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tools/multicol.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tools/bm.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
#
# LaTeX Warning: Unused global option(s):
#     [standalone].
#
# No file temp_c388f549c971466fb393cccfd4a226c8.aux.
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# ) (/usr/share/texlive/texmf-dist/tex/latex/epstopdf-pkg/epstopdf-base.sty
# (/usr/share/texlive/texmf-dist/tex/latex/latexconfig/epstopdf-sys.cfg))
# *geometry* driver: auto-detecting
# *geometry* detected driver: pdftex
# )
# Runaway argument?
# { \begin {tabular}{lrrr} \cline {2-2} & 2017 & 2016 & 2015 \\ \cline \ETC.
# ! File ended while scanning use of \Gscale@box@dd.
# <inserted text>
#                 \par
# <*> ...l/temp_c388f549c971466fb393cccfd4a226c8.tex
#
# ! Emergency stop.
# <*> ...l/temp_c388f549c971466fb393cccfd4a226c8.tex
#
# !  ==> Fatal error occurred, no output PDF file produced!
# Transcript written on /home/lingjun/code/InternVL/internvl_chat/dataset_fintabn
# et/extracted_tables_sft/pdf_tables_full/temp_c388f549c971466fb393cccfd4a226c8.l
# og.
#
# Skipping PNG conversion for image_1014.png - PDF not found
# Completed processing 1
# Processing 31 with image image_304.png...
# Error: PDF not generated for /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_986_png.tex. LaTeX output:
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
#
# (/home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_s
# ft/pdf_tables_full/temp_7baf58b472d2414ca7b016d6971b212c.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amscls/amsthm.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/amssymb.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def)))
# (/usr/share/texlive/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/share/texlive/texmf-dist/tex/latex/tools/array.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/booktabs/booktabs.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/multirow/multirow.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/natbib/natbib.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tools/tabularx.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tools/multicol.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tools/bm.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
#
# LaTeX Warning: Unused global option(s):
#     [standalone].
#
# No file temp_7baf58b472d2414ca7b016d6971b212c.aux.
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# ) (/usr/share/texlive/texmf-dist/tex/latex/epstopdf-pkg/epstopdf-base.sty
# (/usr/share/texlive/texmf-dist/tex/latex/latexconfig/epstopdf-sys.cfg))
# *geometry* driver: auto-detecting
# *geometry* detected driver: pdftex
# )
# Runaway argument?
# { \begin {tabular}{lrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrr\ETC.
# ! File ended while scanning use of \Gscale@box@dd.
# <inserted text>
#                 \par
# <*> ...l/temp_7baf58b472d2414ca7b016d6971b212c.tex
#
# ! Emergency stop.
# <*> ...l/temp_7baf58b472d2414ca7b016d6971b212c.tex
#
# !  ==> Fatal error occurred, no output PDF file produced!
# Transcript written on /home/lingjun/code/InternVL/internvl_chat/dataset_fintabn
# et/extracted_tables_sft/pdf_tables_full/temp_7baf58b472d2414ca7b016d6971b212c.l
# og.
#
# Skipping PNG conversion for image_986.png - PDF not found
# Completed processing 119
# Processing 38 with image image_313.png...
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_369_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_369_png.pdf.
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_271_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_271_png.pdf.
# Error: PDF not generated for /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_224_png.tex. LaTeX output:
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
#
# (/home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_s
# ft/pdf_tables_full/temp_749daaf0f3ae463699e4571796e86b73.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amscls/amsthm.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/amssymb.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def)))
# (/usr/share/texlive/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/share/texlive/texmf-dist/tex/latex/tools/array.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/booktabs/booktabs.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/multirow/multirow.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/natbib/natbib.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tools/tabularx.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tools/multicol.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tools/bm.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
#
# LaTeX Warning: Unused global option(s):
#     [standalone].
#
# No file temp_749daaf0f3ae463699e4571796e86b73.aux.
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# ) (/usr/share/texlive/texmf-dist/tex/latex/epstopdf-pkg/epstopdf-base.sty
# (/usr/share/texlive/texmf-dist/tex/latex/latexconfig/epstopdf-sys.cfg))
# *geometry* driver: auto-detecting
# *geometry* detected driver: pdftex
# )
# Runaway argument?
# { \begin {tabular}{@{}llllrrrrr@{}} (in thousands) & & & \multicolumn \ETC.
# ! File ended while scanning use of \Gscale@box@dd.
# <inserted text>
#                 \par
# <*> ...l/temp_749daaf0f3ae463699e4571796e86b73.tex
#
# ! Emergency stop.
# <*> ...l/temp_749daaf0f3ae463699e4571796e86b73.tex
#
# !  ==> Fatal error occurred, no output PDF file produced!
# Transcript written on /home/lingjun/code/InternVL/internvl_chat/dataset_fintabn
# et/extracted_tables_sft/pdf_tables_full/temp_749daaf0f3ae463699e4571796e86b73.l
# og.
#
# Skipping PNG conversion for image_224.png - PDF not found
# Completed processing 14
# Processing 45 with image image_339.png...
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_521_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_521_png.pdf.
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_589_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_589_png.pdf.
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_422_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_422_png.pdf.
# Error: PDF not generated for /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_1027_png.tex. LaTeX output:
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
#
# (/home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_s
# ft/pdf_tables_full/temp_87de8bfd36a04569ab831d1dc01f36f5.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amscls/amsthm.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/amssymb.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def)))
# (/usr/share/texlive/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/share/texlive/texmf-dist/tex/latex/tools/array.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/booktabs/booktabs.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/multirow/multirow.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/natbib/natbib.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tools/tabularx.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tools/multicol.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tools/bm.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
#
# LaTeX Warning: Unused global option(s):
#     [standalone].
#
# No file temp_87de8bfd36a04569ab831d1dc01f36f5.aux.
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# ) (/usr/share/texlive/texmf-dist/tex/latex/epstopdf-pkg/epstopdf-base.sty
# (/usr/share/texlive/texmf-dist/tex/latex/latexconfig/epstopdf-sys.cfg))
# *geometry* driver: auto-detecting
# *geometry* detected driver: pdftex
# )
# Runaway argument?
# { \begin {tabular}{lrrr} & 2018 & 2017 & 2016 \\ \cmidrule (lr){2-2}\cmidrule \
# ETC.
# ! File ended while scanning use of \Gscale@box@dd.
# <inserted text>
#                 \par
# <*> ...l/temp_87de8bfd36a04569ab831d1dc01f36f5.tex
#
# ! Emergency stop.
# <*> ...l/temp_87de8bfd36a04569ab831d1dc01f36f5.tex
#
# !  ==> Fatal error occurred, no output PDF file produced!
# Transcript written on /home/lingjun/code/InternVL/internvl_chat/dataset_fintabn
# et/extracted_tables_sft/pdf_tables_full/temp_87de8bfd36a04569ab831d1dc01f36f5.l
# og.
#
# Skipping PNG conversion for image_1027.png - PDF not found
# Completed processing 2
# Processing 52 with image image_349.png...
# Processed 1/120 entries (1 successes)
# Processed 2/120 entries (2 successes)
# Processed 3/120 entries (3 successes)
# Processed 4/120 entries (4 successes)
# Error: PDF not generated for /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_247_png.tex. LaTeX output:
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
#
# (/home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_s
# ft/pdf_tables_full/temp_dde67237311546d8baf5816a85a36d85.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amscls/amsthm.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/amssymb.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def)))
# (/usr/share/texlive/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/share/texlive/texmf-dist/tex/latex/tools/array.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/booktabs/booktabs.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/multirow/multirow.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/natbib/natbib.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tools/tabularx.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tools/multicol.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tools/bm.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
#
# LaTeX Warning: Unused global option(s):
#     [standalone].
#
# No file temp_dde67237311546d8baf5816a85a36d85.aux.
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# ) (/usr/share/texlive/texmf-dist/tex/latex/epstopdf-pkg/epstopdf-base.sty
# (/usr/share/texlive/texmf-dist/tex/latex/latexconfig/epstopdf-sys.cfg))
# *geometry* driver: auto-detecting
# *geometry* detected driver: pdftex
# )
# Runaway argument?
# { \begin {tabular}{lrrrrrr} & \multicolumn {1}{c}{\textbf {2010}} & \multicolum
# n \ETC.
# ! File ended while scanning use of \Gscale@box@dd.
# <inserted text>
#                 \par
# <*> ...l/temp_dde67237311546d8baf5816a85a36d85.tex
#
# ! Emergency stop.
# <*> ...l/temp_dde67237311546d8baf5816a85a36d85.tex
#
# !  ==> Fatal error occurred, no output PDF file produced!
# Transcript written on /home/lingjun/code/InternVL/internvl_chat/dataset_fintabn
# et/extracted_tables_sft/pdf_tables_full/temp_dde67237311546d8baf5816a85a36d85.l
# og.
#
# Skipping PNG conversion for image_247.png - PDF not found
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_671_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_671_png.pdf.Completed processing 15
#
# Processing 59 with image image_384.png...Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_826_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_826_png.pdf.
#
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_347_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_347_png.pdf.
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_309_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_309_png.pdf.
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_905_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_905_png.pdf.
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_462_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_462_png.pdf.
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_551_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_551_png.pdf.
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_1002_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_1002_png.pdf.Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_929_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_929_png.pdf.
#
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_695_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_695_png.pdf.
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_612_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_612_png.pdf.
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_346_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_346_png.pdf.
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_120_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_120_png.pdf.Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_264_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_264_png.pdf.
#
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_18_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_18_png.pdf.Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_755_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_755_png.pdf.
#
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_285_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_285_png.pdf.
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_685_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_685_png.pdf.
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_918_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_918_png.pdf.
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_749_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_749_png.pdf.
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_338_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_338_png.pdf.Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_207_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_207_png.pdf.Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_193_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_193_png.pdf.
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_277_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_277_png.pdf.
#
#
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_466_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_466_png.pdf.
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_320_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_320_png.pdf.
# Processed 5/120 entries (5 successes)
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_766_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_766_png.pdf.Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_259_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_259_png.pdf.
#
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_538_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_538_png.pdf.
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_348_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_348_png.pdf.Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_469_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_469_png.pdf.
#
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_334_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_334_png.pdf.Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_290_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_290_png.pdf.
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_276_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_276_png.pdf.Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_852_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_852_png.pdf.Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_603_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_603_png.pdf.Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_280_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_280_png.pdf.Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_431_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_431_png.pdf.Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_371_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_371_png.pdf.Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_429_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_429_png.pdf.Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_19_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_19_png.pdf.Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_839_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_839_png.pdf.
#
#
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_304_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_304_png.pdf.
#
#
#
#
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_312_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_312_png.pdf.
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_308_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_308_png.pdf.Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_288_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_288_png.pdf.Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_313_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_313_png.pdf.
#
#
#
#
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_370_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_370_png.pdf.
#
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_369_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_369.png
# Completed processing 56
# Processing 66 with image image_435.png...
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_339_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_339_png.pdf.
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_521_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_521.png
# Completed processing 77
# Processing 73 with image image_482.png...
# Processed 6/120 entries (6 successes)
# Processed 7/120 entries (7 successes)
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_422_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_422.png
# Completed processing 63
# Processing 80 with image image_559.png...
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_271_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_271.png
# Completed processing 21
# Processing 87 with image image_627.png...
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_349_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_349_png.pdf.
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_589_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_589.png
# Completed processing 84
# Processing 94 with image image_711.png...
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_384_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_384_png.pdf.
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_347_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_347.png
# Completed processing 50
# Processing 101 with image image_779.png...
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_826_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_826.png
# Completed processing 105
# Processing 108 with image image_862.png...
# Processed 8/120 entries (8 successes)
# Processed 9/120 entries (9 successes)
# Processed 10/120 entries (10 successes)
# Processed 11/120 entries (11 successes)
# Processed 12/120 entries (12 successes)
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_671_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_671.png
# Completed processing 91
# Processing 115 with image image_940.png...
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_309_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_309.pngConverted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_905_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_905.png
#
# Completed processing 36Completed processing 112
#
# Processing 4 with image image_155.png...Processing 11 with image image_209.png...
#
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_435_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_435_png.pdf.
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_482_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_482_png.pdf.
# Error: PDF not generated for /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_559_png.tex. LaTeX output:
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
#
# (/home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_s
# ft/pdf_tables_full/temp_fa7a4d9fc78e47b2bffcdd26eb203c7b.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amscls/amsthm.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/amssymb.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def)))
# (/usr/share/texlive/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/share/texlive/texmf-dist/tex/latex/tools/array.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/booktabs/booktabs.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/multirow/multirow.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/natbib/natbib.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tools/tabularx.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tools/multicol.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tools/bm.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
#
# LaTeX Warning: Unused global option(s):
#     [standalone].
#
# No file temp_fa7a4d9fc78e47b2bffcdd26eb203c7b.aux.
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# ) (/usr/share/texlive/texmf-dist/tex/latex/epstopdf-pkg/epstopdf-base.sty
# (/usr/share/texlive/texmf-dist/tex/latex/latexconfig/epstopdf-sys.cfg))
# *geometry* driver: auto-detecting
# *geometry* detected driver: pdftex
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/umsb.fd)
# Overfull \vbox (3.8274pt too high) detected at line 12
#
# Overfull \vbox (3.10413pt too high) detected at line 12
#
# Overfull \vbox (8.09775pt too high) detected at line 12
#
# Overfull \vbox (8.09775pt too high) detected at line 12
#
# Overfull \vbox (8.09775pt too high) detected at line 12
#
# Overfull \vbox (8.09775pt too high) detected at line 12
# ! Extra }, or forgotten \endgroup.
# \@begin@tempboxa ...begingroup #2\color@endgroup }
#                                                   \def \width {\wd \@tempbox...
# l.12 ...antom{0,}\phantom{0,}\phantom{0,}\phantom}
#                                                   \end{table}\end{document}
#
# ! Package graphics Error: Division by 0.
#
# See the graphics package documentation for explanation.
# Type  H <return>  for immediate help.
#  ...
#
# l.12 ...antom{0,}\phantom{0,}\phantom{0,}\phantom}
#                                                   \end{table}\end{document}
# ! Missing } inserted.
# <inserted text>
#                 }
# l.12 ...hantom{0,}\phantom{0,}\phantom}\end{table}
#                                                   \end{document}
# ! Missing \cr inserted.
# <inserted text>
#                 \cr
# l.12 ...hantom{0,}\phantom{0,}\phantom}\end{table}
#                                                   \end{document}
# ! Missing } inserted.
# <inserted text>
#                 }
# l.12 ...hantom{0,}\phantom{0,}\phantom}\end{table}
#                                                   \end{document}
# ! Missing \cr inserted.
# <inserted text>
#                 \cr
# l.12 ...hantom{0,}\phantom{0,}\phantom}\end{table}
#                                                   \end{document}
# ! Misplaced \cr.
# <inserted text> \cr
#
# l.12 ...hantom{0,}\phantom{0,}\phantom}\end{table}
#                                                   \end{document}
# ! Missing \cr inserted.
# <inserted text>
#                 \cr
# l.12 ...hantom{0,}\phantom{0,}\phantom}\end{table}
#                                                   \end{document}
# ! Misplaced \cr.
# <inserted text> \cr
#
# l.12 ...hantom{0,}\phantom{0,}\phantom}\end{table}
#                                                   \end{document}
# ! Missing \cr inserted.
# <inserted text>
#                 \cr
# l.12 ...hantom{0,}\phantom{0,}\phantom}\end{table}
#                                                   \end{document}
# ! Misplaced \cr.
# <inserted text> \cr
#
# l.12 ...hantom{0,}\phantom{0,}\phantom}\end{table}
#                                                   \end{document}
# ! Missing \cr inserted.
# <inserted text>
#                 \cr
# l.12 ...hantom{0,}\phantom{0,}\phantom}\end{table}
#                                                   \end{document}
# ! Misplaced \cr.
# <inserted text> \cr
#
# l.12 ...hantom{0,}\phantom{0,}\phantom}\end{table}
#                                                   \end{document}
# ! Missing \cr inserted.
# <inserted text>
#                 \cr
# l.12 ...hantom{0,}\phantom{0,}\phantom}\end{table}
#                                                   \end{document}
# ! Misplaced \cr.
# <inserted text> \cr
#
# l.12 ...hantom{0,}\phantom{0,}\phantom}\end{table}
#                                                   \end{document}
# ! Missing \cr inserted.
# <inserted text>
#                 \cr
# l.12 ...hantom{0,}\phantom{0,}\phantom}\end{table}
#                                                   \end{document}
# ! Misplaced \cr.
# <inserted text> \cr
#
# l.12 ...hantom{0,}\phantom{0,}\phantom}\end{table}
#                                                   \end{document}
# ! Missing \cr inserted.
# <inserted text>
#                 \cr
# l.12 ...hantom{0,}\phantom{0,}\phantom}\end{table}
#                                                   \end{document}
# ! Misplaced \cr.
# <inserted text> \cr
#
# l.12 ...hantom{0,}\phantom{0,}\phantom}\end{table}
#                                                   \end{document}
# ! Missing \cr inserted.
# <inserted text>
#                 \cr
# l.12 ...hantom{0,}\phantom{0,}\phantom}\end{table}
#                                                   \end{document}
# ! Misplaced \cr.
# <inserted text> \cr
#
# l.12 ...hantom{0,}\phantom{0,}\phantom}\end{table}
#                                                   \end{document}
# ! Missing \cr inserted.
# <inserted text>
#                 \cr
# l.12 ...hantom{0,}\phantom{0,}\phantom}\end{table}
#                                                   \end{document}
# ! Misplaced \cr.
# <inserted text> \cr
#
# l.12 ...hantom{0,}\phantom{0,}\phantom}\end{table}
#                                                   \end{document}
# ! Missing \cr inserted.
# <inserted text>
#                 \cr
# l.12 ...hantom{0,}\phantom{0,}\phantom}\end{table}
#                                                   \end{document}
# ! Misplaced \cr.
# <inserted text> \cr
#
# l.12 ...hantom{0,}\phantom{0,}\phantom}\end{table}
#                                                   \end{document}
# ! Missing \cr inserted.
# <inserted text>
#                 \cr
# l.12 ...hantom{0,}\phantom{0,}\phantom}\end{table}
#                                                   \end{document}
# ! Misplaced \cr.
# <inserted text> \cr
#
# l.12 ...hantom{0,}\phantom{0,}\phantom}\end{table}
#                                                   \end{document}
# ! Missing \cr inserted.
# <inserted text>
#                 \cr
# l.12 ...hantom{0,}\phantom{0,}\phantom}\end{table}
#                                                   \end{document}
# ! Misplaced \cr.
# <inserted text> \cr
#
# l.12 ...hantom{0,}\phantom{0,}\phantom}\end{table}
#                                                   \end{document}
# ! Missing \cr inserted.
# ...
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_317_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_317_png.pdf.
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_659_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_659_png.pdf.
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_456_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_456_png.pdf.Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_577_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_577_png.pdf.
#
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_974_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_974_png.pdf.
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_390_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_390_png.pdf.
# Completed processing 18
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_801_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_801_png.pdf.Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_305_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_305.pngSuccessfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_17_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_17_png.pdf.
#
#
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/latex_tables/image_894_png.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_894_png.pdf.
# Completed processing 32
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_281_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_281.png
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_385_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_385.pngCompleted processing 25
#
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_314_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_314.pngConverted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_495_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_495.png
#
# Completed processing 60
# Completed processing 39
# Completed processing 74
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_564_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_564.png
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_341_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_341.png
# Completed processing 81
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_631_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_631.png
# Completed processing 46
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_791_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_791.png
# Completed processing 88
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_441_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_441.png
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_875_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_875.pngConverted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_723_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_723.pngCompleted processing 102
#
#
# Completed processing 67
# Completed processing 109Completed processing 95
#
# Processed 76/120 entries (76 successes)
# Processed 77/120 entries (77 successes)
# Processed 78/120 entries (78 successes)
# Processed 79/120 entries (79 successes)
# Processed 80/120 entries (80 successes)
# Processed 81/120 entries (81 successes)
# Processed 82/120 entries (82 successes)
# Processed 83/120 entries (83 successes)
# Processed 84/120 entries (84 successes)
# Processed 85/120 entries (85 successes)
# Processed 86/120 entries (86 successes)
# Processed 87/120 entries (87 successes)
# Processed 88/120 entries (88 successes)
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_163_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_163.png
# Completed processing 5
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_386_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_386.png
# Completed processing 61
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_306_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_306.png
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_315_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_315.png
# Completed processing 33
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_210_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_210.pngCompleted processing 40
#
# Completed processing 12
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_444_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_444.png
# Completed processing 68
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_266_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_266.png
# Completed processing 19
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_350_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_350.png
# Completed processing 53
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_344_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_344.png
# Completed processing 47
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_506_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_506.png
# Completed processing 75
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_351_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_351.png
# Completed processing 54
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_267_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_267.png
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_880_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_880.pngConverted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_962_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_962.png
#
# Completed processing 20
# Processed 89/120 entries (89 successes)
# Processed 90/120 entries (90 successes)
# Processed 91/120 entries (91 successes)
# Processed 92/120 entries (92 successes)
# Processed 93/120 entries (93 successes)
# Processed 94/120 entries (94 successes)
# Processed 95/120 entries (95 successes)
# Processed 96/120 entries (96 successes)
# Processed 97/120 entries (97 successes)
# Processed 98/120 entries (98 successes)
# Processed 99/120 entries (99 successes)
# Processed 100/120 entries (100 successes)
# Completed processing 117Completed processing 110
#
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_345_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_345.png
# Completed processing 48
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_284_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_284.pngConverted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_307_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_307.png
#
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_518_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_518.png
# Completed processing 34
# Completed processing 27
# Completed processing 76
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_283_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_283.png
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_17_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_17.png
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_801_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_801.pngConverted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_644_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_644.png
#
# Completed processing 6Completed processing 26
#
# Completed processing 103Completed processing 89
#
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_732_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_732.pngConverted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_578_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_578.png
#
# Completed processing 83Completed processing 96
#
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_659_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_659.png
# Completed processing 90
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_974_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_974.png
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_317_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_317.png
# Completed processing 118
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_894_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_894.pngCompleted processing 41
#
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_390_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_390.png
# Completed processing 62
# Completed processing 111
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_456_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_456.png
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_577_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_577.png
# Completed processing 69Completed processing 82
#
# Converted /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/pdf_tables_full/image_215_png.pdf to /home/lingjun/code/InternVL/internvl_chat/dataset_fintabnet/extracted_tables_sft/png_tables_full/image_215.png
# Processed 101/120 entries (101 successes)
# Processed 102/120 entries (102 successes)
# Processed 103/120 entries (103 successes)
# Processed 104/120 entries (104 successes)
# Processed 105/120 entries (105 successes)
# Processed 106/120 entries (106 successes)
# Processed 107/120 entries (107 successes)
# Processed 108/120 entries (108 successes)
# Processed 109/120 entries (109 successes)
# Processed 110/120 entries (110 successes)
# Processed 111/120 entries (111 successes)
# Processed 112/120 entries (112 successes)
# Processed 113/120 entries (113 successes)
# Processed 114/120 entries (114 successes)
# Processed 115/120 entries (115 successes)
# Processed 116/120 entries (116 successes)
# Processed 117/120 entries (117 successes)
# Processed 118/120 entries (118 successes)
# Processed 119/120 entries (119 successes)
# Completed processing 13
# Processed 120/120 entries (120 successes)
#
# Processing complete. Success rate: 120/120
# Rendering and conversion complete!

# %%
import os
import subprocess
import json
from pdf2image import convert_from_path
from PIL import Image
from multiprocessing import Pool
import uuid


# 全局路径变量，将在主程序中初始化
table_dir = ""
output_pdf_dir = ""
output_png_dir = ""
extracted_tables_dir = ""
base_dir = ""

# Updated LaTeX preamble with UTF-8 support
latex_preamble = r"""
\documentclass[standalone]{article}
\usepackage[utf8]{inputenc}
\usepackage[T1]{fontenc}
\usepackage{amsmath, amsthm, amssymb, graphicx, geometry, array}
\usepackage{booktabs, multirow,natbib,tabularx, multicol, bm}
\pagenumbering{gobble}
\begin{document}
\begin{table}[htp]
\centering
\resizebox*{0.5\columnwidth}{!}{ 
"""
latex_end = r"}\end{table}\end{document}"

def render_tex_to_pdf(tex_path, output_pdf_path, timeout=20):
    """Render a LaTeX file to PDF with unique temporary files for parallel processing"""
    with open(tex_path, "r") as file:
        tex_content = file.read()
    
    full_tex_content = latex_preamble + tex_content + latex_end
    
    # Generate unique temporary filename using UUID
    temp_tex_filename = f"temp_{uuid.uuid4().hex}.tex"
    temp_tex_path = os.path.join(os.path.dirname(output_pdf_path), temp_tex_filename)
    
    with open(temp_tex_path, "w") as temp_file:
        temp_file.write(full_tex_content)
    
    try:
        result = subprocess.run(
            ["pdflatex", "-interaction=nonstopmode", "-output-directory", os.path.dirname(output_pdf_path), temp_tex_path],
            check=False,
            capture_output=True,
            text=True,
            encoding='latin-1',
            timeout=timeout
        )
        
        # Get the actual output PDF path from LaTeX compilation
        temp_pdf_path = temp_tex_path.replace(".tex", ".pdf")
        
        if os.path.exists(temp_pdf_path):
            os.rename(temp_pdf_path, output_pdf_path)
            print(f"Successfully rendered {tex_path} to PDF at {output_pdf_path}.")
        else:
            print(f"Error: PDF not generated for {tex_path}. LaTeX output:\n{result.stdout}")
    except subprocess.TimeoutExpired:
        print(f"Timeout expired while rendering {tex_path}. Skipping this file.")
    except Exception as e:
        print(f"Unexpected error rendering {tex_path}: {str(e)}")
    finally:
        # Cleanup temporary files
        for ext in [".aux", ".log", ".out", ".tex"]:
            file_path = temp_tex_path.replace(".tex", ext)
            if os.path.exists(file_path):
                try:
                    os.remove(file_path)
                except Exception as e:
                    print(f"Warning: Could not delete temporary file {file_path}: {str(e)}")

def convert_pdf_to_png(pdf_path, png_path, dpi=300):
    """Convert PDF to PNG with error handling"""
    try:
        images = convert_from_path(pdf_path, dpi=dpi)
        if images:
            images[0].save(png_path, "PNG")
            print(f"Converted {pdf_path} to {png_path}")
        else:
            print(f"Error: No pages found in {pdf_path}")
    except Exception as e:
        print(f"Error converting {pdf_path} to PNG: {str(e)}")

def process_entry(entry):
    """Process a single JSON entry with full error handling"""
    try:
        question_id = entry["id"]
        print(f"Processing {question_id}...")
        
        # Create output filenames
        base_files = {
            "prediction": (entry["prediction"], f"{question_id}_prediction"),
            "reference": (entry["reference"], f"{question_id}_reference")
        }
        
        for content_type, (content, base_name) in base_files.items():
            # Generate LaTeX file
            tex_path = os.path.join(table_dir, f"{base_name}.tex")
            with open(tex_path, "w") as f:
                f.write(content)
            
            # Generate PDF
            pdf_path = os.path.join(output_pdf_dir, f"{base_name}.pdf")
            render_tex_to_pdf(tex_path, pdf_path)
            
            # Convert to PNG
            if os.path.exists(pdf_path):
                png_path = os.path.join(output_png_dir, f"{base_name}.png")
                convert_pdf_to_png(pdf_path, png_path)
            else:
                print(f"Skipping PNG conversion for {base_name} - PDF not found")
        
        print(f"Completed processing {question_id}")
        return True
    except Exception as e:
        print(f"Error processing {entry.get('questionId', 'unknown')}: {str(e)}")
        return False

def process_json(json_file):
    """Main processing function with parallel execution"""
    with open(json_file, "r") as file:
        data = json.load(file)
    
    # Create necessary directories
    os.makedirs(table_dir, exist_ok=True)
    os.makedirs(output_pdf_dir, exist_ok=True)
    os.makedirs(output_png_dir, exist_ok=True)
    
    # Use half of available CPUs for resource balancing
    num_workers = max(1, os.cpu_count() // 2)
    
    with Pool(processes=num_workers) as pool:
        results = pool.imap_unordered(process_entry, data)
        
        # Monitor progress
        success_count = 0
        for i, result in enumerate(results, 1):
            if result:
                success_count += 1
            print(f"Processed {i}/{len(data)} entries ({success_count} successes)")
    
    print(f"\nProcessing complete. Success rate: {success_count}/{len(data)}")

import concurrent
import numpy as np

def dwt2_simple(img_array):
    """Performs a simple 2D discrete wavelet transform with even-size check"""
    rows, cols = img_array.shape
    rows = rows - rows % 2
    cols = cols - cols % 2
    img_array = img_array[:rows, :cols]
    
    blocks = img_array.reshape(rows//2, 2, cols//2, 2).transpose(0, 2, 1, 3)
    a = blocks[..., 0, 0]
    b = blocks[..., 0, 1]
    c = blocks[..., 1, 0]
    d = blocks[..., 1, 1]
    
    cA = (a + b + c + d) * 0.25
    cH = (a - c) * 0.5
    cV = (a - b) * 0.5
    cD = (a - d) * 0.5
    return cA, cH, cV, cD

def calculate_ssim(img1, img2):
    img1_flat = img1.ravel()
    img2_flat = img2.ravel()
    n = img1_flat.size
    
    sum1 = img1_flat.sum()
    sum2 = img2_flat.sum()
    sum12 = (img1_flat * img2_flat).sum()
    sum1_sq = (img1_flat** 2).sum()
    sum2_sq = (img2_flat** 2).sum()
    
    mean1 = sum1 / n
    mean2 = sum2 / n
    var1 = (sum1_sq - sum1**2 / n) / n
    var2 = (sum2_sq - sum2**2 / n) / n
    
    covar = (sum12 - sum1 * sum2 / n) / (n - 1) if n > 1 else 0.0
    
    C1, C2 = 6.5025, 58.5225
    numerator = (2 * mean1 * mean2 + C1) * (2 * covar + C2)
    denominator = (mean1**2 + mean2**2 + C1) * (var1 + var2 + C2)
    return numerator / denominator

def calculate_cwssim(image1_path, image2_path):
    """Compares two images using Complex Wavelet Structural Similarity Index (CW-SSIM)"""
    try:
        image1 = Image.open(image1_path).convert('L')
        image2 = Image.open(image2_path).convert('L')
        
        image1 = image1.resize(image2.size)
        
        img1_array = np.array(image1)
        img2_array = np.array(image2)
        
        cA1, cH1, cV1, cD1 = dwt2_simple(img1_array)
        cA2, cH2, cV2, cD2 = dwt2_simple(img2_array)
        
        ssim_cA = calculate_ssim(cA1, cA2)
        ssim_cH = calculate_ssim(cH1, cH2)
        ssim_cV = calculate_ssim(cV1, cV2)
        ssim_cD = calculate_ssim(cD1, cD2)
        cwssim_score = (ssim_cA + ssim_cH + ssim_cV + ssim_cD) / 4
        
        return cwssim_score
    
    except Exception as e:
        print(f"Error comparing images {image1_path} and {image2_path}: {e}")
        return 0.0

def process_prefix(prefix, output_png_dir, annotation_images, answer_images):
    annotation_image_path = os.path.join(output_png_dir, annotation_images[prefix])
    if prefix in answer_images:
        answer_image_path = os.path.join(output_png_dir, answer_images[prefix])
        cwssim_score = calculate_cwssim(answer_image_path, annotation_image_path)
        return f"{prefix}: {cwssim_score:.4f}\n"
    else:
        return f"{prefix}: 0.0000\n"
    
def calculate_cwssim_wrapper(task):
    """包装函数处理单个对比任务"""
    prefix, answer_path, annotation_path = task
    try:
        if os.path.exists(answer_path) and os.path.exists(annotation_path):
            return prefix, calculate_cwssim(answer_path, annotation_path)
        return prefix, 0.0
    except Exception as e:
        print(f"Error processing {prefix}: {str(e)}")
        return prefix, 0.0
    
def compare_images_and_save_results(output_png_dir, result_file_path, max_workers=None):
    """优化后的图像对比函数，支持显式指定进程数并批量写入结果"""
    image_files = os.listdir(output_png_dir)
    
    # 构建文件映射关系
    answer_map = {f.split('_')[0]: f for f in image_files if 'prediction.png' in f}
    annotation_map = {f.split('_')[0]: f for f in image_files if 'reference.png' in f}

    # 生成有序任务列表
    tasks = []
    for prefix in sorted(annotation_map.keys(), key=lambda x: int(x)):
        answer_file = answer_map.get(prefix, "")
        task = (
            prefix,
            os.path.join(output_png_dir, answer_file) if answer_file else "",
            os.path.join(output_png_dir, annotation_map[prefix])
        )
        tasks.append(task)

    # 设置默认进程数（CPU核心数75%）
    if max_workers is None:
        max_workers = 16

    # 使用带进度显示的结果收集
    results = []
    with concurrent.futures.ProcessPoolExecutor(max_workers=max_workers) as executor:
        futures = {executor.submit(calculate_cwssim_wrapper, task): task[0] for task in tasks}
        
        # 添加进度显示
        completed = 0
        total = len(tasks)
        print(f"使用 {max_workers} 个进程进行图像对比...")
        
        for future in concurrent.futures.as_completed(futures):
            completed += 1
            prefix = futures[future]
            try:
                _, score = future.result(timeout=60)  # 60秒超时
                results.append((prefix, score))
                # 更新进度显示
                print(f"\r处理进度: {completed}/{total} ({completed/total:.1%})", end="", flush=True)
            except Exception as e:
                print(f"\n处理 {prefix} 时发生错误: {str(e)}")
                results.append((prefix, 0.0))

    # 按原始顺序排序后写入
    with open(result_file_path, "w") as result_file:
        for prefix, score in sorted(results,
            key=lambda x: int(''.join(filter(str.isdigit, x[0])))):
            result_line = f"{prefix}: {score:.4f}\n"
            result_file.write(result_line)
    
    # 空结果检查（新增）
    if len(results) == 0:
        print("严重警告：未生成任何对比结果！")
    else:
        print(f"结果已保存至 {result_file_path} (共 {len(results)} 条记录)")
    

def sort_txt_file(input_file, output_file=None):
    """通用排序函数，路径由调用方提供"""
    try:
        with open(input_file, 'r') as f:
            lines = [line.strip() for line in f if line.strip()]

        def sort_key(line):
            left_num = line.split(':', 1)[0].strip()
            return int(left_num)

        sorted_lines = sorted(lines, key=sort_key)
        output = output_file or input_file.replace('.txt', '_sorted.txt')

        with open(output, 'w') as f:
            f.write('\n'.join(sorted_lines))
        print(f"文件已排序并保存为：{output}")
        return True
    except Exception as e:
        print(f"处理时发生错误：{str(e)}")
        return False

def calculate_average_score(file_path):
    """Calculates the average score from dynamic file path"""
    try:
        with open(file_path, 'r') as file:
            total_score = 0
            count = 0
            for line in file:
                parts = line.split(":")
                if len(parts) == 2:
                    score = float(parts[1].strip())
                    total_score += score
                    count += 1
            return total_score / count if count > 0 else 0.0
    except Exception as e:
        print(f"Error reading the file: {e}")
        return None

def calculate_average_and_ratio(file_path):
    """动态路径版本的非零分数统计"""
    try:
        total_score = 0.0
        valid_count = 0
        non_zero_count = 0
        
        with open(file_path, 'r') as file:
            for line in file:
                if not line.strip():
                    continue
                parts = line.rsplit(':', 1)
                if len(parts) != 2:
                    continue
                try:
                    score = float(parts[1].strip())
                except ValueError:
                    continue
                
                valid_count += 1
                if not np.isclose(score, 0.0):
                    non_zero_count += 1
                    total_score += score

        avg = total_score / non_zero_count if non_zero_count > 0 else 0.0
        ratio = non_zero_count / valid_count if valid_count > 0 else 0.0
        return avg, ratio
    except Exception as e:
        print(f"处理文件时发生错误: {e}")
        return None, None

def process_jsonl(json_file):
    """Main processing function with parallel execution"""
    # 读取 JSONL 文件
    data = []
    with open(json_file, "r") as file:
        for line in file:
            if line.strip():  # 跳过空行
                data.append(json.loads(line))
    
    # 创建必要的目录
    os.makedirs(table_dir, exist_ok=True)
    os.makedirs(output_pdf_dir, exist_ok=True)
    os.makedirs(output_png_dir, exist_ok=True)
    
    # 使用半数可用 CPU 进行资源平衡
    num_workers = max(1, os.cpu_count() // 2)
    
    with Pool(processes=num_workers) as pool:
        results = pool.imap_unordered(process_entry, data)
        
        # 监控进度
        success_count = 0
        for i, result in enumerate(results, 1):
            if result:
                success_count += 1
            print(f"Processed {i}/{len(data)} entries ({success_count} successes)")
    
    print(f"\nProcessing complete. Success rate: {success_count}/{len(data)}")
# 用户只需修改这个JSON文件路径
json_file = "/home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/output.jsonl"  # 修改此处为你的JSON文件路径

# 动态生成所有路径
base_dir = os.path.dirname(json_file)
extracted_tables_dir = os.path.join(base_dir, "extracted_tables")
table_dir = os.path.join(extracted_tables_dir, "latex_tables")
output_pdf_dir = os.path.join(extracted_tables_dir, "pdf_tables_full")
output_png_dir = os.path.join(extracted_tables_dir, "png_tables_full")
result_file_path = os.path.join(base_dir, "ssim_comparison_results.txt")
sorted_result_path = os.path.join(base_dir, "ssim_comparison_results_sorted.txt")

# 执行处理流程
process_jsonl(json_file)
print("Rendering and conversion complete!")

compare_images_and_save_results(output_png_dir, result_file_path)
sort_txt_file(result_file_path, sorted_result_path)
print("Image comparison complete!")

# 计算统计结果
if average_score := calculate_average_score(sorted_result_path):
    avg_message = f"平均值: {average_score:.4f}"
    print(avg_message)
    
avg, ratio = calculate_average_and_ratio(sorted_result_path)
if avg is not None and ratio is not None:
    stats_message = f"非零分数平均值: {avg:.4f}\n非零分数占比: {ratio:.2%}"
    print(stats_message)
    
    # 将统计结果写入文件末尾
    with open(sorted_result_path, 'a') as f:
        f.write('\n' + '-' * 50 + '\n')  # 添加分隔线
        f.write(avg_message + '\n')
        f.write(stats_message + '\n')
# Out:
# Processing 28...Processing 14...Processing 0...Processing 7...Processing 21...
#
# Processing 56...
# Processing 35...
# Processing 91...Processing 63...Processing 49...Processing 70...Processing 42...Processing 77...Processing 84...Processing 98...Processing 126...Processing 112...Processing 105...
#
# Processing 119...Processing 161...
# Processing 189...
# Processing 133...Processing 154...Processing 196...
#
#
# Processing 175...Processing 168...
#
# Processing 182...
# Processing 203...Processing 210...
# Processing 217...Processing 224...Processing 231...
# Processing 245...
# Processing 273...Processing 238...
# Processing 259...
# Processing 315...Processing 294...Processing 252...Processing 280...Processing 266...
# Processing 308...
# Processing 322...Processing 336...Processing 287...Processing 329...
# Processing 8...Processing 15...
# Processing 301...
# Processing 343...Processing 1...Processing 22...
# Processing 350...
#
# Processing 357...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing 140...Processing 147...
#
# Error: PDF not generated for /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/latex_tables/49_prediction.tex. LaTeX output:
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
#
# (/home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_t
# ables/pdf_tables_full/temp_786b33e09f8d41b5a2a810c4329510ed.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amscls/amsthm.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/amssymb.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def)))
# (/usr/share/texlive/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/share/texlive/texmf-dist/tex/latex/tools/array.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/booktabs/booktabs.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/multirow/multirow.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/natbib/natbib.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tools/tabularx.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tools/multicol.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tools/bm.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
#
# LaTeX Warning: Unused global option(s):
#     [standalone].
#
# No file temp_786b33e09f8d41b5a2a810c4329510ed.aux.
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# ) (/usr/share/texlive/texmf-dist/tex/latex/epstopdf-pkg/epstopdf-base.sty
# (/usr/share/texlive/texmf-dist/tex/latex/latexconfig/epstopdf-sys.cfg))
# *geometry* driver: auto-detecting
# *geometry* detected driver: pdftex
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/umsb.fd)
# ! Misplaced \omit.
# \multispan ->\omit
#                    \@multispan
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Missing } inserted.
# <inserted text>
#                 }
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Missing } inserted.
# <inserted text>
#                 }
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Missing \cr inserted.
# <inserted text>
#                 \cr
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...row {3}{*}{\multicolumn {2}{c|}{}} &
#                                                    \multicolumn {5}{c|}{Mist...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \multispan ->\omit
#                    \@multispan
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \span.
# \sp@n ->\span
#               \omit \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \sp@n ->\span \omit
#                     \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \span.
# \sp@n ->\span
#               \omit \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \sp@n ->\span \omit
#                     \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \span.
# \sp@n ->\span
#               \omit \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \sp@n ->\span \omit
#                     \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \span.
# \sp@n ->\span
#               \omit \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \sp@n ->\span \omit
#                     \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Incompatible list can't be unboxed.
# \@arstrut ->\unhcopy \@arstrutbox
#
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...}} & \multicolumn {5}{c|}{Mistral} &
#                                                    \multicolumn {5}{c|}{Chat...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \multispan ->\omit
#                    \@multispan
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \span.
# \sp@n ->\span
#               \omit \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \sp@n ->\span \omit
#                     \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \span.
# \sp@n ->\span
#               \omit \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \sp@n ->\span \omit
#                     \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \span.
# \sp@n ->\span
#               \omit \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \sp@n ->\span \omit
#                     \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \span.
# \sp@n ->\span
#               \omit \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \sp@n ->\span \omit
#                     \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Incompatible list can't be unboxed.
# \@arstrut ->\unhcopy \@arstrutbox
#
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...l} & \multicolumn {5}{c|}{ChatGPT} &
#                                                    \multicolumn {5}{c|}{GPT-...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \multispan ->\omit
#                    \@multispan
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \span.
# \sp@n ->\span
#               \omit \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \sp@n ->\span \omit
#                     \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \span.
# \sp@n ->\span
#               \omit \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \sp@n ->\span \omit
#                     \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \span.
# \sp@n ->\span
#               \omit \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \sp@n ->\span \omit
#                     \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \span.
# \sp@n ->\span
#               \omit \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \sp@n ->\span \omit
#                     \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Incompatible list can't be unboxed.
# \@arstrut ->\unhcopy \@arstrutbox
#
# l.38 \end{tabular}}
#                    \end{table}\end{document}
#
# ! LaTeX Error: There's no line here to end.
#
# See the LaTeX manual or LaTeX Companion for explanation.
# Type  H <return>  for immediate help.
#  ...
#
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.38 \end{tabular}}
#                    \end{table}\end{document}
#
# ! LaTeX Error: Something's wrong--perhaps a missing \item.
#
# See the LaTeX manual or LaTeX Companion for explanation.
# Type  H <return>  for immediate help.
#  ...
#
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \noalign.
# \hline ->\noalign
#                   {\ifnum 0=`}\fi \hrule \@height \arrayrulewidth \futurelet...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! You can't use `\hrule' here except with leaders.
# \hline ->\noalign {\ifnum 0=`}\fi \hrule
#                                          \@height \arrayrulewidth \futurelet...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Missing number, treated as zero.
# <to be read again>
#                    \futurelet
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Illegal unit of measure (pt inserted).
# <to be read again>
#                    \futurelet
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \multispan ->\omit
#                    \@multispan
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \span.
# \sp@n ->\span
#               \omit \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \sp@n ->\span \omit
#                     \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...\\ \hline \multicolumn {2}{c|}{FN} &
#                                                    \multicolumn {2}{c|}{FP} ...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \multispan ->\omit
#                    \@multispan
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \span.
# \sp@n ->\span
#               \omit \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \sp@n ->\span \omit
#                     \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...c|}{FN} & \multicolumn {2}{c|}{FP} &
#                                                    \multicolumn {2}{c|}{Unk....
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \multispan ->\omit
#                    \@multispan
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \span.
# \sp@n ->\span
#               \omit \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \sp@n ->\span \omit
#                     \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...}{FP} & \multicolumn {2}{c|}{Unk.} &
#                                                    \multicolumn {2}{c|}{FN} ...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \multispan ->\omit
#                    \@multispan
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \span.
# \sp@n ->\span
#               \omit \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \sp@n ->\span \omit
#                     \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...}{Unk.} & \multicolumn {2}{c|}{FN} &
#                                                    \multicolumn {2}{c|}{FP} ...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \multispan ->\omit
#                    \@multispan
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \span.
# \sp@n ->\span
#               \omit \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \sp@n ->\span \omit
#                     \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...c|}{FN} & \multicolumn {2}{c|}{FP} &
#                                                    \multicolumn {2}{c|}{Unk....
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \multispan ->\omit
#                    \@multispan
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \span.
# \sp@n ->\span
#               \omit \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \sp@n ->\span \omit
#                     \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...P} & \multicolumn {2}{c|}{Unk. FN} &
#                                                    \multicolumn {2}{c|}{FP} ...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \multispan ->\omit
#                    \@multispan
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \span.
# \sp@n ->\span
#               \omit \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \sp@n ->\span \omit
#                     \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...nk. FN} & \multicolumn {2}{c|}{FP} &
#                                                    \multicolumn {2}{c|}{Unk....
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \multispan ->\omit
#                    \@multispan
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \span.
# \sp@n ->\span
#               \omit \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \sp@n ->\span \omit
#                     \advance \@multicnt \m@ne
# l.38 \end{tabular}}
#                    \end{table}\end{document}
#
# ! LaTeX Error: Something's wrong--perhaps a missing \item.
#
# See the LaTeX manual or LaTeX Companion for explanation.
# Type  H <return>  for immediate help.
#  ...
#
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \noalign.
# \hline ->\noalign
#                   {\ifnum 0=`}\fi \hrule \@height \arrayrulewidth \futurelet...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! You can't use `\hrule' here except with leaders.
# \hline ->\noalign {\ifnum 0=`}\fi \hrule
#                                          \@height \arrayrulewidth \futurelet...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Missing number, treated as zero.
# <to be read again>
#                    \futurelet
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Illegal unit of measure (pt inserted).
# <to be read again>
#                    \futurelet
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! You can't use `macro parameter character #' in restricted horizontal mode.
# <recently read> ##
#
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...icolumn {2}{c|}{Unk.} \\ \hline ## &
#                                                    & ## & & ## & & ## & ## &...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...olumn {2}{c|}{Unk.} \\ \hline ## & &
#                                                    ## & & ## & & ## & ## & &...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! You can't use `macro parameter character #' in restricted horizontal mode.
# <argument> ...mn {2}{c|}{Unk.} \\ \hline ## & & ##
#                                                    & & ## & & ## & ## & & ##...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ... {2}{c|}{Unk.} \\ \hline ## & & ## &
#                                                    & ## & & ## & ## & & ## &...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...2}{c|}{Unk.} \\ \hline ## & & ## & &
#                                                    ## & & ## & ## & & ## & &...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! You can't use `macro parameter character #' in restricted horizontal mode.
# <argument> ...c|}{Unk.} \\ \hline ## & & ## & & ##
#                                                    & & ## & ## & & ## & & ##...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...}{Unk.} \\ \hline ## & & ## & & ## &
#                                                    & ## & ## & & ## & & ## &...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...Unk.} \\ \hline ## & & ## & & ## & &
#                                                    ## & ## & & ## & & ## & &...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! You can't use `macro parameter character #' in restricted horizontal mode.
# <argument> ....} \\ \hline ## & & ## & & ## & & ##
#                                                    & ## & & ## & & ## & & ##...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ... \\ \hline ## & & ## & & ## & & ## &
#                                                    ## & & ## & & ## & & ## &...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! You can't use `macro parameter character #' in restricted horizontal mode.
# <argument> ... \hline ## & & ## & & ## & & ## & ##
#                                                    & & ## & & ## & & ## & ##...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...hline ## & & ## & & ## & & ## & ## &
#                                                    & ## & & ## & & ## & ## &...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...ine ## & & ## & & ## & & ## & ## & &
#                                                    ## & & ## & & ## & ## & \...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! You can't use `macro parameter character #' in restricted horizontal mode.
# <argument> ... ## & & ## & & ## & & ## & ## & & ##
#                                                    & & ## & & ## & ## & \\ \...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...# & & ## & & ## & & ## & ## & & ## &
#                                                    & ## & & ## & ## & \\ \hl...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...& & ## & & ## & & ## & ## & & ## & &
#                                                    ## & & ## & ## & \\ \hlin...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! You can't use `macro parameter character #' in restricted horizontal mode.
# <argument> ... ## & & ## & & ## & ## & & ## & & ##
#                                                    & & ## & ## & \\ \hline \...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...# & & ## & & ## & ## & & ## & & ## &
#                                                    & ## & ## & \\ \hline \mu...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...& & ## & & ## & ## & & ## & & ## & &
#                                                    ## & ## & \\ \hline \mult...
# l.38 \end{tabular}}
#                    \end{table}\end{document}
# (That makes 100 errors; please try again.)
# !  ==> Fatal error occurred, no output PDF file produced!
# Transcript written on /home/lingjun/code/InternVL/internvl_chat/html_table_late
# x_results/extracted_tables/pdf_tables_full/temp_786b33e09f8d41b5a2a810c4329510e
# d.log.
#
# Skipping PNG conversion for 49_prediction - PDF not found
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/latex_tables/0_prediction.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/0_prediction.pdf.
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/latex_tables/126_prediction.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/126_prediction.pdf.Successfully rendered /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/latex_tables/266_prediction.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/266_prediction.pdf.
#
# Error: PDF not generated for /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/latex_tables/7_prediction.tex. LaTeX output:
# This is pdfTeX, Version 3.14159265-2.6-1.40.20 (TeX Live 2019/Debian) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
#
# (/home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_t
# ables/pdf_tables_full/temp_cd4c6c48023649ac80c8684df80792b8.tex
# LaTeX2e <2020-02-02> patch level 2
# L3 programming layer <2020-02-14>
# (/usr/share/texlive/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/share/texlive/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texlive/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/base/fontenc.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsgen.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsbsy.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsmath/amsopn.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/amscls/amsthm.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/amssymb.sty
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/amsfonts.sty))
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/graphicx.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/graphics.sty
# (/usr/share/texlive/texmf-dist/tex/latex/graphics/trig.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-cfg/graphics.cfg)
# (/usr/share/texlive/texmf-dist/tex/latex/graphics-def/pdftex.def)))
# (/usr/share/texlive/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/share/texlive/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/share/texlive/texmf-dist/tex/latex/tools/array.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/booktabs/booktabs.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/multirow/multirow.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/natbib/natbib.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tools/tabularx.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tools/multicol.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/tools/bm.sty)
# (/usr/share/texlive/texmf-dist/tex/latex/l3backend/l3backend-pdfmode.def)
#
# LaTeX Warning: Unused global option(s):
#     [standalone].
#
# No file temp_cd4c6c48023649ac80c8684df80792b8.aux.
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# ) (/usr/share/texlive/texmf-dist/tex/latex/epstopdf-pkg/epstopdf-base.sty
# (/usr/share/texlive/texmf-dist/tex/latex/latexconfig/epstopdf-sys.cfg))
# *geometry* driver: auto-detecting
# *geometry* detected driver: pdftex
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/umsa.fd)
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/umsb.fd)
# ! Misplaced \omit.
# \multispan ->\omit
#                    \@multispan
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Missing } inserted.
# <inserted text>
#                 }
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Missing } inserted.
# <inserted text>
#                 }
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Missing \cr inserted.
# <inserted text>
#                 \cr
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...2}{*}{\multicolumn {2}{c|}{model}} &
#                                                    \multicolumn {2}{c|}{body...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \multispan ->\omit
#                    \@multispan
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \span.
# \sp@n ->\span
#               \omit \advance \@multicnt \m@ne
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \sp@n ->\span \omit
#                     \advance \@multicnt \m@ne
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Incompatible list can't be unboxed.
# \@arstrut ->\unhcopy \@arstrutbox
#
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...del}} & \multicolumn {2}{c|}{body} &
#                                                    \multicolumn {2}{c|}{hand...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \multispan ->\omit
#                    \@multispan
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \span.
# \sp@n ->\span
#               \omit \advance \@multicnt \m@ne
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \sp@n ->\span \omit
#                     \advance \@multicnt \m@ne
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Incompatible list can't be unboxed.
# \@arstrut ->\unhcopy \@arstrutbox
#
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...body} & \multicolumn {2}{c|}{hand} &
#                                                    \multicolumn {2}{c|}{face...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \multispan ->\omit
#                    \@multispan
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \span.
# \sp@n ->\span
#               \omit \advance \@multicnt \m@ne
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \sp@n ->\span \omit
#                     \advance \@multicnt \m@ne
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Incompatible list can't be unboxed.
# \@arstrut ->\unhcopy \@arstrutbox
#
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...hand} & \multicolumn {2}{c|}{face} &
#                                                    \multicolumn {2}{c|}{obje...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \multispan ->\omit
#                    \@multispan
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \span.
# \sp@n ->\span
#               \omit \advance \@multicnt \m@ne
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \sp@n ->\span \omit
#                     \advance \@multicnt \m@ne
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Incompatible list can't be unboxed.
# \@arstrut ->\unhcopy \@arstrutbox
#
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...ce} & \multicolumn {2}{c|}{object} &
#                                                    \multicolumn {2}{c|}{conm...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \multispan ->\omit
#                    \@multispan
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \span.
# \sp@n ->\span
#               \omit \advance \@multicnt \m@ne
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \omit.
# \sp@n ->\span \omit
#                     \advance \@multicnt \m@ne
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Incompatible list can't be unboxed.
# \@arstrut ->\unhcopy \@arstrutbox
#
# l.50 \end{tabular}}
#                    \end{table}\end{document}
#
# ! LaTeX Error: There's no line here to end.
#
# See the LaTeX manual or LaTeX Companion for explanation.
# Type  H <return>  for immediate help.
#  ...
#
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.50 \end{tabular}}
#                    \end{table}\end{document}
#
# ! LaTeX Error: Something's wrong--perhaps a missing \item.
#
# See the LaTeX manual or LaTeX Companion for explanation.
# Type  H <return>  for immediate help.
#  ...
#
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \noalign.
# \hline ->\noalign
#                   {\ifnum 0=`}\fi \hrule \@height \arrayrulewidth \futurelet...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! You can't use `\hrule' here except with leaders.
# \hline ->\noalign {\ifnum 0=`}\fi \hrule
#                                          \@height \arrayrulewidth \futurelet...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Missing number, treated as zero.
# <to be read again>
#                    \futurelet
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Illegal unit of measure (pt inserted).
# <to be read again>
#                    \futurelet
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...n {2}{c|}{conmmon} \\ \hline value &
#                                                    num & value & num & value...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...c|}{conmmon} \\ \hline value & num &
#                                                    value & num & value & num...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...mon} \\ \hline value & num & value &
#                                                    num & value & num & value...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...\ \hline value & num & value & num &
#                                                    value & num & value & num...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ... value & num & value & num & value &
#                                                    num & value & num & value...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ... & num & value & num & value & num &
#                                                    value & num & value & num...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ... value & num & value & num & value &
#                                                    num & value & num \\ \hli...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ... & num & value & num & value & num &
#                                                    value & num \\ \hline \mu...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ... value & num & value & num & value &
#                                                    num \\ \hline \multirow {...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
#
# ! LaTeX Error: Something's wrong--perhaps a missing \item.
#
# See the LaTeX manual or LaTeX Companion for explanation.
# Type  H <return>  for immediate help.
#  ...
#
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \noalign.
# \hline ->\noalign
#                   {\ifnum 0=`}\fi \hrule \@height \arrayrulewidth \futurelet...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! You can't use `\hrule' here except with leaders.
# \hline ->\noalign {\ifnum 0=`}\fi \hrule
#                                          \@height \arrayrulewidth \futurelet...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Missing number, treated as zero.
# <to be read again>
#                    \futurelet
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Illegal unit of measure (pt inserted).
# <to be read again>
#                    \futurelet
# l.50 \end{tabular}}
#                    \end{table}\end{document}
#
# Overfull \vbox (12.0pt too high) detected at line 50
# ! Misplaced alignment tab character &.
# <argument> ...num \\ \hline \multirow {2}{*}{IF} &
#                                                    gt & 234 & 128 & 106 & 11...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...\ \hline \multirow {2}{*}{IF} & gt &
#                                                    234 & 128 & 106 & 119 & 1...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...ne \multirow {2}{*}{IF} & gt & 234 &
#                                                    128 & 106 & 119 & 128 & 1...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...ltirow {2}{*}{IF} & gt & 234 & 128 &
#                                                    106 & 119 & 128 & 139 & 3...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ... {2}{*}{IF} & gt & 234 & 128 & 106 &
#                                                    119 & 128 & 139 & 364 & &...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...}{IF} & gt & 234 & 128 & 106 & 119 &
#                                                    128 & 139 & 364 & & 130 &...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...& gt & 234 & 128 & 106 & 119 & 128 &
#                                                    139 & 364 & & 130 & \\ \h...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ... 234 & 128 & 106 & 119 & 128 & 139 &
#                                                    364 & & 130 & \\ \hline p...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ... 128 & 106 & 119 & 128 & 139 & 364 &
#                                                    & 130 & \\ \hline predict...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...28 & 106 & 119 & 128 & 139 & 364 & &
#                                                    130 & \\ \hline predict &...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...06 & 119 & 128 & 139 & 364 & & 130 &
#                                                    \\ \hline predict & 200 &...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
#
# ! LaTeX Error: Something's wrong--perhaps a missing \item.
#
# See the LaTeX manual or LaTeX Companion for explanation.
# Type  H <return>  for immediate help.
#  ...
#
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \noalign.
# \hline ->\noalign
#                   {\ifnum 0=`}\fi \hrule \@height \arrayrulewidth \futurelet...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! You can't use `\hrule' here except with leaders.
# \hline ->\noalign {\ifnum 0=`}\fi \hrule
#                                          \@height \arrayrulewidth \futurelet...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Missing number, treated as zero.
# <to be read again>
#                    \futurelet
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Illegal unit of measure (pt inserted).
# <to be read again>
#                    \futurelet
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ... & 364 & & 130 & \\ \hline predict &
#                                                    200 & 126 & 83 & 121 & 13...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ... & & 130 & \\ \hline predict & 200 &
#                                                    126 & 83 & 121 & 136 & 13...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...30 & \\ \hline predict & 200 & 126 &
#                                                    83 & 121 & 136 & 139 & 36...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...\\ \hline predict & 200 & 126 & 83 &
#                                                    121 & 136 & 139 & 368 & &...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...ine predict & 200 & 126 & 83 & 121 &
#                                                    136 & 139 & 368 & & 115 &...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...edict & 200 & 126 & 83 & 121 & 136 &
#                                                    139 & 368 & & 115 & \\ \h...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...& 200 & 126 & 83 & 121 & 136 & 139 &
#                                                    368 & & 115 & \\ \hline \...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...& 126 & 83 & 121 & 136 & 139 & 368 &
#                                                    & 115 & \\ \hline \multir...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...126 & 83 & 121 & 136 & 139 & 368 & &
#                                                    115 & \\ \hline \multirow...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...83 & 121 & 136 & 139 & 368 & & 115 &
#                                                    \\ \hline \multirow {2}{*...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
#
# ! LaTeX Error: Something's wrong--perhaps a missing \item.
#
# See the LaTeX manual or LaTeX Companion for explanation.
# Type  H <return>  for immediate help.
#  ...
#
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \noalign.
# \hline ->\noalign
#                   {\ifnum 0=`}\fi \hrule \@height \arrayrulewidth \futurelet...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! You can't use `\hrule' here except with leaders.
# \hline ->\noalign {\ifnum 0=`}\fi \hrule
#                                          \@height \arrayrulewidth \futurelet...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Missing number, treated as zero.
# <to be read again>
#                    \futurelet
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Illegal unit of measure (pt inserted).
# <to be read again>
#                    \futurelet
# l.50 \end{tabular}}
#                    \end{table}\end{document}
#
# Overfull \vbox (12.0pt too high) detected at line 50
# ! Misplaced alignment tab character &.
# <argument> ... & \\ \hline \multirow {2}{*}{LCM} &
#                                                    gt & 125 & 148 & 89 & 143...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ... \hline \multirow {2}{*}{LCM} & gt &
#                                                    125 & 148 & 89 & 143 & 16...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...e \multirow {2}{*}{LCM} & gt & 125 &
#                                                    148 & 89 & 143 & 166 & 15...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...tirow {2}{*}{LCM} & gt & 125 & 148 &
#                                                    89 & 143 & 166 & 153 & 29...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ... {2}{*}{LCM} & gt & 125 & 148 & 89 &
#                                                    143 & 166 & 153 & 298 & &...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...}{LCM} & gt & 125 & 148 & 89 & 143 &
#                                                    166 & 153 & 298 & & 81 & ...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ... & gt & 125 & 148 & 89 & 143 & 166 &
#                                                    153 & 298 & & 81 & \\ \hl...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...& 125 & 148 & 89 & 143 & 166 & 153 &
#                                                    298 & & 81 & \\ \hline pr...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...& 148 & 89 & 143 & 166 & 153 & 298 &
#                                                    & 81 & \\ \hline predict ...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...148 & 89 & 143 & 166 & 153 & 298 & &
#                                                    81 & \\ \hline predict & ...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ... 89 & 143 & 166 & 153 & 298 & & 81 &
#                                                    \\ \hline predict & 135 &...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
#
# ! LaTeX Error: Something's wrong--perhaps a missing \item.
#
# See the LaTeX manual or LaTeX Companion for explanation.
# Type  H <return>  for immediate help.
#  ...
#
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced \noalign.
# \hline ->\noalign
#                   {\ifnum 0=`}\fi \hrule \@height \arrayrulewidth \futurelet...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! You can't use `\hrule' here except with leaders.
# \hline ->\noalign {\ifnum 0=`}\fi \hrule
#                                          \@height \arrayrulewidth \futurelet...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Missing number, treated as zero.
# <to be read again>
#                    \futurelet
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Illegal unit of measure (pt inserted).
# <to be read again>
#                    \futurelet
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...3 & 298 & & 81 & \\ \hline predict &
#                                                    135 & 149 & 85 & 144 & 15...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...8 & & 81 & \\ \hline predict & 135 &
#                                                    149 & 85 & 144 & 150 & 15...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# ! Misplaced alignment tab character &.
# <argument> ...81 & \\ \hline predict & 135 & 149 &
#                                                    85 & 144 & 150 & 150 & 32...
# l.50 \end{tabular}}
#                    \end{table}\end{document}
# (That makes 100 errors; please try again.)
# !  ==> Fatal error occurred, no output PDF file produced!
# Transcript written on /home/lingjun/code/InternVL/internvl_chat/html_table_late
# x_results/extracted_tables/pdf_tables_full/temp_cd4c6c48023649ac80c8684df80792b
# 8.log.
#
# Skipping PNG conversion for 7_prediction - PDF not found
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/latex_tables/203_prediction.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/203_prediction.pdf.
# ...
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/111_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/111_reference.png
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/349_prediction.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/349_prediction.png
# Completed processing 111
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/125_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/125_reference.png
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/314_prediction.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/314_prediction.pngCompleted processing 125
#
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/251_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/251_reference.png
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/latex_tables/279_reference.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/279_reference.pdf.
# Completed processing 251
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/286_prediction.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/286_prediction.png
# Processed 322/361 entries (322 successes)
# Processed 323/361 entries (323 successes)
# Processed 324/361 entries (324 successes)
# Processed 325/361 entries (325 successes)
# Processed 326/361 entries (326 successes)
# Processed 327/361 entries (327 successes)
# Processed 328/361 entries (328 successes)
# Processed 329/361 entries (329 successes)
# Processed 330/361 entries (330 successes)
# Processed 331/361 entries (331 successes)
# Processed 332/361 entries (332 successes)
# Processed 333/361 entries (333 successes)
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/latex_tables/202_reference.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/202_reference.pdf.
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/latex_tables/244_reference.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/244_reference.pdf.
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/139_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/139_reference.png
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/335_prediction.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/335_prediction.png
# Completed processing 139
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/latex_tables/258_reference.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/258_reference.pdf.
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/latex_tables/230_reference.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/230_reference.pdf.Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/342_prediction.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/342_prediction.png
#
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/latex_tables/272_reference.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/272_reference.pdf.
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/latex_tables/265_reference.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/265_reference.pdf.
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/188_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/188_reference.png
# Completed processing 188
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/118_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/118_reference.png
# Completed processing 118
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/174_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/174_reference.png
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/153_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/153_reference.pngCompleted processing 174
#
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/167_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/167_reference.pngSuccessfully rendered /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/latex_tables/300_reference.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/300_reference.pdf.Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/146_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/146_reference.png
#
#
# Completed processing 153
# Completed processing 167Completed processing 146
#
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/latex_tables/293_reference.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/293_reference.pdf.
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/195_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/195_reference.png
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/209_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/209_reference.png
# Completed processing 195
# Completed processing 209
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/321_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/321_reference.png
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/latex_tables/314_reference.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/314_reference.pdf.
# Completed processing 321
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/latex_tables/349_reference.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/349_reference.pdf.
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/latex_tables/328_reference.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/328_reference.pdf.
# Processed 334/361 entries (334 successes)
# Processed 335/361 entries (335 successes)
# Processed 336/361 entries (336 successes)
# Processed 337/361 entries (337 successes)
# Processed 338/361 entries (338 successes)
# Processed 339/361 entries (339 successes)
# Processed 340/361 entries (340 successes)
# Processed 341/361 entries (341 successes)
# Processed 342/361 entries (342 successes)
# Processed 343/361 entries (343 successes)
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/latex_tables/286_reference.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/286_reference.pdf.
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/279_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/279_reference.png
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/307_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/307_reference.pngCompleted processing 279
#
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/latex_tables/335_reference.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/335_reference.pdf.
# Completed processing 307
# Successfully rendered /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/latex_tables/342_reference.tex to PDF at /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/342_reference.pdf.
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/223_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/223_reference.png
# Completed processing 223Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/202_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/202_reference.png
#
# Completed processing 202
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/230_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/230_reference.pngConverted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/244_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/244_reference.png
#
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/356_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/356_reference.png
# Completed processing 230Completed processing 244
#
# Completed processing 356
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/265_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/265_reference.png
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/272_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/272_reference.png
# Completed processing 265Completed processing 272
#
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/258_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/258_reference.png
# Completed processing 258
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/300_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/300_reference.png
# Completed processing 300
# Processed 344/361 entries (344 successes)
# Processed 345/361 entries (345 successes)
# Processed 346/361 entries (346 successes)
# Processed 347/361 entries (347 successes)
# Processed 348/361 entries (348 successes)
# Processed 349/361 entries (349 successes)
# Processed 350/361 entries (350 successes)
# Processed 351/361 entries (351 successes)
# Processed 352/361 entries (352 successes)
# Processed 353/361 entries (353 successes)
# Processed 354/361 entries (354 successes)
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/293_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/293_reference.png
# Completed processing 293
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/314_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/314_reference.png
# Completed processing 314
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/286_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/286_reference.png
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/349_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/349_reference.png
# Completed processing 286
# Completed processing 349
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/342_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/342_reference.png
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/328_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/328_reference.pngCompleted processing 342
#
# Completed processing 328
# Converted /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/pdf_tables_full/335_reference.pdf to /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/extracted_tables/png_tables_full/335_reference.png
# Completed processing 335
# Processed 355/361 entries (355 successes)
# Processed 356/361 entries (356 successes)
# Processed 357/361 entries (357 successes)
# Processed 358/361 entries (358 successes)
# Processed 359/361 entries (359 successes)
# Processed 360/361 entries (360 successes)
# Processed 361/361 entries (361 successes)
#
# Processing complete. Success rate: 361/361
# Rendering and conversion complete!
# 使用 16 个进程进行图像对比...
# 处理进度: 361/361 (100.0%)结果已保存至 /home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/ssim_comparison_results.txt (共 361 条记录)
# 文件已排序并保存为：/home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/ssim_comparison_results_sorted.txt
# Image comparison complete!
# 平均值: 0.4181
# 非零分数平均值: 0.4869
# 非零分数占比: 85.87%

# %%
###########Teds_structure_evaluation###########
import re
from table_recognition_metric import TEDS
import multiprocessing
import json

def remove_grid_lines(latex_table):
    cleaned_table = re.sub(r'\\cmidrule{\s*}|\\cdashline\{[0-9]+(-[0-9]+)?\}\s*|\\cmidrule$(?:lr|r|l)?$\{[0-9]+\-[0-9]+\}\s*|\\arrayrulecolor{.*?}\s*|\\caption{.*?}\s*|\\centering\s*|\\hline\s*|\\cline{.*?}\s*|\\toprule\s*|\\midrule\s*|\\bottomrule\s*', '', latex_table)
    cleaned_table = re.sub(r'\\tabularnewline', r'\\\\', cleaned_table)
    cleaned_table = re.sub(r'\n\s*\n', '\n', cleaned_table)
    return cleaned_table.strip(' \n')

def fix_multi(cell):
    multirow_pattern = r'\\multirow{(\d+)}{.*?}{(.*?)}'
    multicol_pattern = r'\\multicolumn{(\d+)}{.*?}{(.*?)}'
    
    match = re.search(multirow_pattern, cell['content'])
    if match:
        cell['rowspan'] = int(match.group(1))
        cell['content'] = cell['content'].replace(match.group(0), match.group(2).strip(), 1).strip()

    match = re.search(multicol_pattern, cell['content'])
    if match:
        cell['colspan'] = int(match.group(1))
        cell['content'] = cell['content'].replace(match.group(0), match.group(2).strip(), 1).strip()
    return cell    

def grid2html(grid):
    def to_td(grid, r, c):
        if grid[r][c] in ['<<', '^^', '..']:
            return ''
        td = {'text': grid[r][c], 'rowspan':1, 'colspan': 1}
        for i in range(r + 1, len(grid)):
            if grid[i][c] == '^^':
                td['rowspan'] += 1
            else:
                break   
        for j in range(c + 1, len(grid[r])):
            if grid[r][j] == '<<':
                td['colspan'] += 1
            else:
                break
        return f'<td rowspan={td["rowspan"]} colspan={td["colspan"]}> {td["text"]} </td>'.replace('rowspan=1', '').replace('colspan=1', '')
        
    html = []
    for r in range(len(grid)):
        row = []
        for c in range(len(grid[0])):
            row.append(to_td(grid, r, c))
        html.append(f'<tr> {"".join(row)} </tr>')
    return '<html><body><table>' + '\n'.join(html) + '</table></body></html>'

def qylatex_to_grid(latex):
    if not re.search(r'\\end{tabular[x]*\*?\}', latex):
        return
    pattern = r'\\begin\{tabular[x]*\*?\}.*?\\end\{tabular[x]*\*?\}'
    matches = re.findall(pattern, latex, re.DOTALL)
    if not matches:
        return
    content = remove_grid_lines(matches[0])
    rows = content.strip(' \n').split(r'\\')
    processed_rows = []
    for row in rows:
        if not row.strip():
            continue
        columns = re.split(r'(?<!\\)&', row)
        columns = [fix_multi({'content': c.strip(' \n'), 'rowspan': 1, 'colspan': 1}) for c in columns]
        processed_rows.append(columns)
    max_cols = max([sum([it['colspan'] for it in r]) for r in processed_rows]) if processed_rows else 0
    grid = [[None for _ in range(max_cols)] for _ in range(len(processed_rows))]
    r_idx_bias = 0
    for r_idx, row in enumerate(processed_rows):
        r_idx += r_idx_bias
        while r_idx >= len(grid):
            grid.append([None for _ in range(max_cols)])
        c_idx = 0
        current_row_bias = 10000
        for cell in row:
            while c_idx < len(grid[r_idx]) and grid[r_idx][c_idx] is not None:
                c_idx += 1
            if c_idx >= len(grid[r_idx]):
                break
            current_row_bias = min(current_row_bias, cell['rowspan'])
            grid[r_idx][c_idx] = cell['content']
            for r in range(cell['rowspan']):
                for c in range(cell['colspan']):
                    if r == 0 and c == 0:
                        continue
                    target_r = r_idx + r
                    target_c = c_idx + c
                    if target_r >= len(grid):
                        grid.append([None for _ in range(max_cols)])
                    if target_c < len(grid[target_r]):
                        grid[target_r][target_c] = '^^' if r > 0 else ('<<' if c > 0 else '..')
            c_idx += cell['colspan']
        r_idx_bias += current_row_bias - 1
    grid = [[c if c is not None else '' for c in r] for r in grid]
    return grid

def latex2html(latex_str):
    latex_str = re.sub(r'(?<!\\)%.*$', '', latex_str, flags=re.MULTILINE)
    latex_str = re.sub(r'(?<!\\)\\\\$$.*?$$', '', latex_str, flags=re.DOTALL)
    latex_str = latex_str.replace('\n', '').replace('\t', '')
    try:
        grid = qylatex_to_grid(latex_str)
    except IndexError as e:
        print(f"IndexError: {str(e)}")
        return 
    if not grid:
        return
    return grid2html(grid)

def teds_structure(gt, pred):
    gt_html = latex2html(gt)
    pred_html = latex2html(pred)
    if not pred_html:
        return 0, 0
    structure_teds = TEDS(structure_only=True)
    structure_score = structure_teds(gt_html, pred_html)
    all_teds = TEDS()
    teds_score = all_teds(gt_html, pred_html)
    return structure_score, teds_score

def process_item(args):
    idx, item = args
    try:
        if not isinstance(item, dict):
            print(f"Item {idx}: Invalid data type, skipping")
            return (None, None, None)
        # Check for different possible key combinations
        if 'questionId' in item and 'answer' in item and 'annotation' in item:
            qid = item['questionId']
            pred = item['answer']
            gt = item['annotation']
        elif 'id' in item and 'prediction' in item and 'reference' in item:
            qid = item['id']
            pred = item['prediction']
            gt = item['reference']
        else:
            print(f"Item {idx}: Missing required keys")
            return (None, None, None)
        structure_score, teds_score = teds_structure(gt, pred)
        return (qid, structure_score, teds_score)
    except Exception as e:
        print(f"Error processing item {idx}: {str(e)}")
        return (None, None, None)

def calculate_stats(scores):
    avg_all = sum(scores) / len(scores) if scores else 0
    non_zero_scores = [s for s in scores if s != 0]
    avg_non_zero = sum(non_zero_scores)/len(non_zero_scores) if non_zero_scores else 0
    non_zero_ratio = len(non_zero_scores)/len(scores) if scores else 0
    return avg_all, avg_non_zero, non_zero_ratio

def process_file(input_path):
    output_path = input_path.rsplit('.', 1)[0] + '_eval.txt'
    data = []
    # Determine file type and read data
    if input_path.endswith('.json'):
        try:
            with open(input_path, 'r', encoding='utf-8') as f:
                data = json.load(f)
                if not isinstance(data, list):
                    raise ValueError("JSON root is not an array")
        except Exception as e:
            print(f"Error reading JSON: {str(e)}")
            return
    elif input_path.endswith('.jsonl'):
        with open(input_path, 'r', encoding='utf-8') as f:
            for line in f:
                try:
                    data.append(json.loads(line.strip()))
                except json.JSONDecodeError as e:
                    print(f"JSONL parse error: {str(e)}")
    else:
        print("Unsupported file format. Use .json or .jsonl")
        return
    
    # Process data
    structure_results = {}
    teds_results = {}
    cpu_num = multiprocessing.cpu_count()//2
    pool = multiprocessing.Pool(processes=cpu_num)
    task_args = [(i+1, item) for i, item in enumerate(data)]
    
    processed = 0
    for qid, structure_score, teds_score in pool.imap(process_item, task_args):
        if qid is not None:
            structure_results[qid] = structure_score
            teds_results[qid] = teds_score
        processed += 1
        if processed % 10 == 0:
            print(f"Processed {processed}/{len(data)}")
    
    pool.close()
    pool.join()
    
    # Write results
    structure_stats = calculate_stats(list(structure_results.values()))
    teds_stats = calculate_stats(list(teds_results.values()))
    
    with open(output_path, 'w', encoding='utf-8') as f:
        f.write("ID:Structure_Score,TEDS_Score\n")
        for qid in sorted(structure_results):
            f.write(f"{qid}:{structure_results[qid]:.4f},{teds_results[qid]:.4f}\n")
        
        f.write("\n=== Structure Score ===\n")
        f.write(f"Total: {len(data)}\nValid: {len(structure_results)}\n")
        f.write(f"Non-zero: {structure_stats[2]:.2%}\n")
        f.write(f"Average (All): {structure_stats[0]:.4f}\nAverage (Non-zero): {structure_stats[1]:.4f}\n")
        
        f.write("\n=== TEDS Score ===\n")
        f.write(f"Total: {len(data)}\nValid: {len(teds_results)}\n")
        f.write(f"Non-zero: {teds_stats[2]:.2%}\n")
        f.write(f"Average (All): {teds_stats[0]:.4f}\nAverage (Non-zero): {teds_stats[1]:.4f}\n")

# Example usage
process_file("/home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/output.jsonl")  # Replace with your file path
# Out:
# Processed 10/361
# Processed 20/361
# Processed 30/361
# Processed 40/361
# Processed 50/361
# Processed 60/361
# Processed 70/361
# Processed 80/361
# Processed 90/361
# Processed 100/361
# Processed 110/361
# Processed 120/361
# Processed 130/361
# Processed 140/361
# Processed 150/361
# Processed 160/361
# Processed 170/361
# Processed 180/361
# Processed 190/361
# Processed 200/361
# Processed 210/361
# Process ForkPoolWorker-169:
# Process ForkPoolWorker-172:
# Process ForkPoolWorker-168:
# Process ForkPoolWorker-183:
# Process ForkPoolWorker-152:
# Process ForkPoolWorker-173:
# Process ForkPoolWorker-155:
# Process ForkPoolWorker-171:
# Process ForkPoolWorker-158:
# Process ForkPoolWorker-184:
# Process ForkPoolWorker-181:
# Process ForkPoolWorker-148:
# Process ForkPoolWorker-146:
# Process ForkPoolWorker-153:
# Process ForkPoolWorker-139:
# Process ForkPoolWorker-147:
# Process ForkPoolWorker-162:
# Process ForkPoolWorker-175:
# Process ForkPoolWorker-136:
# Process ForkPoolWorker-160:
# Process ForkPoolWorker-179:
# Process ForkPoolWorker-182:
# Process ForkPoolWorker-174:
# Process ForkPoolWorker-176:
# Process ForkPoolWorker-138:
# Process ForkPoolWorker-135:
# Process ForkPoolWorker-177:
# Process ForkPoolWorker-129:
# Process ForkPoolWorker-178:
# Process ForkPoolWorker-131:
# Process ForkPoolWorker-166:
# Process ForkPoolWorker-130:
# Process ForkPoolWorker-157:
# Process ForkPoolWorker-151:
# Process ForkPoolWorker-154:
# Process ForkPoolWorker-134:
# Process ForkPoolWorker-170:
# Process ForkPoolWorker-144:
# Process ForkPoolWorker-180:
# Process ForkPoolWorker-140:
# Process ForkPoolWorker-167:
# Process ForkPoolWorker-159:
# Process ForkPoolWorker-156:
# Process ForkPoolWorker-142:
# Process ForkPoolWorker-165:
# Process ForkPoolWorker-133:
# Process ForkPoolWorker-141:
# Process ForkPoolWorker-145:
# Process ForkPoolWorker-161:
# Process ForkPoolWorker-132:
# Process ForkPoolWorker-143:
# Process ForkPoolWorker-163:
# Process ForkPoolWorker-164:
# Process ForkPoolWorker-137:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     res = self._reader.recv_bytes()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# Process ForkPoolWorker-150:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# KeyboardInterrupt
# KeyboardInterrupt
# Process ForkPoolWorker-149:
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
# KeyboardInterrupt
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_4155837/2378464982.py", line 142, in process_item
#     structure_score, teds_score = teds_structure(gt, pred)
#   File "/tmp/ipykernel_4155837/2378464982.py", line 121, in teds_structure
#     teds_score = all_teds(gt_html, pred_html)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/site-packages/table_recognition_metric/main.py", line 63, in __call__
#     ).compute_edit_distance()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/site-packages/apted/apted.py", line 106, in compute_edit_distance
#     self.result = self.gted()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/site-packages/apted/apted.py", line 381, in gted
#     return self.sub_gted(data, it2, it1, tree2, path_id, node_id, True)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/site-packages/apted/apted.py", line 395, in sub_gted
#     self.gted(data)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/site-packages/apted/apted.py", line 381, in gted
#     return self.sub_gted(data, it2, it1, tree2, path_id, node_id, True)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/site-packages/apted/apted.py", line 404, in sub_gted
#     return self.spf(
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/site-packages/apted/single_path_functions.py", line 669, in __call__
#     result = {
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/site-packages/apted/single_path_functions.py", line 216, in spf_l
#     return self.spf_generic_side()
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/site-packages/apted/single_path_functions.py", line 262, in spf_generic_side
#     tree_edit_dist(current1, keyroots[i], forestdist)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/site-packages/apted/single_path_functions.py", line 331, in tree_edit_dist
#     u = rename(info1_node, info2_node)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/site-packages/apted/single_path_functions.py", line 133, in <lambda>
#     self.rename = lambda x, y: apted.config.rename(y, x)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/site-packages/table_recognition_metric/main.py", line 159, in rename
#     return self.normalized_distance(node1.content, node2.content)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/site-packages/table_recognition_metric/main.py", line 146, in normalized_distance
#     return float(distance(*sequences)) / self.maximum(*sequences)
#   File "/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/site-packages/Levenshtein/__init__.py", line 123, in distance
#     return _Levenshtein.distance(
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py:856, in IMapIterator.next(self, timeout)
#     855 try:
# --> 856     item = self._items.popleft()
#     857 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 218
#     215         f.write(f"Average (All): {teds_stats[0]:.4f}\nAverage (Non-zero): {teds_stats[1]:.4f}\n")
#     217 # Example usage
# --> 218 process_file("/home/lingjun/code/InternVL/internvl_chat/html_table_latex_results/output.jsonl")  # Replace with your file path
#
# Cell In[3], line 187, in process_file(input_path)
#     184 task_args = [(i+1, item) for i, item in enumerate(data)]
#     186 processed = 0
# --> 187 for qid, structure_score, teds_score in pool.imap(process_item, task_args):
#     188     if qid is not None:
#     189         structure_results[qid] = structure_score
#
# File ~/miniconda3/envs/vlm-r1/lib/python3.10/multiprocessing/pool.py:861, in IMapIterator.next(self, timeout)
#     859     self._pool = None
#     860     raise StopIteration from None
# --> 861 self._cond.wait(timeout)
#     862 try:
#     863     item = self._items.popleft()
#
# File ~/miniconda3/envs/vlm-r1/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
import os
import subprocess
import json
from pdf2image import convert_from_path
from PIL import Image
from multiprocessing import Pool, cpu_count
import uuid
import concurrent.futures
import numpy as np

# 全局路径变量
table_dir = ""
output_pdf_dir = ""
output_png_dir = ""
extracted_tables_dir = ""
base_dir = ""

# 增强的LaTeX模板
latex_preamble = r"""
\documentclass[standalone]{article}
\usepackage[utf8]{inputenc}
\usepackage[T1]{fontenc}
\usepackage{textcomp}
\usepackage{amsmath, amsthm, amssymb, graphicx, geometry, array}
\usepackage{booktabs, multirow, tabularx, multicol, bm}
\pagenumbering{gobble}
\begin{document}
\begin{table}[htp]
\centering
\resizebox*{0.5\columnwidth}{!}{
"""
latex_end = r"}\end{table}\end{document}"

def render_tex_to_pdf(tex_path, output_pdf_path, timeout=30):
    """增强的LaTeX渲染函数"""
    with open(tex_path, "r") as file:
        tex_content = file.read()
    
    full_tex = latex_preamble + tex_content + latex_end
    
    temp_id = uuid.uuid4().hex
    temp_tex = os.path.join(os.path.dirname(output_pdf_path), f"temp_{temp_id}.tex")
    
    with open(temp_tex, "w") as f:
        f.write(full_tex)
    
    try:
        result = subprocess.run(
            ["pdflatex", "-interaction=nonstopmode", 
             "-output-directory", os.path.dirname(output_pdf_path), temp_tex],
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            timeout=timeout,
            encoding='latin-1'
        )
        
        # 处理输出文件
        temp_pdf = temp_tex.replace(".tex", ".pdf")
        if os.path.exists(temp_pdf):
            os.rename(temp_pdf, output_pdf_path)
            print(f"✓ Rendered {os.path.basename(tex_path)}")
        else:
            print(f"× Failed {os.path.basename(tex_path)}\nLog: {result.stdout[:500]}")
            
    except subprocess.TimeoutExpired:
        print(f"⌛ Timeout {os.path.basename(tex_path)}")
    finally:
        # 清理临时文件
        for ext in [".aux", ".log", ".out", ".tex"]:
            temp_file = temp_tex.replace(".tex", ext)
            if os.path.exists(temp_file):
                try:
                    os.remove(temp_file)
                except:
                    pass

def convert_pdf_to_png(pdf_path, png_path, dpi=300):
    """增强的PDF转PNG函数"""
    try:
        images = convert_from_path(pdf_path, dpi=dpi)
        if images:
            images[0].save(png_path, "PNG", optimize=True, quality=95)
            print(f"✓ Converted {os.path.basename(pdf_path)}")
        else:
            print(f"× Empty PDF {os.path.basename(pdf_path)}")
    except Exception as e:
        print(f"× Conversion failed {os.path.basename(pdf_path)}: {str(e)}")

def process_entry(entry):
    """处理单个JSON条目"""
    try:
        qid = entry["id"]
        print(f"\n▶ Processing {qid}")
        
        # 生成LaTeX文件
        for field in ["gt", "latte_2"]:
            content = entry[field]
            base_name = f"{qid}_{field}"
            
            # 生成LaTeX文件
            tex_path = os.path.join(table_dir, f"{base_name}.tex")
            with open(tex_path, "w") as f:
                f.write(content)
            
            # 生成PDF
            pdf_path = os.path.join(output_pdf_dir, f"{base_name}.pdf")
            render_tex_to_pdf(tex_path, pdf_path)
            
            # 转换为PNG
            if os.path.exists(pdf_path):
                png_path = os.path.join(output_png_dir, f"{base_name}.png")
                convert_pdf_to_png(pdf_path, png_path)
                
        return True
    except Exception as e:
        print(f"⊗ Failed {entry.get('id', 'unknown')}: {str(e)}")
        return False

def process_json(json_path):
    """处理整个JSON文件"""
    with open(json_path, "r") as f:
        data = json.load(f)
    
    # 转换数据结构
    entries = [{"id": k, "gt": v["gt"], "latte_2": v["latte_2"]} 
               for k, v in data.items()]
    
    # 创建目录
    os.makedirs(table_dir, exist_ok=True)
    os.makedirs(output_pdf_dir, exist_ok=True)
    os.makedirs(output_png_dir, exist_ok=True)
    
    # 并行处理
    workers = max(1, cpu_count()//2)
    with Pool(processes=workers) as pool:
        results = pool.imap_unordered(process_entry, entries)
        
        success = 0
        for i, result in enumerate(results, 1):
            if result:
                success += 1
            print(f"▷ Progress: {i}/{len(entries)} ({success} successes)")
    
    print(f"\n★ Completed: {success}/{len(entries)} succeeded")

# CW-SSIM计算核心
def dwt2_simple(img):
    """简化版二维离散小波变换"""
    h, w = img.shape
    h -= h % 2
    w -= w % 2
    img = img[:h, :w]
    
    blocks = img.reshape(h//2, 2, w//2, 2).transpose(0, 2, 1, 3)
    a = blocks[..., 0, 0]
    b = blocks[..., 0, 1]
    c = blocks[..., 1, 0]
    d = blocks[..., 1, 1]
    
    return (a + b + c + d)/4, (a - c)/2, (a - b)/2, (a - d)/2

def calculate_ssim(patch1, patch2):
    """结构相似性计算"""
    C1, C2 = 6.5025, 58.5225
    
    mu1 = np.mean(patch1)
    mu2 = np.mean(patch2)
    
    sigma1_sq = np.var(patch1)
    sigma2_sq = np.var(patch2)
    sigma12 = np.cov(patch1.ravel(), patch2.ravel())[0,1]
    
    num = (2*mu1*mu2 + C1) * (2*sigma12 + C2)
    den = (mu1**2 + mu2**2 + C1) * (sigma1_sq + sigma2_sq + C2)
    
    return np.clip(num / den, 0.0, 1.0)



# def calculate_cwssim(img1_path, img2_path):
#     """完整的CW-SSIM计算"""
#     try:
#         # 图像预处理
#         img1 = Image.open(img1_path).convert('L')
#         img2 = Image.open(img2_path).convert('L').resize(img1.size)
        
#         arr1 = np.array(img1, dtype=np.float32)
#         arr2 = np.array(img2, dtype=np.float32)
        
#         # 小波分解
#         cA1, cH1, cV1, cD1 = dwt2_simple(arr1)
#         cA2, cH2, cV2, cD2 = dwt2_simple(arr2)
        
#         # 多尺度SSIM计算
#         ssims = [
#             calculate_ssim(cA1, cA2),
#             calculate_ssim(cH1, cH2),
#             calculate_ssim(cV1, cV2),
#             calculate_ssim(cD1, cD2)
#         ]
        
#         return np.mean(ssims)
#     except Exception as e:
#         print(f"⚠ Error computing CW-SSIM: {str(e)}")
#         return 0.0

import numpy as np
from pyrtools.pyramids import SCFpyr
from scipy.signal import convolve2d
import warnings

def cwssim_index(img1, img2):
    level=4
    ori=8
    guardb=0
    K=0.01
    # 确保图像是二维灰度图，转换为float类型
    if img1.ndim > 2:
        img1 = img1.mean(axis=2)
    if img2.ndim > 2:
        img2 = img2.mean(axis=2)
    img1 = img1.astype(np.float64)
    img2 = img2.astype(np.float64)
    
    # 构建复数可控金字塔
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")  # 忽略可能的警告
        pyr1 = SCFpyr(img1, height=level, nbands=ori)
        pyr2 = SCFpyr(img2, height=level, nbands=ori)
    
    winsize = 7
    window = np.ones((winsize, winsize)) / (winsize ** 2)
    
    # 计算边界裁剪量
    gb = guardb // (2 ** (level - 1))
    
    # 获取最高层级的子带尺寸以生成高斯权重
    band_key = (level-1, 0)  # 假设使用第一个方向子带
    band_coeff = pyr1.pyr_coeffs.get(band_key, None)
    if band_coeff is None:
        raise ValueError("无法获取指定层级的子带。")
    s = band_coeff.shape
    s_cropped = (s[0] - 2*gb, s[1] - 2*gb)
    size = (s_cropped[0] - winsize + 1, s_cropped[1] - winsize + 1)
    
    # 生成高斯权重矩阵
    sigma = size[0] / 4.0
    x = np.linspace(-(size[1]-1)/2, (size[1]-1)/2, size[1])
    y = np.linspace(-(size[0]-1)/2, (size[0]-1)/2, size[0])
    X, Y = np.meshgrid(x, y)
    w = np.exp(-(X**2 + Y**2) / (2 * sigma**2))
    w /= w.sum()
    
    band_cssim = np.zeros(ori)
    
    for i in range(ori):
        band_key = (level-1, i)
        band1 = pyr1.pyr_coeffs.get(band_key, None)
        band2 = pyr2.pyr_coeffs.get(band_key, None)
        if band1 is None or band2 is None:
            raise ValueError(f"方向子带 {i} 不存在于金字塔中。")
        
        # 裁剪边界
        band1 = band1[gb:-gb, gb:-gb]
        band2 = band2[gb:-gb, gb:-gb]
        
        # 计算相关系数和方差
        corr = band1 * np.conj(band2)
        varr = np.abs(band1)**2 + np.abs(band2)**2
        
        # 滑动窗口平均
        corr_band = convolve2d(corr, window, mode='valid')
        varr_band = convolve2d(varr, window, mode='valid')
        
        # 计算CSSIM映射
        cssim_map = (2 * np.abs(corr_band) + K) / (varr_band + K + 1e-8)  # 避免除零
        
        # 确保尺寸匹配
        if cssim_map.shape != w.shape:
            raise ValueError("CSSIM映射与权重矩阵尺寸不匹配。")
        
        band_cssim[i] = np.sum(cssim_map * w)
    
    cwssim = np.mean(band_cssim)
    return cwssim


def compare_images(output_dir, result_path):
    """批量图像对比"""
    # 构建文件映射
    file_pairs = {}
    for f in os.listdir(output_dir):
        if f.endswith('_gt.png'):
            qid = f[:-7]
            gt_path = os.path.join(output_dir, f)
            latte_path = os.path.join(output_dir, f"{qid}_latte_2.png")
            
            # 只有当两个文件都存在时才添加
            if os.path.exists(gt_path) and os.path.exists(latte_path):
                file_pairs[qid] = {
                    'gt': gt_path,
                    'latte_2': latte_path
                }
    
    # 准备任务
    tasks = [(qid, pd['latte_2'], pd['gt']) 
            for qid, pd in file_pairs.items() 
            if os.path.exists(pd['latte_2'])]
    
    print(f"Found {len(tasks)} valid pairs for comparison")
    
    # 并行计算
    results = []
    with concurrent.futures.ProcessPoolExecutor(max_workers=8) as executor:
        futures = {executor.submit(calculate_cwssim, p1, p2): qid 
                  for qid, p1, p2 in tasks}
        
        for future in concurrent.futures.as_completed(futures):
            qid = futures[future]
            try:
                score = future.result()
                results.append((qid, score))
                print(f"✓ {qid}: {score:.4f}")
            except Exception as e:
                print(f"⊗ {qid}: {str(e)}")
                results.append((qid, 0.0))
    
    # 保存结果
    with open(result_path, "w") as f:
        for qid, score in sorted(results, key=lambda x: x[0]):
            f.write(f"{qid}: {score:.4f}\n")
    
    print(f"Results saved to {result_path}")

# 主流程

# 配置路径
json_file = "/home/lingjun/code/InternVL/internvl_chat/results_latte/Latte_2.json"  # 修改为实际路径
base_dir = os.path.dirname(json_file)

extracted_tables_dir = os.path.join(base_dir, "extracted_tables")
table_dir = os.path.join(extracted_tables_dir, "latex")
output_pdf_dir = os.path.join(extracted_tables_dir, "pdf")
output_png_dir = os.path.join(extracted_tables_dir, "png")
result_path = os.path.join(base_dir, "cwssim_results_test.txt")

# 执行处理流程
# process_json(json_file)
compare_images(output_png_dir, result_path)

# 计算统计结果
scores = []
with open(result_path, "r") as f:
    for line in f:
        if ":" in line:
            score = float(line.split(":")[1].strip())
            scores.append(score)

if scores:
    avg = sum(scores) / len(scores)
    non_zero = len([s for s in scores if s > 0.01])
    sum_non_zero = sum(s for s in scores if s > 0.01)
    avg_non_zero = sum_non_zero / non_zero if non_zero > 0 else 0
    print(f"\n★ Final Results ★\n"
            f"Average CW-SSIM: {avg:.4f}\n"
            f"Average CW-SSIM (non-zero): {avg_non_zero:.4f}\n"
            f"Non-zero rate: {non_zero}/{len(scores)} ({non_zero/len(scores):.1%})")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 208
#     180 # def calculate_cwssim(img1_path, img2_path):
#     181 #     """完整的CW-SSIM计算"""
#     182 #     try:
#    (...)
#     204 #         print(f"⚠ Error computing CW-SSIM: {str(e)}")
#     205 #         return 0.0
#     207 import numpy as np
# --> 208 from pyrtools.pyramids import SCFpyr
#     209 from scipy.signal import convolve2d
#     210 import warnings
#
# ImportError: cannot import name 'SCFpyr' from 'pyrtools.pyramids' (/home/lingjun/miniconda3/envs/vlm-r1/lib/python3.10/site-packages/pyrtools/pyramids/__init__.py)

# %%
###########Teds_structure_evaluation###########
import re
from table_recognition_metric import TEDS
import multiprocessing
import json

def remove_grid_lines(latex_table):
    cleaned_table = re.sub(r'\\cmidrule{\s*}|\\cdashline\{[0-9]+(-[0-9]+)?\}\s*|\\cmidrule$(?:lr|r|l)?$\{[0-9]+\-[0-9]+\}\s*|\\arrayrulecolor{.*?}\s*|\\caption{.*?}\s*|\\centering\s*|\\hline\s*|\\cline{.*?}\s*|\\toprule\s*|\\midrule\s*|\\bottomrule\s*', '', latex_table)
    cleaned_table = re.sub(r'\\tabularnewline', r'\\\\', cleaned_table)
    cleaned_table = re.sub(r'\n\s*\n', '\n', cleaned_table)
    return cleaned_table.strip(' \n')

def fix_multi(cell):
    multirow_pattern = r'\\multirow{(\d+)}{.*?}{(.*?)}'
    multicol_pattern = r'\\multicolumn{(\d+)}{.*?}{(.*?)}'
    
    match = re.search(multirow_pattern, cell['content'])
    if match:
        cell['rowspan'] = int(match.group(1))
        cell['content'] = cell['content'].replace(match.group(0), match.group(2).strip(), 1).strip()

    match = re.search(multicol_pattern, cell['content'])
    if match:
        cell['colspan'] = int(match.group(1))
        cell['content'] = cell['content'].replace(match.group(0), match.group(2).strip(), 1).strip()
    return cell    

def grid2html(grid):
    def to_td(grid, r, c):
        if grid[r][c] in ['<<', '^^', '..']:
            return ''
        td = {'text': grid[r][c], 'rowspan':1, 'colspan': 1}
        for i in range(r + 1, len(grid)):
            if grid[i][c] == '^^':
                td['rowspan'] += 1
            else:
                break   
        for j in range(c + 1, len(grid[r])):
            if grid[r][j] == '<<':
                td['colspan'] += 1
            else:
                break
        return f'<td rowspan={td["rowspan"]} colspan={td["colspan"]}> {td["text"]} </td>'.replace('rowspan=1', '').replace('colspan=1', '')
        
    html = []
    for r in range(len(grid)):
        row = []
        for c in range(len(grid[0])):
            row.append(to_td(grid, r, c))
        html.append(f'<tr> {"".join(row)} </tr>')
    return '<html><body><table>' + '\n'.join(html) + '</table></body></html>'

def qylatex_to_grid(latex):
    if not re.search(r'\\end{tabular[x]*\*?\}', latex):
        return
    pattern = r'\\begin\{tabular[x]*\*?\}.*?\\end\{tabular[x]*\*?\}'
    matches = re.findall(pattern, latex, re.DOTALL)
    if not matches:
        return
    content = remove_grid_lines(matches[0])
    rows = content.strip(' \n').split(r'\\')
    processed_rows = []
    for row in rows:
        if not row.strip():
            continue
        columns = re.split(r'(?<!\\)&', row)
        columns = [fix_multi({'content': c.strip(' \n'), 'rowspan': 1, 'colspan': 1}) for c in columns]
        processed_rows.append(columns)
    max_cols = max([sum([it['colspan'] for it in r]) for r in processed_rows]) if processed_rows else 0
    grid = [[None for _ in range(max_cols)] for _ in range(len(processed_rows))]
    r_idx_bias = 0
    for r_idx, row in enumerate(processed_rows):
        r_idx += r_idx_bias
        while r_idx >= len(grid):
            grid.append([None for _ in range(max_cols)])
        c_idx = 0
        current_row_bias = 10000
        for cell in row:
            while c_idx < len(grid[r_idx]) and grid[r_idx][c_idx] is not None:
                c_idx += 1
            if c_idx >= len(grid[r_idx]):
                break
            current_row_bias = min(current_row_bias, cell['rowspan'])
            grid[r_idx][c_idx] = cell['content']
            for r in range(cell['rowspan']):
                for c in range(cell['colspan']):
                    if r == 0 and c == 0:
                        continue
                    target_r = r_idx + r
                    target_c = c_idx + c
                    if target_r >= len(grid):
                        grid.append([None for _ in range(max_cols)])
                    if target_c < len(grid[target_r]):
                        grid[target_r][target_c] = '^^' if r > 0 else ('<<' if c > 0 else '..')
            c_idx += cell['colspan']
        r_idx_bias += current_row_bias - 1
    grid = [[c if c is not None else '' for c in r] for r in grid]
    return grid

def latex2html(latex_str):
    latex_str = re.sub(r'(?<!\\)%.*$', '', latex_str, flags=re.MULTILINE)
    latex_str = re.sub(r'(?<!\\)\\\\$$.*?$$', '', latex_str, flags=re.DOTALL)
    latex_str = latex_str.replace('\n', '').replace('\t', '')
    try:
        grid = qylatex_to_grid(latex_str)
    except IndexError as e:
        print(f"IndexError: {str(e)}")
        return 
    if not grid:
        return
    return grid2html(grid)

def teds_structure(gt, pred):
    gt_html = latex2html(gt)
    pred_html = latex2html(pred)
    if not pred_html:
        return 0, 0
    structure_teds = TEDS(structure_only=True)
    structure_score = structure_teds(gt_html, pred_html)
    all_teds = TEDS()
    teds_score = all_teds(gt_html, pred_html)
    return structure_score, teds_score

def process_item(args):
    idx, item = args
    try:
        if not isinstance(item, dict):
            print(f"Item {idx}: Invalid data type, skipping")
            return (None, None, None)
        # Modified to handle new format
        qid = item['id']
        pred = item['prediction']
        gt = item['reference']
        structure_score, teds_score = teds_structure(gt, pred)
        return (qid, structure_score, teds_score)
    except Exception as e:
        print(f"Error processing item {idx}: {str(e)}")
        return (None, None, None)

def calculate_stats(scores):
    avg_all = sum(scores) / len(scores) if scores else 0
    non_zero_scores = [s for s in scores if s != 0]
    avg_non_zero = sum(non_zero_scores)/len(non_zero_scores) if non_zero_scores else 0
    non_zero_ratio = len(non_zero_scores)/len(scores) if scores else 0
    return avg_all, avg_non_zero, non_zero_ratio

def process_file(input_path):
    output_path = input_path.rsplit('.', 1)[0] + '_eval.txt'
    data = []
    
    if input_path.endswith('.json'):
        try:
            with open(input_path, 'r', encoding='utf-8') as f:
                # Load as dictionary and convert to list format
                data_dict = json.load(f)
                data = [
                    {
                        'id': key,
                        'reference': value['gt'],
                        'prediction': value['latte_2']
                    }
                    for key, value in data_dict.items()
                ]
        except Exception as e:
            print(f"Error reading JSON: {str(e)}")
            return
    
    structure_results = {}
    teds_results = {}
    cpu_num = multiprocessing.cpu_count()//2
    pool = multiprocessing.Pool(processes=cpu_num)
    task_args = [(i+1, item) for i, item in enumerate(data)]
    
    processed = 0
    for qid, structure_score, teds_score in pool.imap(process_item, task_args):
        if qid is not None:
            structure_results[qid] = structure_score
            teds_results[qid] = teds_score
        processed += 1
        if processed % 10 == 0:
            print(f"Processed {processed}/{len(data)}")
    
    pool.close()
    pool.join()
    
    structure_stats = calculate_stats(list(structure_results.values()))
    teds_stats = calculate_stats(list(teds_results.values()))
    
    with open(output_path, 'w', encoding='utf-8') as f:
        f.write("ID:Structure_Score,TEDS_Score\n")
        for qid in sorted(structure_results):
            f.write(f"{qid}:{structure_results[qid]:.4f},{teds_results[qid]:.4f}\n")
        
        f.write("\n=== Structure Score ===\n")
        f.write(f"Total: {len(data)}\nValid: {len(structure_results)}\n")
        f.write(f"Non-zero: {structure_stats[2]:.2%}\n")
        f.write(f"Average (All): {structure_stats[0]:.4f}\nAverage (Non-zero): {structure_stats[1]:.4f}\n")
        
        f.write("\n=== TEDS Score ===\n")
        f.write(f"Total: {len(data)}\nValid: {len(teds_results)}\n")
        f.write(f"Non-zero: {teds_stats[2]:.2%}\n")
        f.write(f"Average (All): {teds_stats[0]:.4f}\nAverage (Non-zero): {teds_stats[1]:.4f}\n")

# Example usage
process_file("/home/lingjun/code/InternVL/internvl_chat/results_latte/Latte_2.json")  # Replace with your file path
# Out:
# Processed 10/2740
# Processed 20/2740
# Processed 30/2740
# Processed 40/2740
# Processed 50/2740
# Processed 60/2740
# Processed 70/2740
# Processed 80/2740
# Processed 90/2740
# Processed 100/2740
# Processed 110/2740
# Processed 120/2740
# Processed 130/2740
# Processed 140/2740
# Processed 150/2740
# Processed 160/2740
# Processed 170/2740
# Processed 180/2740
# Processed 190/2740
# Processed 200/2740
# Processed 210/2740
# Processed 220/2740
# Processed 230/2740
# Processed 240/2740
# Processed 250/2740
# Processed 260/2740
# Processed 270/2740
# Processed 280/2740
# Processed 290/2740
# Processed 300/2740
# Processed 310/2740
# Processed 320/2740
# Processed 330/2740
# Processed 340/2740
# Processed 350/2740
# Processed 360/2740
# Processed 370/2740
# Processed 380/2740
# Processed 390/2740
# Processed 400/2740
# Processed 410/2740
# Processed 420/2740
# Processed 430/2740
# Processed 440/2740
# Processed 450/2740
# Processed 460/2740
# Processed 470/2740
# Processed 480/2740
# Processed 490/2740
# Processed 500/2740
# Processed 510/2740
# Processed 520/2740
# Processed 530/2740
# Processed 540/2740
# Processed 550/2740
# Processed 560/2740
# Processed 570/2740
# Processed 580/2740
# Processed 590/2740
# Processed 600/2740
# Processed 610/2740
# Processed 620/2740
# Processed 630/2740
# Processed 640/2740
# Processed 650/2740
# Processed 660/2740
# Processed 670/2740
# Processed 680/2740
# Processed 690/2740
# Processed 700/2740
# Processed 710/2740
# Processed 720/2740
# Processed 730/2740
# Processed 740/2740
# Processed 750/2740
# Processed 760/2740
# Processed 770/2740
# Processed 780/2740
# Processed 790/2740
# Processed 800/2740
# Processed 810/2740
# Processed 820/2740
# Processed 830/2740
# Processed 840/2740
# Processed 850/2740
# Processed 860/2740
# Processed 870/2740
# Processed 880/2740
# Processed 890/2740
# Processed 900/2740
# Processed 910/2740
# Processed 920/2740
# Processed 930/2740
# Processed 940/2740
# Processed 950/2740
# Processed 960/2740
# Processed 970/2740
# Processed 980/2740
# Processed 990/2740
# Processed 1000/2740
# Processed 1010/2740
# Processed 1020/2740
# Processed 1030/2740
# Processed 1040/2740
# Processed 1050/2740
# Processed 1060/2740
# Processed 1070/2740
# Processed 1080/2740
# Processed 1090/2740
# Processed 1100/2740
# Processed 1110/2740
# Processed 1120/2740
# Processed 1130/2740
# Processed 1140/2740
# Processed 1150/2740
# Processed 1160/2740
# Processed 1170/2740
# Processed 1180/2740
# Processed 1190/2740
# Processed 1200/2740
# Processed 1210/2740
# Processed 1220/2740
# Processed 1230/2740
# Processed 1240/2740
# Processed 1250/2740
# Processed 1260/2740
# Processed 1270/2740
# Processed 1280/2740
# Processed 1290/2740
# Processed 1300/2740
# Processed 1310/2740
# Processed 1320/2740
# Processed 1330/2740
# Processed 1340/2740
# Processed 1350/2740
# Processed 1360/2740
# Processed 1370/2740
# Processed 1380/2740
# Processed 1390/2740
# Processed 1400/2740
# Processed 1410/2740
# Processed 1420/2740
# Processed 1430/2740
# Processed 1440/2740
# Processed 1450/2740
# Processed 1460/2740
# Processed 1470/2740
# Processed 1480/2740
# Processed 1490/2740
# Processed 1500/2740
# Processed 1510/2740
# Processed 1520/2740
# Processed 1530/2740
# Processed 1540/2740
# Processed 1550/2740
# Processed 1560/2740
# Processed 1570/2740
# Processed 1580/2740
# Processed 1590/2740
# Processed 1600/2740
# Processed 1610/2740
# Processed 1620/2740
# Processed 1630/2740
# Processed 1640/2740
# Processed 1650/2740
# Processed 1660/2740
# Processed 1670/2740
# Processed 1680/2740
# Processed 1690/2740
# Processed 1700/2740
# Processed 1710/2740
# Processed 1720/2740
# Processed 1730/2740
# Processed 1740/2740
# Processed 1750/2740
# Processed 1760/2740
# Processed 1770/2740
# Processed 1780/2740
# Processed 1790/2740
# Processed 1800/2740
# Processed 1810/2740
# Processed 1820/2740
# Processed 1830/2740
# Processed 1840/2740
# Processed 1850/2740
# Processed 1860/2740
# Processed 1870/2740
# Processed 1880/2740
# Processed 1890/2740
# Processed 1900/2740
# Processed 1910/2740
# Processed 1920/2740
# Processed 1930/2740
# Processed 1940/2740
# Processed 1950/2740
# Processed 1960/2740
# Processed 1970/2740
# Processed 1980/2740
# Processed 1990/2740
# Processed 2000/2740
# Processed 2010/2740
# Processed 2020/2740
# Processed 2030/2740
# Processed 2040/2740
# Processed 2050/2740
# Processed 2060/2740
# Processed 2070/2740
# Processed 2080/2740
# Processed 2090/2740
# Processed 2100/2740
# Processed 2110/2740
# Processed 2120/2740
# Processed 2130/2740
# Processed 2140/2740
# Processed 2150/2740
# Processed 2160/2740
# Processed 2170/2740
# Processed 2180/2740
# Processed 2190/2740
# Processed 2200/2740
# Processed 2210/2740
# Processed 2220/2740
# Processed 2230/2740
# Processed 2240/2740
# Processed 2250/2740
# Processed 2260/2740
# Processed 2270/2740
# Processed 2280/2740
# Processed 2290/2740
# Processed 2300/2740
# Processed 2310/2740
# Processed 2320/2740
# Processed 2330/2740
# Processed 2340/2740
# Processed 2350/2740
# Processed 2360/2740
# Processed 2370/2740
# Processed 2380/2740
# Processed 2390/2740
# Processed 2400/2740
# Processed 2410/2740
# Processed 2420/2740
# Processed 2430/2740
# Processed 2440/2740
# Processed 2450/2740
# Processed 2460/2740
# Processed 2470/2740
# Processed 2480/2740
# Processed 2490/2740
# Processed 2500/2740
# Processed 2510/2740
# Processed 2520/2740
# Processed 2530/2740
# Processed 2540/2740
# Processed 2550/2740
# Processed 2560/2740
# Processed 2570/2740
# Processed 2580/2740
# Processed 2590/2740
# Processed 2600/2740
# Processed 2610/2740
# Processed 2620/2740
# Processed 2630/2740
# Processed 2640/2740
# Processed 2650/2740
# Processed 2660/2740
# Processed 2670/2740
# Processed 2680/2740
# Processed 2690/2740
# Processed 2700/2740
# Processed 2710/2740
# Processed 2720/2740
# Processed 2730/2740
# Processed 2740/2740

# %%
import os
import subprocess
import json
from pdf2image import convert_from_path
from PIL import Image
from multiprocessing import Pool
import uuid
from skimage.metrics import structural_similarity as cw_ssim
import re

def get_sort_key(prefix):
    """从前缀中提取数字部分用于排序"""
    digits = re.sub(r'\D', '', prefix)
    return int(digits) if digits else 0
# 全局路径变量，将在主程序中初始化
table_dir = ""
output_pdf_dir = ""
output_png_dir = ""
extracted_tables_dir = ""
base_dir = ""

# Updated LaTeX preamble with UTF-8 support
latex_preamble = r"""
\documentclass[standalone]{article}
\usepackage[utf8]{inputenc}
\usepackage[T1]{fontenc}
\usepackage{amsmath, amsthm, amssymb, graphicx, geometry, array}
\usepackage{booktabs, multirow,natbib,tabularx, multicol, bm}
\pagenumbering{gobble}
\begin{document}
\begin{table}[htp]
\centering
\resizebox*{0.5\columnwidth}{!}{ 
"""
latex_end = r"}\end{table}\end{document}"

def render_tex_to_pdf(tex_path, output_pdf_path, timeout=20):
    """Render a LaTeX file to PDF with unique temporary files for parallel processing"""
    with open(tex_path, "r") as file:
        tex_content = file.read()
    
    full_tex_content = latex_preamble + tex_content + latex_end
    
    # Generate unique temporary filename using UUID
    temp_tex_filename = f"temp_{uuid.uuid4().hex}.tex"
    temp_tex_path = os.path.join(os.path.dirname(output_pdf_path), temp_tex_filename)
    
    with open(temp_tex_path, "w") as temp_file:
        temp_file.write(full_tex_content)
    
    try:
        result = subprocess.run(
            ["pdflatex", "-interaction=nonstopmode", "-output-directory", os.path.dirname(output_pdf_path), temp_tex_path],
            check=False,
            capture_output=True,
            text=True,
            encoding='latin-1',
            timeout=timeout
        )
        
        # Get the actual output PDF path from LaTeX compilation
        temp_pdf_path = temp_tex_path.replace(".tex", ".pdf")
        
        if os.path.exists(temp_pdf_path):
            os.rename(temp_pdf_path, output_pdf_path)
            print(f"Successfully rendered {tex_path} to PDF at {output_pdf_path}.")
        else:
            print(f"Error: PDF not generated for {tex_path}. LaTeX output:\n{result.stdout}")
    except subprocess.TimeoutExpired:
        print(f"Timeout expired while rendering {tex_path}. Skipping this file.")
    except Exception as e:
        print(f"Unexpected error rendering {tex_path}: {str(e)}")
    finally:
        # Cleanup temporary files
        for ext in [".aux", ".log", ".out", ".tex"]:
            file_path = temp_tex_path.replace(".tex", ext)
            if os.path.exists(file_path):
                try:
                    os.remove(file_path)
                except Exception as e:
                    print(f"Warning: Could not delete temporary file {file_path}: {str(e)}")

def convert_pdf_to_png(pdf_path, png_path, dpi=300):
    """Convert PDF to PNG with error handling"""
    try:
        images = convert_from_path(pdf_path, dpi=dpi)
        if images:
            images[0].save(png_path, "PNG")
            print(f"Converted {pdf_path} to {png_path}")
        else:
            print(f"Error: No pages found in {pdf_path}")
    except Exception as e:
        print(f"Error converting {pdf_path} to PNG: {str(e)}")

def process_entry(entry):
    """Process a single JSON entry with full error handling"""
    try:
        question_id = entry["id"]
        print(f"Processing {question_id}...")
        
        # Create output filenames
        base_files = {
            "prediction": (entry["prediction"], f"{question_id}_prediction"),
            "reference": (entry["reference"], f"{question_id}_reference")
        }
        
        for content_type, (content, base_name) in base_files.items():
            # Generate LaTeX file
            tex_path = os.path.join(table_dir, f"{base_name}.tex")
            with open(tex_path, "w") as f:
                f.write(content)
            
            # Generate PDF
            pdf_path = os.path.join(output_pdf_dir, f"{base_name}.pdf")
            render_tex_to_pdf(tex_path, pdf_path)
            
            # Convert to PNG
            if os.path.exists(pdf_path):
                png_path = os.path.join(output_png_dir, f"{base_name}.png")
                convert_pdf_to_png(pdf_path, png_path)
            else:
                print(f"Skipping PNG conversion for {base_name} - PDF not found")
        
        print(f"Completed processing {question_id}")
        return True
    except Exception as e:
        print(f"Error processing {entry.get('questionId', 'unknown')}: {str(e)}")
        return False

def process_json(json_file):
    """Main processing function with parallel execution"""
    with open(json_file, "r") as file:
        data = json.load(file)
    
    # Create necessary directories
    os.makedirs(table_dir, exist_ok=True)
    os.makedirs(output_pdf_dir, exist_ok=True)
    os.makedirs(output_png_dir, exist_ok=True)
    
    # Use half of available CPUs for resource balancing
    num_workers = max(1, os.cpu_count() // 2)
    
    with Pool(processes=num_workers) as pool:
        results = pool.imap_unordered(process_entry, data)
        
        # Monitor progress
        success_count = 0
        for i, result in enumerate(results, 1):
            if result:
                success_count += 1
            print(f"Processed {i}/{len(data)} entries ({success_count} successes)")
    
    print(f"\nProcessing complete. Success rate: {success_count}/{len(data)}")

import concurrent
import numpy as np

def dwt2_simple(img_array):
    """Performs a simple 2D discrete wavelet transform with even-size check"""
    rows, cols = img_array.shape
    rows = rows - rows % 2
    cols = cols - cols % 2
    img_array = img_array[:rows, :cols]
    
    blocks = img_array.reshape(rows//2, 2, cols//2, 2).transpose(0, 2, 1, 3)
    a = blocks[..., 0, 0]
    b = blocks[..., 0, 1]
    c = blocks[..., 1, 0]
    d = blocks[..., 1, 1]
    
    cA = (a + b + c + d) * 0.25
    cH = (a - c) * 0.5
    cV = (a - b) * 0.5
    cD = (a - d) * 0.5
    return cA, cH, cV, cD

def calculate_ssim(img1, img2):
    img1_flat = img1.ravel()
    img2_flat = img2.ravel()
    n = img1_flat.size
    
    sum1 = img1_flat.sum()
    sum2 = img2_flat.sum()
    sum12 = (img1_flat * img2_flat).sum()
    sum1_sq = (img1_flat** 2).sum()
    sum2_sq = (img2_flat** 2).sum()
    
    mean1 = sum1 / n
    mean2 = sum2 / n
    var1 = (sum1_sq - sum1**2 / n) / n
    var2 = (sum2_sq - sum2**2 / n) / n
    
    covar = (sum12 - sum1 * sum2 / n) / (n - 1) if n > 1 else 0.0
    
    C1, C2 = 6.5025, 58.5225
    numerator = (2 * mean1 * mean2 + C1) * (2 * covar + C2)
    denominator = (mean1**2 + mean2**2 + C1) * (var1 + var2 + C2)
    return numerator / denominator

def calculate_cwssim(image1_path, image2_path):
    """Compares two images using Complex Wavelet Structural Similarity Index (CW-SSIM)"""
    try:
        image1 = Image.open(image1_path).convert('L')
        image2 = Image.open(image2_path).convert('L')
        
        image1 = image1.resize(image2.size)
        
        img1_array = np.array(image1)
        img2_array = np.array(image2)
        
        cA1, cH1, cV1, cD1 = dwt2_simple(img1_array)
        cA2, cH2, cV2, cD2 = dwt2_simple(img2_array)
        
        ssim_cA = calculate_ssim(cA1, cA2)
        ssim_cH = calculate_ssim(cH1, cH2)
        ssim_cV = calculate_ssim(cV1, cV2)
        ssim_cD = calculate_ssim(cD1, cD2)
        cwssim_score = (ssim_cA + ssim_cH + ssim_cV + ssim_cD) / 4
        
        return cwssim_score
    
    except Exception as e:
        print(f"Error comparing images {image1_path} and {image2_path}: {e}")
        return 0.0

def process_prefix(prefix, output_png_dir, annotation_images, answer_images):
    annotation_image_path = os.path.join(output_png_dir, annotation_images[prefix])
    if prefix in answer_images:
        answer_image_path = os.path.join(output_png_dir, answer_images[prefix])
        cwssim_score = calculate_cwssim(answer_image_path, annotation_image_path)
        return f"{prefix}: {cwssim_score:.4f}\n"
    else:
        return f"{prefix}: 0.0000\n"
    
def calculate_cwssim_wrapper(task):
    """包装函数处理单个对比任务"""
    prefix, answer_path, annotation_path = task
    try:
        if os.path.exists(answer_path) and os.path.exists(annotation_path):
            return prefix, calculate_cwssim(answer_path, annotation_path)
        return prefix, 0.0
    except Exception as e:
        print(f"Error processing {prefix}: {str(e)}")
        return prefix, 0.0
    
def compare_images_and_save_results(output_png_dir, result_file_path, max_workers=None):
    """优化后的图像对比函数，支持显式指定进程数并批量写入结果"""
    image_files = os.listdir(output_png_dir)
    
    # 构建文件映射关系
    answer_map = {f.split('_')[0]: f for f in image_files if 'prediction.png' in f}
    annotation_map = {f.split('_')[0]: f for f in image_files if 'reference.png' in f}

    # 生成有序任务列表
    tasks = []
    # 修改排序方式：按提取的数字排序
    for prefix in sorted(annotation_map.keys(), key=get_sort_key):
        answer_file = answer_map.get(prefix, "")
        task = (
            prefix,
            os.path.join(output_png_dir, answer_file) if answer_file else "",
            os.path.join(output_png_dir, annotation_map[prefix])
        )
        tasks.append(task)

    # 设置默认进程数（CPU核心数75%）
    if max_workers is None:
        max_workers = 16

    # 使用带进度显示的结果收集
    results = []
    with concurrent.futures.ProcessPoolExecutor(max_workers=max_workers) as executor:
        futures = {executor.submit(calculate_cwssim_wrapper, task): task[0] for task in tasks}
        
        # 添加进度显示
        completed = 0
        total = len(tasks)
        print(f"使用 {max_workers} 个进程进行图像对比...")
        
        for future in concurrent.futures.as_completed(futures):
            completed += 1
            prefix = futures[future]
            try:
                _, score = future.result(timeout=60)  # 60秒超时
                results.append((prefix, score))
                # 更新进度显示
                print(f"\r处理进度: {completed}/{total} ({completed/total:.1%})", end="", flush=True)
            except Exception as e:
                print(f"\n处理 {prefix} 时发生错误: {str(e)}")
                results.append((prefix, 0.0))

    # 按原始顺序排序后写入
    with open(result_file_path, "w") as result_file:
        for prefix, score in sorted(results, key=lambda x: get_sort_key(x[0])):
            result_line = f"{prefix}: {score:.4f}\n"
            result_file.write(result_line)
    
    # 空结果检查（新增）
    if len(results) == 0:
        print("严重警告：未生成任何对比结果！")
    else:
        print(f"结果已保存至 {result_file_path} (共 {len(results)} 条记录)")
    

def sort_txt_file(input_file, output_file=None):
    """通用排序函数，路径由调用方提供"""
    try:
        with open(input_file, 'r') as f:
            lines = [line.strip() for line in f if line.strip()]

        def sort_key(line):
            left_num = line.split(':', 1)[0].strip()
            return int(left_num)

        sorted_lines = sorted(lines, key=sort_key)
        output = output_file or input_file.replace('.txt', '_sorted.txt')

        with open(output, 'w') as f:
            f.write('\n'.join(sorted_lines))
        print(f"文件已排序并保存为：{output}")
        return True
    except Exception as e:
        print(f"处理时发生错误：{str(e)}")
        return False

def calculate_average_score(file_path):
    """精确计算所有有效行的平均值"""
    try:
        total = 0.0
        count = 0
        with open(file_path, 'r') as f:
            for line in f:
                line = line.strip()
                # 跳过统计信息分隔行
                if not line or line.startswith('-') or '平均值' in line or '占比' in line:
                    continue
                if ':' in line:
                    # 使用rsplit处理可能包含多个冒号的情况
                    parts = line.rsplit(':', 1)
                    if len(parts) != 2:
                        continue
                    _, score_str = parts
                    try:
                        score = float(score_str.strip())
                        total += score
                        count += 1
                    except ValueError:
                        continue
        return total / count if count > 0 else 0.0
    except Exception as e:
        print(f"计算平均值时发生错误: {str(e)}")
        return 0.0

def calculate_average_and_ratio(file_path):
    """精确计算非零分数平均值和占比"""
    try:
        total_score = 0.0
        valid_count = 0
        non_zero_count = 0
        
        with open(file_path, 'r') as f:
            for line in f:
                line = line.strip()
                # 跳过分隔行和统计信息
                if not line or line.startswith('-') or '平均值' in line or '占比' in line:
                    continue
                if ':' in line:
                    parts = line.rsplit(':', 1)
                    if len(parts) != 2:
                        continue
                    _, score_str = parts
                    try:
                        score = float(score_str.strip())
                        valid_count += 1
                        if score > 1e-6:  # 更精确的浮点比较阈值
                            non_zero_count += 1
                            total_score += score
                    except ValueError:
                        continue

        avg = total_score / non_zero_count if non_zero_count > 0 else 0.0
        ratio = non_zero_count / valid_count if valid_count > 0 else 0.0
        return avg, ratio
    except Exception as e:
        print(f"计算统计值时发生错误: {str(e)}")
        return 0.0, 0.0

# 修改后的结果处理流程
def process_statistics(sorted_result_path):
    """综合统计结果处理"""
    # 计算全局平均值
    global_avg = calculate_average_score(sorted_result_path)
    
    # 计算非零平均值和占比
    non_zero_avg, non_zero_ratio = calculate_average_and_ratio(sorted_result_path)
    
    # 生成统计信息
    stats = [
        f"{'-'*50}",
        f"全局平均值（含零）: {global_avg:.4f}",
        f"非零分数平均值: {non_zero_avg:.4f}",
        f"有效对比占比: {non_zero_ratio:.2%}",
        f"统计样本总数: {_get_total_count(sorted_result_path)}"
    ]
    
    # 写入文件
    with open(sorted_result_path, 'a') as f:
        f.write('\n' + '\n'.join(stats))
    
    # 控制台输出
    print('\n'.join(stats))

def _get_total_count(file_path):
    """辅助函数：获取有效对比总数"""
    count = 0
    with open(file_path, 'r') as f:
        for line in f:
            line = line.strip()
            if line and ':' in line and not line.startswith('-') and '平均值' not in line:
                count += 1
    return count
def process_jsonl(json_file):
    """Main processing function with parallel execution"""
    # 读取 JSONL 文件
    data = []
    with open(json_file, "r") as file:
        for line in file:
            if line.strip():  # 跳过空行
                data.append(json.loads(line))
    
    # 创建必要的目录
    os.makedirs(table_dir, exist_ok=True)
    os.makedirs(output_pdf_dir, exist_ok=True)
    os.makedirs(output_png_dir, exist_ok=True)
    
    # 使用半数可用 CPU 进行资源平衡
    num_workers = max(1, os.cpu_count() // 2)
    
    with Pool(processes=num_workers) as pool:
        results = pool.imap_unordered(process_entry, data)
        
        # 监控进度
        success_count = 0
        for i, result in enumerate(results, 1):
            if result:
                success_count += 1
            print(f"Processed {i}/{len(data)} entries ({success_count} successes)")
    
    print(f"\nProcessing complete. Success rate: {success_count}/{len(data)}")
# 用户只需修改这个JSON文件路径
json_file = "/home/lingjun/code/InternVL/internvl_chat/test_2/output.jsonl"  # 修改此处为你的JSON文件路径

# 动态生成所有路径
base_dir = os.path.dirname(json_file)
extracted_tables_dir = os.path.join(base_dir, "extracted_tables")
table_dir = os.path.join(extracted_tables_dir, "latex_tables")
output_pdf_dir = os.path.join(extracted_tables_dir, "pdf_tables_full")
output_png_dir = os.path.join(extracted_tables_dir, "png_tables_full")
result_file_path = os.path.join(base_dir, "ssim_comparison_results.txt")
sorted_result_path = os.path.join(base_dir, "ssim_comparison_results_sorted.txt")

# 执行处理流程
process_jsonl(json_file)
print("Rendering and conversion complete!")

compare_images_and_save_results(output_png_dir, result_file_path)
process_statistics(result_file_path)
print("Image comparison complete!")

# 计算统计结果
if average_score := calculate_average_score(sorted_result_path):
    avg_message = f"平均值: {average_score:.4f}"
    print(avg_message)
    
avg, ratio = calculate_average_and_ratio(sorted_result_path)
if avg is not None and ratio is not None:
    stats_message = f"非零分数平均值: {avg:.4f}\n非零分数占比: {ratio:.2%}"
    print(stats_message)
    
    # 将统计结果写入文件末尾
    with open(sorted_result_path, 'a') as f:
        f.write('\n' + '-' * 50 + '\n')  # 添加分隔线
        f.write(avg_message + '\n')
        f.write(stats_message + '\n')
# Out:
# Processing AI-11184...Processing AI-10162...Processing AI-10792...Processing AI-11194...Processing AI-10650...Processing AI-11277...Processing AI-10070...Processing AI-11152...Processing AI-11128...Processing AI-10956...Processing AI-11027...Processing AI-10944...Processing AI-10717...Processing AI-11493...
#
# Processing AI-10884...
#
# Processing AI-1092...Processing AI-10328...Processing AI-11419...
#
#
#
#
# Processing AI-10282...Processing AI-1046...Processing AI-10469...Processing AI-10177...
#
# Processing AI-10865...Processing AI-10490...Processing AI-10799...Processing AI-10157...
#
# Processing AI-10858...
# Error processing unknown: 'prediction'Processing AI-1159...Processing AI-11689...Error processing unknown: 'prediction'Processing AI-10357...
# Processing AI-12210...Processing AI-11148...Processing AI-10040...Processing AI-12293...Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Processing AI-12288...Processing AI-11744...Processing AI-11869...Processing AI-11754...Processing AI-12001...Processing AI-11990...Processing AI-11649...
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-11953...Processing AI-11964...Error processing unknown: 'prediction'
# Processing AI-12306...Processing AI-12017...Error processing unknown: 'prediction'Processing AI-12111...Processing AI-12788...
# Processing AI-12703...Processing AI-12125...
#
# Processing AI-12189...Processing AI-12831...Processing AI-12856...
# Error processing unknown: 'prediction'Processing AI-1216...
# Processing AI-12697...Error processing unknown: 'prediction'
#
#
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'
#
# Error processing unknown: 'prediction'
#
#
#
# Error processing unknown: 'prediction'
#
#
# Error processing unknown: 'prediction'
#
#
#
#
#
#
#
#
#
#
# Error processing unknown: 'prediction'
#
#
#
#
# Error processing unknown: 'prediction'
#
#
#
#
# Error processing unknown: 'prediction'
#
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'
#
# Error processing unknown: 'prediction'
#
# Error processing unknown: 'prediction'
#
#
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'
# Processing AI-11981...Error processing unknown: 'prediction'Error processing unknown: 'prediction'
#
# Processing AI-12241...Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Processing AI-12720...Processing AI-12800...Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-11998...Error processing unknown: 'prediction'
# Processing AI-12164...Error processing unknown: 'prediction'
# Processing AI-12718...Error processing unknown: 'prediction'Processing AI-12712...Error processing unknown: 'prediction'Processing AI-12861...Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'
# Processing AI-1288...Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'
# Processing AI-12899...
# Processing AI-12896...
# Processing AI-12892...
#
#
# Processing AI-13822...Processing AI-13037...
#
#
#
#
#
#
# Processing AI-13561...
#
#
#
#
#
#
#
#
#
#
# Processing AI-1336...
#
# Processing AI-13460...
#
#
#
#
# Processing AI-13400...
#
#
#
#
#
# Processing AI-14112...
#
# Processing AI-13986...
# Processing AI-13825...
# Processing AI-1397...
#
# Error processing unknown: 'prediction'Processing AI-14191...
# Processing AI-14105...Processing AI-13522...
# Processing AI-13401...Processing AI-13725...
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Processing AI-13877...Processing AI-14218...Processing AI-13937...Error processing unknown: 'prediction'Processing AI-13669...Error processing unknown: 'prediction'Processing AI-13904...Processing AI-13665...Processing AI-1406...Processing AI-13901...Processing AI-14331...Processing AI-13925...
# Error processing unknown: 'prediction'Processing AI-1451...Processing AI-14370...Processing AI-13946...Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Processing AI-14687...
# Processing AI-14891...Processing AI-14710...Processing AI-15097...Processing AI-14932...Processing AI-1504...Processing AI-14893...
# Processing AI-15046...Processing AI-14917...Error processing unknown: 'prediction'Processing AI-15183...
# Processing AI-15243...Processing AI-15275...
# Error processing unknown: 'prediction'
# Processing AI-15123...Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'
# Processing AI-1083...
#
#
# Error processing unknown: 'prediction'
#
# Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'
#
#
#
#
#
#
#
#
#
#
# Error processing unknown: 'prediction'
#
#
#
#
#
# Processing AI-11107...
#
# Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'
#
#
#
#
#
# Error processing unknown: 'prediction'
#
#
# Error processing unknown: 'prediction'
#
# Error processing unknown: 'prediction'
#
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'
#
#
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-15207...Error processing unknown: 'prediction'
#
# Error processing unknown: 'prediction'
# Processing AI-15380...Processing AI-16233...
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-15772...Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Processing AI-15428...Processing AI-15378...Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-16111...Processing AI-15464...
#
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Processing AI-1603...Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Processing AI-16354...Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'
# Processing AI-15675...
# Error processing unknown: 'prediction'Processing AI-15813...
#
#
# Processing AI-15509...
# Processing AI-15256...
# Error processing unknown: 'prediction'
# Processing AI-16345...
# Processing AI-15827...
#
#
#
#
#
#
#
#
#
# Processing AI-16112...
#
#
#
#
#
#
#
# Error processing unknown: 'prediction'Processing AI-15501...
#
#
#
# Processing AI-1638...
#
#
#
#
# Processing AI-16411...
#
# Processing AI-16414...
#
# Processing AI-16420...
# Processing AI-16446...
#
#
# Processing AI-16526...Processing AI-16464...Processing AI-16658...Error processing unknown: 'prediction'
# Processing AI-16675...
# Error processing unknown: 'prediction'
# Processing AI-16473...
#
# Error processing unknown: 'prediction'Processing AI-16716...Processing AI-16842...Processing AI-16876...Error processing unknown: 'prediction'Processing AI-16589...Processing AI-16470...Processing AI-17841...Processing AI-16975...
# Processing AI-17685...Processing AI-17859...Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-1733...Error processing unknown: 'prediction'Processing AI-178...Processing AI-17849...Processing AI-16995...Error processing unknown: 'prediction'
#
# Processing AI-16854...Error processing unknown: 'prediction'Processing AI-17868...
# Processing AI-16824...Processing AI-17586...Processing AI-17035...Processing AI-16942...
# Processing AI-17235...Processing AI-17361...Processing AI-1735...Processing AI-17876...
# Processing AI-1801...
# Error processing unknown: 'prediction'
# Processing AI-18012...Error processing unknown: 'prediction'Processing AI-18020...Error processing unknown: 'prediction'
#
#
# Error processing unknown: 'prediction'
#
#
# Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Processing AI-18081...Error processing unknown: 'prediction'
#
#
#
#
#
#
# Error processing unknown: 'prediction'
#
#
#
#
#
#
#
#
#
#
#
# Error processing unknown: 'prediction'
#
# Processing AI-18201...
# Error processing unknown: 'prediction'
#
#
#
# Error processing unknown: 'prediction'
#
#
#
# Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'
#
#
#
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-1810...Processing AI-18292...
#
# Error processing unknown: 'prediction'
#
# Processing AI-18581...Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-1827...Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-18397...Error processing unknown: 'prediction'Processing AI-18305...Error processing unknown: 'prediction'Processing AI-19122...Error processing unknown: 'prediction'Processing AI-18549...
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-19008...
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'
# Processing AI-18839...
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Processing AI-18820...Processing AI-18926...
# Processing AI-19099...
#
#
#
# Processing AI-18964...Processing AI-18852...
# Error processing unknown: 'prediction'Processing AI-19119...
#
#
#
#
#
#
#
# Processing AI-19143...
#
#
#
#
#
#
#
#
#
#
# Processing AI-19429...
# Error processing unknown: 'prediction'
#
#
#
# Processing AI-19437...
#
#
# Processing AI-19184...
#
# Processing AI-18892...
#
#
# Processing AI-19341...
# Processing AI-18850...
# Processing AI-19368...
#
# Processing AI-19464...
# Error processing unknown: 'prediction'Processing AI-19132...Processing AI-19540...Error processing unknown: 'prediction'Processing AI-19504...
#
#
#
# Error processing unknown: 'prediction'Processing AI-19616...Processing AI-19591...Error processing unknown: 'prediction'Processing AI-19711...Processing AI-19746...Processing AI-19722...Processing AI-19862...
# Processing AI-19769...Processing AI-20067...Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-19872...Processing AI-19913...Error processing unknown: 'prediction'Processing AI-19921...Error processing unknown: 'prediction'Processing AI-19902...Processing AI-20263...
#
# Processing AI-20392...Processing AI-2067...Processing AI-2172...Error processing unknown: 'prediction'Processed 1/2725 entries (0 successes)
# Processed 2/2725 entries (0 successes)
# Processed 3/2725 entries (0 successes)
# Processed 4/2725 entries (0 successes)
# Processed 5/2725 entries (0 successes)
# Processed 6/2725 entries (0 successes)
# Processed 7/2725 entries (0 successes)
# Processed 8/2725 entries (0 successes)
# Processed 9/2725 entries (0 successes)
# Processed 10/2725 entries (0 successes)
# Processed 11/2725 entries (0 successes)
# Processed 12/2725 entries (0 successes)
# Processed 13/2725 entries (0 successes)
# Processed 14/2725 entries (0 successes)
# Processed 15/2725 entries (0 successes)
# Processed 16/2725 entries (0 successes)
# Processed 17/2725 entries (0 successes)
# Processed 18/2725 entries (0 successes)
# Processed 19/2725 entries (0 successes)
# Processed 20/2725 entries (0 successes)
# Processed 21/2725 entries (0 successes)
# Processed 22/2725 entries (0 successes)
# Processed 23/2725 entries (0 successes)
# Processed 24/2725 entries (0 successes)
# Processed 25/2725 entries (0 successes)
# Processed 26/2725 entries (0 successes)
# Processed 27/2725 entries (0 successes)
# Processed 28/2725 entries (0 successes)
# Processed 29/2725 entries (0 successes)
# Processed 30/2725 entries (0 successes)
# Processed 31/2725 entries (0 successes)
# Processed 32/2725 entries (0 successes)
# Processed 33/2725 entries (0 successes)
# Processed 34/2725 entries (0 successes)
# Processed 35/2725 entries (0 successes)
# Processed 36/2725 entries (0 successes)
# Processed 37/2725 entries (0 successes)
# Processed 38/2725 entries (0 successes)
# Processed 39/2725 entries (0 successes)
# Processed 40/2725 entries (0 successes)
# Processed 41/2725 entries (0 successes)
# Processed 42/2725 entries (0 successes)
# Processed 43/2725 entries (0 successes)
# Processed 44/2725 entries (0 successes)
# Processed 45/2725 entries (0 successes)
# Processed 46/2725 entries (0 successes)
# Processed 47/2725 entries (0 successes)
# Processed 48/2725 entries (0 successes)
# Processed 49/2725 entries (0 successes)
# Processed 50/2725 entries (0 successes)
# Processed 51/2725 entries (0 successes)
# Processed 52/2725 entries (0 successes)
# Processed 53/2725 entries (0 successes)
# Processed 54/2725 entries (0 successes)
# Processed 55/2725 entries (0 successes)
# Processed 56/2725 entries (0 successes)
# Processed 57/2725 entries (0 successes)
# Processed 58/2725 entries (0 successes)
# Processed 59/2725 entries (0 successes)
# Processed 60/2725 entries (0 successes)
# Processed 61/2725 entries (0 successes)
# Processed 62/2725 entries (0 successes)
# Processed 63/2725 entries (0 successes)
# Processed 64/2725 entries (0 successes)
# Processed 65/2725 entries (0 successes)
# Processed 66/2725 entries (0 successes)
# Processed 67/2725 entries (0 successes)
# Processed 68/2725 entries (0 successes)
# Processed 69/2725 entries (0 successes)
# Processed 70/2725 entries (0 successes)
# Processed 71/2725 entries (0 successes)
# Processed 72/2725 entries (0 successes)
# Processed 73/2725 entries (0 successes)
# Processed 74/2725 entries (0 successes)
# Processed 75/2725 entries (0 successes)
# Processed 76/2725 entries (0 successes)
# Processed 77/2725 entries (0 successes)
# Processed 78/2725 entries (0 successes)
# Processed 79/2725 entries (0 successes)
# Processed 80/2725 entries (0 successes)
# Processed 81/2725 entries (0 successes)
# Processed 82/2725 entries (0 successes)
# Processed 83/2725 entries (0 successes)
# Processed 84/2725 entries (0 successes)
# Processed 85/2725 entries (0 successes)
# Processed 86/2725 entries (0 successes)
# Processed 87/2725 entries (0 successes)
# Processed 88/2725 entries (0 successes)
# Processed 89/2725 entries (0 successes)
# Processed 90/2725 entries (0 successes)
# Processed 91/2725 entries (0 successes)
# Processed 92/2725 entries (0 successes)
# Processed 93/2725 entries (0 successes)
# Processed 94/2725 entries (0 successes)
# Processed 95/2725 entries (0 successes)
# Processed 96/2725 entries (0 successes)
# Processed 97/2725 entries (0 successes)
# Processed 98/2725 entries (0 successes)
# Processed 99/2725 entries (0 successes)
# Processed 100/2725 entries (0 successes)
# Processed 101/2725 entries (0 successes)
# Processed 102/2725 entries (0 successes)
# Processed 103/2725 entries (0 successes)
# Processed 104/2725 entries (0 successes)
# Processed 105/2725 entries (0 successes)
# Processed 106/2725 entries (0 successes)
# Processed 107/2725 entries (0 successes)
# Processed 108/2725 entries (0 successes)
# Processed 109/2725 entries (0 successes)
# Processed 110/2725 entries (0 successes)
# Processed 111/2725 entries (0 successes)
# Processed 112/2725 entries (0 successes)
# Processed 113/2725 entries (0 successes)
# Processed 114/2725 entries (0 successes)
# Processed 115/2725 entries (0 successes)
# Processed 116/2725 entries (0 successes)
# Processed 117/2725 entries (0 successes)
# Processed 118/2725 entries (0 successes)
# Processed 119/2725 entries (0 successes)
# Processed 120/2725 entries (0 successes)
# Processed 121/2725 entries (0 successes)
# Processed 122/2725 entries (0 successes)
# Processed 123/2725 entries (0 successes)
# Processed 124/2725 entries (0 successes)
# Processed 125/2725 entries (0 successes)
# Processed 126/2725 entries (0 successes)
# Processed 127/2725 entries (0 successes)
# Processed 128/2725 entries (0 successes)
# Processed 129/2725 entries (0 successes)
# Processed 130/2725 entries (0 successes)
# Processed 131/2725 entries (0 successes)
# Processed 132/2725 entries (0 successes)
# Processed 133/2725 entries (0 successes)
# Processed 134/2725 entries (0 successes)
# Processed 135/2725 entries (0 successes)
# Processed 136/2725 entries (0 successes)
# Processed 137/2725 entries (0 successes)
# Processed 138/2725 entries (0 successes)
# Processed 139/2725 entries (0 successes)
# Processed 140/2725 entries (0 successes)
# Processed 141/2725 entries (0 successes)
# Processed 142/2725 entries (0 successes)
# Processed 143/2725 entries (0 successes)
# Processed 144/2725 entries (0 successes)
# Processed 145/2725 entries (0 successes)
# Processed 146/2725 entries (0 successes)
# Processed 147/2725 entries (0 successes)
# Processed 148/2725 entries (0 successes)
# Processed 149/2725 entries (0 successes)
# Processed 150/2725 entries (0 successes)
# Processed 151/2725 entries (0 successes)
# Processed 152/2725 entries (0 successes)
# Processed 153/2725 entries (0 successes)
# Processed 154/2725 entries (0 successes)
# Processed 155/2725 entries (0 successes)
# Processed 156/2725 entries (0 successes)
# Processed 157/2725 entries (0 successes)
# Processed 158/2725 entries (0 successes)
# Processed 159/2725 entries (0 successes)
# Processed 160/2725 entries (0 successes)
# Processed 161/2725 entries (0 successes)
# Processed 162/2725 entries (0 successes)
# Processed 163/2725 entries (0 successes)
# Processed 164/2725 entries (0 successes)
# Processed 165/2725 entries (0 successes)
# Processed 166/2725 entries (0 successes)
# Processed 167/2725 entries (0 successes)
# Processed 168/2725 entries (0 successes)
# Processed 169/2725 entries (0 successes)
# Processed 170/2725 entries (0 successes)
# Processed 171/2725 entries (0 successes)
# Processed 172/2725 entries (0 successes)
# Processed 173/2725 entries (0 successes)
# Processed 174/2725 entries (0 successes)
# Processed 175/2725 entries (0 successes)
# Processed 176/2725 entries (0 successes)
# Processed 177/2725 entries (0 successes)
# Processed 178/2725 entries (0 successes)
# Processed 179/2725 entries (0 successes)
# Processed 180/2725 entries (0 successes)
# Processed 181/2725 entries (0 successes)
# Processed 182/2725 entries (0 successes)
# Processed 183/2725 entries (0 successes)
# Processed 184/2725 entries (0 successes)
# Processed 185/2725 entries (0 successes)
# Processed 186/2725 entries (0 successes)
# Processed 187/2725 entries (0 successes)
# Processed 188/2725 entries (0 successes)
# Processed 189/2725 entries (0 successes)
# Processed 190/2725 entries (0 successes)
# Processed 191/2725 entries (0 successes)
# Processed 192/2725 entries (0 successes)
# Processed 193/2725 entries (0 successes)
# Processed 194/2725 entries (0 successes)
# Processed 195/2725 entries (0 successes)
# Processed 196/2725 entries (0 successes)
# Processed 197/2725 entries (0 successes)
# Processed 198/2725 entries (0 successes)
# Processed 199/2725 entries (0 successes)
# Processed 200/2725 entries (0 successes)
# Processed 201/2725 entries (0 successes)
# Processed 202/2725 entries (0 successes)
# Processed 203/2725 entries (0 successes)
# Processed 204/2725 entries (0 successes)
# Processed 205/2725 entries (0 successes)
# Processed 206/2725 entries (0 successes)
# Processed 207/2725 entries (0 successes)
# Processed 208/2725 entries (0 successes)
# Processed 209/2725 entries (0 successes)
# Processed 210/2725 entries (0 successes)
# Processed 211/2725 entries (0 successes)
# Processed 212/2725 entries (0 successes)
# Processed 213/2725 entries (0 successes)
# Processed 214/2725 entries (0 successes)
# Processed 215/2725 entries (0 successes)
# Processed 216/2725 entries (0 successes)
# Processed 217/2725 entries (0 successes)
# Processed 218/2725 entries (0 successes)
# Processed 219/2725 entries (0 successes)
# Processed 220/2725 entries (0 successes)
# Processed 221/2725 entries (0 successes)
# Processed 222/2725 entries (0 successes)
# Processed 223/2725 entries (0 successes)
# Processed 224/2725 entries (0 successes)
# Processed 225/2725 entries (0 successes)
# Processed 226/2725 entries (0 successes)
# Processed 227/2725 entries (0 successes)
# Processed 228/2725 entries (0 successes)
# Processed 229/2725 entries (0 successes)
# Processed 230/2725 entries (0 successes)
# Processed 231/2725 entries (0 successes)
# Processed 232/2725 entries (0 successes)
# Processed 233/2725 entries (0 successes)
# Processed 234/2725 entries (0 successes)
# Processed 235/2725 entries (0 successes)
# Processed 236/2725 entries (0 successes)
# Processed 237/2725 entries (0 successes)
# Processed 238/2725 entries (0 successes)
# Processed 239/2725 entries (0 successes)
# Processed 240/2725 entries (0 successes)
# Processed 241/2725 entries (0 successes)
# Processed 242/2725 entries (0 successes)
# Processed 243/2725 entries (0 successes)
# Processed 244/2725 entries (0 successes)
# Processed 245/2725 entries (0 successes)
# Processed 246/2725 entries (0 successes)
# Processed 247/2725 entries (0 successes)
# Processed 248/2725 entries (0 successes)
# Processed 249/2725 entries (0 successes)
# Processed 250/2725 entries (0 successes)
# Processed 251/2725 entries (0 successes)
# Processed 252/2725 entries (0 successes)
# Processed 253/2725 entries (0 successes)
# Processed 254/2725 entries (0 successes)
# Processed 255/2725 entries (0 successes)
# Processed 256/2725 entries (0 successes)
# Processed 257/2725 entries (0 successes)
# Processed 258/2725 entries (0 successes)
# Processed 259/2725 entries (0 successes)
# Processed 260/2725 entries (0 successes)
# Processed 261/2725 entries (0 successes)
# Processed 262/2725 entries (0 successes)
# Processed 263/2725 entries (0 successes)
# Processed 264/2725 entries (0 successes)
# Processed 265/2725 entries (0 successes)
# Processed 266/2725 entries (0 successes)
# Processed 267/2725 entries (0 successes)
# Processed 268/2725 entries (0 successes)
# Processed 269/2725 entries (0 successes)
# Processed 270/2725 entries (0 successes)
# Processed 271/2725 entries (0 successes)
# Processed 272/2725 entries (0 successes)
# Processed 273/2725 entries (0 successes)
# Processed 274/2725 entries (0 successes)
# Processed 275/2725 entries (0 successes)
# Processed 276/2725 entries (0 successes)
# Processed 277/2725 entries (0 successes)
# Processed 278/2725 entries (0 successes)
# Processed 279/2725 entries (0 successes)
# Processed 280/2725 entries (0 successes)
# Processed 281/2725 entries (0 successes)
# Processed 282/2725 entries (0 successes)
# Processed 283/2725 entries (0 successes)
# Processed 284/2725 entries (0 successes)
# Processed 285/2725 entries (0 successes)
# Processed 286/2725 entries (0 successes)
# Processed 287/2725 entries (0 successes)
# Processed 288/2725 entries (0 successes)
# Processed 289/2725 entries (0 successes)
# Processed 290/2725 entries (0 successes)
# Processed 291/2725 entries (0 successes)
# Processed 292/2725 entries (0 successes)
# Processed 293/2725 entries (0 successes)
# Processed 294/2725 entries (0 successes)
# Processed 295/2725 entries (0 successes)
# Processed 296/2725 entries (0 successes)
# Processed 297/2725 entries (0 successes)
# Processed 298/2725 entries (0 successes)
# Processed 299/2725 entries (0 successes)
# Processed 300/2725 entries (0 successes)
# Processed 301/2725 entries (0 successes)
# Processed 302/2725 entries (0 successes)
# Processed 303/2725 entries (0 successes)
# Processed 304/2725 entries (0 successes)
# Processed 305/2725 entries (0 successes)
# Processed 306/2725 entries (0 successes)
# Processed 307/2725 entries (0 successes)
# Processed 308/2725 entries (0 successes)
# Processed 309/2725 entries (0 successes)
# Processed 310/2725 entries (0 successes)
# Processed 311/2725 entries (0 successes)
# Processed 312/2725 entries (0 successes)
# Processed 313/2725 entries (0 successes)
# Processed 314/2725 entries (0 successes)
# Processed 315/2725 entries (0 successes)
# Processed 316/2725 entries (0 successes)
# Processed 317/2725 entries (0 successes)
# Processed 318/2725 entries (0 successes)
# Processed 319/2725 entries (0 successes)
# Processed 320/2725 entries (0 successes)
# Processed 321/2725 entries (0 successes)
# Processed 322/2725 entries (0 successes)
# Processed 323/2725 entries (0 successes)
# Processed 324/2725 entries (0 successes)
# Processed 325/2725 entries (0 successes)
# Processed 326/2725 entries (0 successes)
# Processed 327/2725 entries (0 successes)
# Processed 328/2725 entries (0 successes)
# Processed 329/2725 entries (0 successes)
# Processed 330/2725 entries (0 successes)
# Processed 331/2725 entries (0 successes)
# Processed 332/2725 entries (0 successes)
# Processed 333/2725 entries (0 successes)
# Processed 334/2725 entries (0 successes)
# Processed 335/2725 entries (0 successes)
# Processed 336/2725 entries (0 successes)
# Processed 337/2725 entries (0 successes)
# Processed 338/2725 entries (0 successes)
# Processed 339/2725 entries (0 successes)
# Processed 340/2725 entries (0 successes)
# Processed 341/2725 entries (0 successes)
# Processed 342/2725 entries (0 successes)
# Processed 343/2725 entries (0 successes)
# Processed 344/2725 entries (0 successes)
# Processed 345/2725 entries (0 successes)
# Processed 346/2725 entries (0 successes)
# Processed 347/2725 entries (0 successes)
# Processed 348/2725 entries (0 successes)
# Processed 349/2725 entries (0 successes)
# Processed 350/2725 entries (0 successes)
# Processed 351/2725 entries (0 successes)
# Processed 352/2725 entries (0 successes)
# Processed 353/2725 entries (0 successes)
# Processed 354/2725 entries (0 successes)
# Processed 355/2725 entries (0 successes)
# Processed 356/2725 entries (0 successes)
# Processed 357/2725 entries (0 successes)
# Processed 358/2725 entries (0 successes)
# Processed 359/2725 entries (0 successes)
# Processed 360/2725 entries (0 successes)
# Processed 361/2725 entries (0 successes)
# Processed 362/2725 entries (0 successes)
# Processed 363/2725 entries (0 successes)
# Processed 364/2725 entries (0 successes)
# Processed 365/2725 entries (0 successes)
# Processed 366/2725 entries (0 successes)
# Processed 367/2725 entries (0 successes)
# Processed 368/2725 entries (0 successes)
# Processed 369/2725 entries (0 successes)
# Processed 370/2725 entries (0 successes)
# Processed 371/2725 entries (0 successes)
# Processed 372/2725 entries (0 successes)
# Processed 373/2725 entries (0 successes)
# Processed 374/2725 entries (0 successes)
# Processed 375/2725 entries (0 successes)
# Processed 376/2725 entries (0 successes)
# Processed 377/2725 entries (0 successes)
# Processed 378/2725 entries (0 successes)
# Processed 379/2725 entries (0 successes)
# Processed 380/2725 entries (0 successes)
# Processed 381/2725 entries (0 successes)
# Processed 382/2725 entries (0 successes)
# Processed 383/2725 entries (0 successes)
# Processed 384/2725 entries (0 successes)
# Processed 385/2725 entries (0 successes)
# Processed 386/2725 entries (0 successes)
# Processed 387/2725 entries (0 successes)
# Processed 388/2725 entries (0 successes)
# Processed 389/2725 entries (0 successes)
# Processed 390/2725 entries (0 successes)
# Processed 391/2725 entries (0 successes)
# Processed 392/2725 entries (0 successes)
# Processed 393/2725 entries (0 successes)
# Processed 394/2725 entries (0 successes)
# Processed 395/2725 entries (0 successes)
# Processed 396/2725 entries (0 successes)
# Processed 397/2725 entries (0 successes)
# Processed 398/2725 entries (0 successes)
# Processed 399/2725 entries (0 successes)
# Processed 400/2725 entries (0 successes)
# Processed 401/2725 entries (0 successes)
# Processed 402/2725 entries (0 successes)
# Processed 403/2725 entries (0 successes)
#
# Processing AI-20268...Processing AI-2071...
# Processing AI-21791...Processing AI-21994...Processing AI-2078...
# Processing AI-21895...Processing AI-21788...Processing AI-2122...
# Error processing unknown: 'prediction'
# Processing AI-2191...
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Processing AI-22130...Error processing unknown: 'prediction'
#
#
#
#
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'
#
# Processing AI-2093...
#
#
#
#
#
#
# Error processing unknown: 'prediction'
#
#
#
#
#
#
#
#
#
# Error processing unknown: 'prediction'
# Processing AI-220...
#
#
# Error processing unknown: 'prediction'
#
#
# Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'
#
#
#
# Error processing unknown: 'prediction'
#
#
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'
#
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-22026...Error processing unknown: 'prediction'Processing AI-22029...
#
# Error processing unknown: 'prediction'
#
# Processing AI-22135...Error processing unknown: 'prediction'Processing AI-22143...Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Processing AI-22146...Error processing unknown: 'prediction'Processing AI-22147...Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-22166...Error processing unknown: 'prediction'Processing AI-22288...Error processing unknown: 'prediction'Error processing unknown: 'prediction'
#
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Processing AI-22354...Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Processing AI-22373...
#
# Processing AI-22496...Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Processing AI-22516...Processing AI-22492...
#
#
#
#
# Processing AI-22519...Processing AI-22568...
# Processing AI-22639...Error processing unknown: 'prediction'
#
#
#
#
#
#
#
#
#
# Processing AI-22598...
#
#
#
#
#
#
#
#
# Error processing unknown: 'prediction'
# Processing AI-22600...
# Processing AI-22822...
#
#
#
#
# Processing AI-22767...
#
# Processing AI-22689...
#
#
# Processing AI-23012...
# Processing AI-22837...Processing AI-23129...
# Processing AI-22999...
#
#
# Error processing unknown: 'prediction'Processing AI-22873...Processing AI-23013...Error processing unknown: 'prediction'Processing AI-22866...
#
# Processing AI-23032...
#
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-23144...Processing AI-23023...Processing AI-22856...Processing AI-2320...Error processing unknown: 'prediction'Processing AI-23069...Processing AI-23253...
# Error processing unknown: 'prediction'Processing AI-23382...Processing AI-23350...Processing AI-23327...Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-23385...Processing AI-23402...Processing AI-2349...Processing AI-23457...
#
# Processing AI-2354...Processing AI-23458...
# Error processing unknown: 'prediction'Processing AI-23523...Processing AI-23574...Processing AI-23640...Processing AI-23653...
# Processing AI-23696...Processing AI-23760...
# Error processing unknown: 'prediction'
# Processing AI-23874...Processing AI-23693...
# Error processing unknown: 'prediction'
#
# Processing AI-23802...Processing AI-23745...Error processing unknown: 'prediction'Error processing unknown: 'prediction'
#
#
#
#
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'
#
# Processing AI-23841...
#
#
#
#
# Error processing unknown: 'prediction'
#
#
#
#
#
#
#
#
#
#
#
# Error processing unknown: 'prediction'
# Processing AI-23987...
# Error processing unknown: 'prediction'
#
#
#
# Error processing unknown: 'prediction'
#
#
# Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'
#
# Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'
#
#
#
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-23791...Processing AI-2412...
#
# Error processing unknown: 'prediction'
# Processing AI-23972...Processing AI-24182...
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Processing AI-2397...Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-23777...Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-23945...Error processing unknown: 'prediction'Processing AI-24030...Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'
#
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-24290...
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'
#
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-2438...
#
# Processing AI-24465...Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'
# Processing AI-2449...Processing AI-24500...
#
#
#
# Processing AI-2458...Processing AI-2452...
#
# Processing AI-24593...
# Error processing unknown: 'prediction'
#
#
#
#
# Processing AI-247...
#
#
#
#
#
#
#
#
#
#
#
# Processing AI-24691...
# Error processing unknown: 'prediction'
# Processing AI-24804...
#
# Processing AI-24918...
#
#
#
#
#
# Processing AI-24647...
# Processing AI-24961...
# Processing AI-24956...
#
# Processing AI-25064...
# Processing AI-25093...Processing AI-25096...
#
# Processing AI-25937...Error processing unknown: 'prediction'Processing AI-25487...Error processing unknown: 'prediction'
#
# Error processing unknown: 'prediction'Processing AI-25138...
# Error processing unknown: 'prediction'
# Processing AI-2578...Processing AI-25101...Processing AI-2588...Processing AI-25772...Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Processing AI-25621...Processing AI-25927...Processing AI-25765...Error processing unknown: 'prediction'Processing AI-25264...Processing AI-25345...Error processing unknown: 'prediction'Processing AI-260...Processing AI-25554...
# Processing AI-2601...Processing AI-2618...
# Processing AI-26014...
# Processing AI-26050...Processing AI-26066...Error processing unknown: 'prediction'
# Processing AI-26227...Processing AI-26240...Processing AI-26292...Processing AI-26629...Processing AI-26687...Processing AI-26657...Error processing unknown: 'prediction'
#
# Processing AI-2667...Processing AI-26788...
# Error processing unknown: 'prediction'
# Processing AI-26822...
#
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'
#
#
# Error processing unknown: 'prediction'
#
#
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'
#
# Processing AI-26874...
#
#
#
# Error processing unknown: 'prediction'
#
#
#
#
#
#
#
#
#
# Error processing unknown: 'prediction'
#
#
# Processing AI-26911...Error processing unknown: 'prediction'
#
#
#
# Error processing unknown: 'prediction'
#
#
#
#
#
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'
#
# Error processing unknown: 'prediction'
#
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'
# Processing AI-26893...
# Error processing unknown: 'prediction'Processing AI-27069...Processing AI-26931...Error processing unknown: 'prediction'
#
# Error processing unknown: 'prediction'Processing AI-27129...
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-27280...
# Error processing unknown: 'prediction'Processing AI-27061...Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-27355...Error processing unknown: 'prediction'Processing AI-27404...Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-27376...Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-2715...
#
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Processing AI-27025...
#
#
#
# Processing AI-27428...
# Processing AI-26961...
# Processing AI-27344...
#
#
# Processing AI-27237...
# Processing AI-2749...
# Error processing unknown: 'prediction'
#
#
#
#
#
# Processing AI-2763...
#
#
#
#
#
#
#
#
# Processing AI-27576...Error processing unknown: 'prediction'
#
#
# Processing AI-27615...
#
#
#
# Processing AI-27600...
#
#
#
#
#
# Processing AI-27625...
# Processing AI-27636...
# Processing AI-27639...
# Processing AI-2765...Processing AI-27729...Processing AI-27708...
# Processing AI-2772...
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Processing AI-27781...Error processing unknown: 'prediction'Processing AI-27799...
# Processing AI-27802...Error processing unknown: 'prediction'
#
# Error processing unknown: 'prediction'Processing AI-27812...Processing AI-27818...Error processing unknown: 'prediction'Processing AI-2783...Processing AI-28200...
# Processing AI-28309...Processing AI-27861...Error processing unknown: 'prediction'Processing AI-27919...Processing AI-2800...Error processing unknown: 'prediction'Processing AI-27880...Processing AI-28084...
#
# Processing AI-28060...Processing AI-28011...Processing AI-28567...Processing AI-28411...Error processing unknown: 'prediction'
# Processing AI-28405...
# Processing AI-28599...Processing AI-28383...Processing AI-28589...Error processing unknown: 'prediction'Processing AI-28284...Processing AI-27951...Processing AI-28577...Processing AI-2860...
# Processing AI-28885...
#
# Processing AI-28980...Error processing unknown: 'prediction'Error processing unknown: 'prediction'
#
#
# Error processing unknown: 'prediction'
#
#
# Error processing unknown: 'prediction'
#
#
# Error processing unknown: 'prediction'
# Processed 404/2725 entries (0 successes)
# Processed 405/2725 entries (0 successes)
# Processed 406/2725 entries (0 successes)
# Processed 407/2725 entries (0 successes)
# Processed 408/2725 entries (0 successes)
# Processed 409/2725 entries (0 successes)
# Processed 410/2725 entries (0 successes)
# Processed 411/2725 entries (0 successes)
# Processed 412/2725 entries (0 successes)
# Processed 413/2725 entries (0 successes)
# Processed 414/2725 entries (0 successes)
# Processed 415/2725 entries (0 successes)
# Processed 416/2725 entries (0 successes)
# Processed 417/2725 entries (0 successes)
# Processed 418/2725 entries (0 successes)
# Processed 419/2725 entries (0 successes)
# Processed 420/2725 entries (0 successes)
# Processed 421/2725 entries (0 successes)
# Processed 422/2725 entries (0 successes)
# Processed 423/2725 entries (0 successes)
# Processed 424/2725 entries (0 successes)
# Processed 425/2725 entries (0 successes)
# Processed 426/2725 entries (0 successes)
# Processed 427/2725 entries (0 successes)
# Processed 428/2725 entries (0 successes)
# Processed 429/2725 entries (0 successes)
# Processed 430/2725 entries (0 successes)
# Processed 431/2725 entries (0 successes)
# Processed 432/2725 entries (0 successes)
# Processed 433/2725 entries (0 successes)
# Processed 434/2725 entries (0 successes)
# Processed 435/2725 entries (0 successes)
# Processed 436/2725 entries (0 successes)
# Processed 437/2725 entries (0 successes)
# Processed 438/2725 entries (0 successes)
# Processed 439/2725 entries (0 successes)
# Processed 440/2725 entries (0 successes)
# Processed 441/2725 entries (0 successes)
# Processed 442/2725 entries (0 successes)
# Processed 443/2725 entries (0 successes)
# Processed 444/2725 entries (0 successes)
# Processed 445/2725 entries (0 successes)
# Processed 446/2725 entries (0 successes)
# Processed 447/2725 entries (0 successes)
# Processed 448/2725 entries (0 successes)
# Processed 449/2725 entries (0 successes)
# Processed 450/2725 entries (0 successes)
# Processed 451/2725 entries (0 successes)
# Processed 452/2725 entries (0 successes)
# Processed 453/2725 entries (0 successes)
# Processed 454/2725 entries (0 successes)
# Processed 455/2725 entries (0 successes)
# Processed 456/2725 entries (0 successes)
# Processed 457/2725 entries (0 successes)
# Processed 458/2725 entries (0 successes)
# Processed 459/2725 entries (0 successes)
# Processed 460/2725 entries (0 successes)
# Processed 461/2725 entries (0 successes)
# Processed 462/2725 entries (0 successes)
# Processed 463/2725 entries (0 successes)
# Processed 464/2725 entries (0 successes)
# Processed 465/2725 entries (0 successes)
# Processed 466/2725 entries (0 successes)
# Processed 467/2725 entries (0 successes)
# Processed 468/2725 entries (0 successes)
# Processed 469/2725 entries (0 successes)
# Processed 470/2725 entries (0 successes)
# Processed 471/2725 entries (0 successes)
# Processed 472/2725 entries (0 successes)
# Processed 473/2725 entries (0 successes)
# Processed 474/2725 entries (0 successes)
# Processed 475/2725 entries (0 successes)
# Processed 476/2725 entries (0 successes)
# Processed 477/2725 entries (0 successes)
# Processed 478/2725 entries (0 successes)
# Processed 479/2725 entries (0 successes)
# Processed 480/2725 entries (0 successes)
# Processed 481/2725 entries (0 successes)
# Processed 482/2725 entries (0 successes)
# Processed 483/2725 entries (0 successes)
# Processed 484/2725 entries (0 successes)
# Processed 485/2725 entries (0 successes)
# Processed 486/2725 entries (0 successes)
# Processed 487/2725 entries (0 successes)
# Processed 488/2725 entries (0 successes)
# Processed 489/2725 entries (0 successes)
# Processed 490/2725 entries (0 successes)
# Processed 491/2725 entries (0 successes)
# Processed 492/2725 entries (0 successes)
# Processed 493/2725 entries (0 successes)
# Processed 494/2725 entries (0 successes)
# Processed 495/2725 entries (0 successes)
# Processed 496/2725 entries (0 successes)
# Processed 497/2725 entries (0 successes)
# Processed 498/2725 entries (0 successes)
# Processed 499/2725 entries (0 successes)
# Processed 500/2725 entries (0 successes)
# Processed 501/2725 entries (0 successes)
# Processed 502/2725 entries (0 successes)
# Processed 503/2725 entries (0 successes)
# Processed 504/2725 entries (0 successes)
# Processed 505/2725 entries (0 successes)
# Processed 506/2725 entries (0 successes)
# Processed 507/2725 entries (0 successes)
# Processed 508/2725 entries (0 successes)
# Processed 509/2725 entries (0 successes)
# Processed 510/2725 entries (0 successes)
# Processed 511/2725 entries (0 successes)
# Processed 512/2725 entries (0 successes)
# Processed 513/2725 entries (0 successes)
# Processed 514/2725 entries (0 successes)
# Processed 515/2725 entries (0 successes)
# Processed 516/2725 entries (0 successes)
# Processed 517/2725 entries (0 successes)
# Processed 518/2725 entries (0 successes)
# Processed 519/2725 entries (0 successes)
# Processed 520/2725 entries (0 successes)
# Processed 521/2725 entries (0 successes)
# Processed 522/2725 entries (0 successes)
# Processed 523/2725 entries (0 successes)
# Processed 524/2725 entries (0 successes)
# Processed 525/2725 entries (0 successes)
# Processed 526/2725 entries (0 successes)
# Processed 527/2725 entries (0 successes)
# Processed 528/2725 entries (0 successes)
# Processed 529/2725 entries (0 successes)
# Processed 530/2725 entries (0 successes)
# Processed 531/2725 entries (0 successes)
# Processed 532/2725 entries (0 successes)
# Processed 533/2725 entries (0 successes)
# Processed 534/2725 entries (0 successes)
# Processed 535/2725 entries (0 successes)
# Processed 536/2725 entries (0 successes)
# Processed 537/2725 entries (0 successes)
# Processed 538/2725 entries (0 successes)
# Processed 539/2725 entries (0 successes)
# Processed 540/2725 entries (0 successes)
# Processed 541/2725 entries (0 successes)
# Processed 542/2725 entries (0 successes)
# Processed 543/2725 entries (0 successes)
# Processed 544/2725 entries (0 successes)
# Processed 545/2725 entries (0 successes)
# Processed 546/2725 entries (0 successes)
# Processed 547/2725 entries (0 successes)
# Processed 548/2725 entries (0 successes)
# Processed 549/2725 entries (0 successes)
# Processed 550/2725 entries (0 successes)
# Processed 551/2725 entries (0 successes)
# Processed 552/2725 entries (0 successes)
# Processed 553/2725 entries (0 successes)
# Processed 554/2725 entries (0 successes)
# Processed 555/2725 entries (0 successes)
# Processed 556/2725 entries (0 successes)
# Processed 557/2725 entries (0 successes)
# Processed 558/2725 entries (0 successes)
# Processed 559/2725 entries (0 successes)
# Processed 560/2725 entries (0 successes)
# Processed 561/2725 entries (0 successes)
# Processed 562/2725 entries (0 successes)
# Processed 563/2725 entries (0 successes)
# Processed 564/2725 entries (0 successes)
# Processed 565/2725 entries (0 successes)
# Processed 566/2725 entries (0 successes)
# Processed 567/2725 entries (0 successes)
# Processed 568/2725 entries (0 successes)
# Processed 569/2725 entries (0 successes)
# Processed 570/2725 entries (0 successes)
# Processed 571/2725 entries (0 successes)
# Processed 572/2725 entries (0 successes)
# Processed 573/2725 entries (0 successes)
# Processed 574/2725 entries (0 successes)
# Processed 575/2725 entries (0 successes)
# Processed 576/2725 entries (0 successes)
# Processed 577/2725 entries (0 successes)
# Processed 578/2725 entries (0 successes)
# Processed 579/2725 entries (0 successes)
# Processed 580/2725 entries (0 successes)
# Processed 581/2725 entries (0 successes)
# Processed 582/2725 entries (0 successes)
# Processed 583/2725 entries (0 successes)
# Processed 584/2725 entries (0 successes)
# Processed 585/2725 entries (0 successes)
# Processed 586/2725 entries (0 successes)
# Processed 587/2725 entries (0 successes)
# Processed 588/2725 entries (0 successes)
# Processed 589/2725 entries (0 successes)
# Processed 590/2725 entries (0 successes)
# Processed 591/2725 entries (0 successes)
# Processed 592/2725 entries (0 successes)
# Processed 593/2725 entries (0 successes)
# Processed 594/2725 entries (0 successes)
# Processed 595/2725 entries (0 successes)
# Processed 596/2725 entries (0 successes)
# Processed 597/2725 entries (0 successes)
# Processed 598/2725 entries (0 successes)
# Processed 599/2725 entries (0 successes)
# Processed 600/2725 entries (0 successes)
# Processed 601/2725 entries (0 successes)
# Processed 602/2725 entries (0 successes)
# Processed 603/2725 entries (0 successes)
# Processed 604/2725 entries (0 successes)
# Processed 605/2725 entries (0 successes)
# Processed 606/2725 entries (0 successes)
# Processed 607/2725 entries (0 successes)
# Processed 608/2725 entries (0 successes)
# Processed 609/2725 entries (0 successes)
# Processed 610/2725 entries (0 successes)
# Processed 611/2725 entries (0 successes)
# Processed 612/2725 entries (0 successes)
# Processed 613/2725 entries (0 successes)
# Processed 614/2725 entries (0 successes)
# Processed 615/2725 entries (0 successes)
# Processed 616/2725 entries (0 successes)
# Processed 617/2725 entries (0 successes)
# Processed 618/2725 entries (0 successes)
# Processed 619/2725 entries (0 successes)
# Processed 620/2725 entries (0 successes)
# Processed 621/2725 entries (0 successes)
# Processed 622/2725 entries (0 successes)
# Processed 623/2725 entries (0 successes)
# Processed 624/2725 entries (0 successes)
# Processed 625/2725 entries (0 successes)
# Processed 626/2725 entries (0 successes)
# Processed 627/2725 entries (0 successes)
# Processed 628/2725 entries (0 successes)
# Processed 629/2725 entries (0 successes)
# Processed 630/2725 entries (0 successes)
# Processed 631/2725 entries (0 successes)
# Processed 632/2725 entries (0 successes)
# Processed 633/2725 entries (0 successes)
# Processed 634/2725 entries (0 successes)
# Processed 635/2725 entries (0 successes)
# Processed 636/2725 entries (0 successes)
# Processed 637/2725 entries (0 successes)
# Processed 638/2725 entries (0 successes)
# Processed 639/2725 entries (0 successes)
# Processed 640/2725 entries (0 successes)
# Processed 641/2725 entries (0 successes)
# Processed 642/2725 entries (0 successes)
# Processed 643/2725 entries (0 successes)
# Processed 644/2725 entries (0 successes)
# Processed 645/2725 entries (0 successes)
# Processed 646/2725 entries (0 successes)
# Processed 647/2725 entries (0 successes)
# Processed 648/2725 entries (0 successes)
# Processed 649/2725 entries (0 successes)
# Processed 650/2725 entries (0 successes)
# Processed 651/2725 entries (0 successes)
# Processed 652/2725 entries (0 successes)
# Processed 653/2725 entries (0 successes)
# Processed 654/2725 entries (0 successes)
# Processed 655/2725 entries (0 successes)
# Processed 656/2725 entries (0 successes)
# Processed 657/2725 entries (0 successes)
# Processed 658/2725 entries (0 successes)
# Processed 659/2725 entries (0 successes)
# Processed 660/2725 entries (0 successes)
# Processed 661/2725 entries (0 successes)
# Processed 662/2725 entries (0 successes)
# Processed 663/2725 entries (0 successes)
# Processed 664/2725 entries (0 successes)
# Processed 665/2725 entries (0 successes)
# Processed 666/2725 entries (0 successes)
# Processed 667/2725 entries (0 successes)
# Processed 668/2725 entries (0 successes)
# Processed 669/2725 entries (0 successes)
# Processed 670/2725 entries (0 successes)
# Processed 671/2725 entries (0 successes)
# Processed 672/2725 entries (0 successes)
# Processed 673/2725 entries (0 successes)
# Processed 674/2725 entries (0 successes)
# Processed 675/2725 entries (0 successes)
# Processed 676/2725 entries (0 successes)
# Processed 677/2725 entries (0 successes)
# Processed 678/2725 entries (0 successes)
# Processed 679/2725 entries (0 successes)
# Processed 680/2725 entries (0 successes)
# Processed 681/2725 entries (0 successes)
# Processed 682/2725 entries (0 successes)
# Processed 683/2725 entries (0 successes)
# Processed 684/2725 entries (0 successes)
# Processed 685/2725 entries (0 successes)
# Processed 686/2725 entries (0 successes)
# Processed 687/2725 entries (0 successes)
# Processed 688/2725 entries (0 successes)
# Processed 689/2725 entries (0 successes)
# Processed 690/2725 entries (0 successes)
# Processed 691/2725 entries (0 successes)
# Processed 692/2725 entries (0 successes)
# Processed 693/2725 entries (0 successes)
# Processed 694/2725 entries (0 successes)
# Processed 695/2725 entries (0 successes)
# Processed 696/2725 entries (0 successes)
# Processed 697/2725 entries (0 successes)
# Processed 698/2725 entries (0 successes)
# Processed 699/2725 entries (0 successes)
# Processed 700/2725 entries (0 successes)
# Processed 701/2725 entries (0 successes)
# Processed 702/2725 entries (0 successes)
# Processed 703/2725 entries (0 successes)
# Processed 704/2725 entries (0 successes)
# Processed 705/2725 entries (0 successes)
# Processed 706/2725 entries (0 successes)
# Processed 707/2725 entries (0 successes)
# Processed 708/2725 entries (0 successes)
# Processed 709/2725 entries (0 successes)
# Processed 710/2725 entries (0 successes)
# Processed 711/2725 entries (0 successes)
# Processed 712/2725 entries (0 successes)
# Processed 713/2725 entries (0 successes)
# Processed 714/2725 entries (0 successes)
# Processed 715/2725 entries (0 successes)
# Processed 716/2725 entries (0 successes)
# Processed 717/2725 entries (0 successes)
# Processed 718/2725 entries (0 successes)
# Processed 719/2725 entries (0 successes)
# Processed 720/2725 entries (0 successes)
# Processed 721/2725 entries (0 successes)
# Processed 722/2725 entries (0 successes)
# Processed 723/2725 entries (0 successes)
# Processed 724/2725 entries (0 successes)
# Processed 725/2725 entries (0 successes)
# Processed 726/2725 entries (0 successes)
# Processed 727/2725 entries (0 successes)
# Processed 728/2725 entries (0 successes)
# Processed 729/2725 entries (0 successes)
# Processed 730/2725 entries (0 successes)
# Processed 731/2725 entries (0 successes)
# Processed 732/2725 entries (0 successes)
# Processed 733/2725 entries (0 successes)
# Processed 734/2725 entries (0 successes)
# Processed 735/2725 entries (0 successes)
# Processed 736/2725 entries (0 successes)
# Processed 737/2725 entries (0 successes)
# Processed 738/2725 entries (0 successes)
# Processed 739/2725 entries (0 successes)
# Processed 740/2725 entries (0 successes)
# Processed 741/2725 entries (0 successes)
# Processed 742/2725 entries (0 successes)
# Processed 743/2725 entries (0 successes)
# Processed 744/2725 entries (0 successes)
# Processed 745/2725 entries (0 successes)
# Processed 746/2725 entries (0 successes)
# Processed 747/2725 entries (0 successes)
# Processed 748/2725 entries (0 successes)
# Processed 749/2725 entries (0 successes)
# Processed 750/2725 entries (0 successes)
# Processed 751/2725 entries (0 successes)
# Processed 752/2725 entries (0 successes)
# Processed 753/2725 entries (0 successes)
# Processed 754/2725 entries (0 successes)
# Processed 755/2725 entries (0 successes)
# Processed 756/2725 entries (0 successes)
# Processed 757/2725 entries (0 successes)
# Processed 758/2725 entries (0 successes)
# Processed 759/2725 entries (0 successes)
# Processed 760/2725 entries (0 successes)
# Processed 761/2725 entries (0 successes)
# Processed 762/2725 entries (0 successes)
# Processed 763/2725 entries (0 successes)
# Processed 764/2725 entries (0 successes)
# Processed 765/2725 entries (0 successes)
# Processed 766/2725 entries (0 successes)
# Processed 767/2725 entries (0 successes)
# Processed 768/2725 entries (0 successes)
# Processed 769/2725 entries (0 successes)
# Processed 770/2725 entries (0 successes)
# Processed 771/2725 entries (0 successes)
# Processed 772/2725 entries (0 successes)
# Processed 773/2725 entries (0 successes)
# Processed 774/2725 entries (0 successes)
# Processed 775/2725 entries (0 successes)
# Processed 776/2725 entries (0 successes)
# Processed 777/2725 entries (0 successes)
# Processed 778/2725 entries (0 successes)
# Processed 779/2725 entries (0 successes)
# Processed 780/2725 entries (0 successes)
# Processed 781/2725 entries (0 successes)
# Processed 782/2725 entries (0 successes)
# Processed 783/2725 entries (0 successes)
# Processed 784/2725 entries (0 successes)
# Processed 785/2725 entries (0 successes)
# Processed 786/2725 entries (0 successes)
# Processed 787/2725 entries (0 successes)
# Processed 788/2725 entries (0 successes)
# Processed 789/2725 entries (0 successes)
# Processed 790/2725 entries (0 successes)
# Processed 791/2725 entries (0 successes)
# Processed 792/2725 entries (0 successes)
# Processed 793/2725 entries (0 successes)
# Processed 794/2725 entries (0 successes)
# Processed 795/2725 entries (0 successes)
# Processed 796/2725 entries (0 successes)
# Processed 797/2725 entries (0 successes)
# Processed 798/2725 entries (0 successes)
# Processed 799/2725 entries (0 successes)
# Processed 800/2725 entries (0 successes)
# Processed 801/2725 entries (0 successes)
# Processed 802/2725 entries (0 successes)
# Error processing unknown: 'prediction'
# Processing AI-29010...
#
#
#
#
#
# Error processing unknown: 'prediction'
#
#
#
#
#
#
#
# Error processing unknown: 'prediction'Processing AI-29028...
#
#
#
#
# Error processing unknown: 'prediction'
#
# Error processing unknown: 'prediction'
#
#
#
#
#
#
#
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'
#
#
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-29029...Error processing unknown: 'prediction'Processing AI-29124...
# Error processing unknown: 'prediction'Processing AI-29253...
# Error processing unknown: 'prediction'
#
# Error processing unknown: 'prediction'Processing AI-29262...Processing AI-29279...Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-29431...Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Processing AI-29443...Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-29451...Error processing unknown: 'prediction'Error processing unknown: 'prediction'
#
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-29508...
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-29558...Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'
#
# Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Processing AI-2958...
#
# Processing AI-29608...Processing AI-29561...
#
#
#
#
# Processing AI-29571...
#
#
#
# Processing AI-29663...Error processing unknown: 'prediction'Processing AI-29678...
#
#
#
#
#
#
#
# Processing AI-29684...
#
#
#
#
#
# Processing AI-29708...Error processing unknown: 'prediction'
#
#
#
#
#
# Processing AI-29766...
#
#
# Processing AI-29825...
#
#
#
#
# Processing AI-30126...Processing AI-30401...
#
#
# Processing AI-29929...Processing AI-30426...Processing AI-30357...
#
# Processing AI-29797...Processing AI-29688...Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Processing AI-30438...Error processing unknown: 'prediction'Processing AI-3044...
# Processing AI-30464...Processing AI-30495...
#
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-30520...Processing AI-30690...Error processing unknown: 'prediction'Processing AI-30707...Processing AI-30909...Processing AI-30864...
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-3091...Processing AI-30921...
# Processing AI-30970...Processing AI-31105...Processing AI-30936...
# Processing AI-3102...Processing AI-31052...Error processing unknown: 'prediction'Processing AI-31049...Processing AI-3119...
# Processing AI-31286...Processing AI-31365...Error processing unknown: 'prediction'
# Processing AI-31211...Processing AI-31222...Processing AI-31429...Processing AI-31441...
# Processing AI-31575...
# Processing AI-31439...Processing AI-31479...Error processing unknown: 'prediction'
#
#
# Error processing unknown: 'prediction'
#
#
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'
#
#
#
#
#
# Error processing unknown: 'prediction'
#
# Processing AI-31599...
#
#
#
#
# Error processing unknown: 'prediction'
#
#
#
# Error processing unknown: 'prediction'
#
#
#
#
#
# Processing AI-31718...
#
#
# Error processing unknown: 'prediction'
#
#
#
# Error processing unknown: 'prediction'
#
#
# Error processing unknown: 'prediction'
#
# Error processing unknown: 'prediction'
#
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-31664...
# Error processing unknown: 'prediction'
#
# Processing AI-31887...Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Processing AI-31938...Processing AI-31979...
# Processing AI-31951...Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-32046...
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Processing AI-32104...Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-327...Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-32709...Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Processing AI-32999...Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Processing AI-32982...
#
#
#
# Processing AI-33027...
#
# Processing AI-33070...
# Processing AI-33294...Processing AI-33142...
#
#
#
# Processing AI-33404...
#
# Error processing unknown: 'prediction'
#
#
#
#
# Processing AI-33428...
#
# Processing AI-33343...
#
#
#
#
#
#
#
# Error processing unknown: 'prediction'
#
#
#
#
#
# Processing AI-33322...
#
#
# Processing AI-33486...
#
#
# Processing AI-33517...
# Processing AI-33599...
# Processing AI-33712...
# Processing AI-33707...Processing AI-33794...
# Processing AI-33955...Error processing unknown: 'prediction'
#
# Processing AI-340...Processing AI-33927...
# Error processing unknown: 'prediction'Processing AI-33797...Error processing unknown: 'prediction'
# Processing AI-33848...Processing AI-34055...
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Processing AI-34024...Processing AI-34104...Error processing unknown: 'prediction'Processing AI-34175...
# Processing AI-34057...
# Processing AI-341...Error processing unknown: 'prediction'Processing AI-34197...Processing AI-34241...Processing AI-34231...Error processing unknown: 'prediction'Processing AI-34416...Processing AI-3449...
# Processing AI-34522...Processing AI-34569...Error processing unknown: 'prediction'Processing AI-34580...
# Processing AI-3492...Error processing unknown: 'prediction'Processing AI-35010...Processing AI-34842...Processing AI-3503...Processing AI-35033...Processing AI-35078...
# Processing AI-35038...Processing AI-35198...
# Processing AI-35368...
#
# Error processing unknown: 'prediction'
#
# Processing AI-35322...Error processing unknown: 'prediction'
#
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'
#
# Error processing unknown: 'prediction'
#
#
# Error processing unknown: 'prediction'
#
#
# Processing AI-35386...
#
#
#
#
# Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'
#
#
#
#
#
#
#
#
#
# Processing AI-35393...
#
# Error processing unknown: 'prediction'
#
#
#
#
#
#
# Error processing unknown: 'prediction'
#
#
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'
# Error processing unknown: 'prediction'Error processing unknown: 'prediction'Error processing unknown: 'prediction'

# %%
###########Teds_structure_evaluation###########
import re
from table_recognition_metric import TEDS
import multiprocessing
import json

def remove_grid_lines(latex_table):
    cleaned_table = re.sub(r'\\cmidrule{\s*}|\\cdashline\{[0-9]+(-[0-9]+)?\}\s*|\\cmidrule$(?:lr|r|l)?$\{[0-9]+\-[0-9]+\}\s*|\\arrayrulecolor{.*?}\s*|\\caption{.*?}\s*|\\centering\s*|\\hline\s*|\\cline{.*?}\s*|\\toprule\s*|\\midrule\s*|\\bottomrule\s*', '', latex_table)
    cleaned_table = re.sub(r'\\tabularnewline', r'\\\\', cleaned_table)
    cleaned_table = re.sub(r'\n\s*\n', '\n', cleaned_table)
    return cleaned_table.strip(' \n')

def fix_multi(cell):
    multirow_pattern = r'\\multirow{(\d+)}{.*?}{(.*?)}'
    multicol_pattern = r'\\multicolumn{(\d+)}{.*?}{(.*?)}'
    
    match = re.search(multirow_pattern, cell['content'])
    if match:
        cell['rowspan'] = int(match.group(1))
        cell['content'] = cell['content'].replace(match.group(0), match.group(2).strip(), 1).strip()

    match = re.search(multicol_pattern, cell['content'])
    if match:
        cell['colspan'] = int(match.group(1))
        cell['content'] = cell['content'].replace(match.group(0), match.group(2).strip(), 1).strip()
    return cell    

def grid2html(grid):
    def to_td(grid, r, c):
        if grid[r][c] in ['<<', '^^', '..']:
            return ''
        td = {'text': grid[r][c], 'rowspan':1, 'colspan': 1}
        for i in range(r + 1, len(grid)):
            if grid[i][c] == '^^':
                td['rowspan'] += 1
            else:
                break   
        for j in range(c + 1, len(grid[r])):
            if grid[r][j] == '<<':
                td['colspan'] += 1
            else:
                break
        return f'<td rowspan={td["rowspan"]} colspan={td["colspan"]}> {td["text"]} </td>'.replace('rowspan=1', '').replace('colspan=1', '')
        
    html = []
    for r in range(len(grid)):
        row = []
        for c in range(len(grid[0])):
            row.append(to_td(grid, r, c))
        html.append(f'<tr> {"".join(row)} </tr>')
    return '<html><body><table>' + '\n'.join(html) + '</table></body></html>'

def qylatex_to_grid(latex):
    if not re.search(r'\\end{tabular[x]*\*?\}', latex):
        return
    pattern = r'\\begin\{tabular[x]*\*?\}.*?\\end\{tabular[x]*\*?\}'
    matches = re.findall(pattern, latex, re.DOTALL)
    if not matches:
        return
    content = remove_grid_lines(matches[0])
    rows = content.strip(' \n').split(r'\\')
    processed_rows = []
    for row in rows:
        if not row.strip():
            continue
        columns = re.split(r'(?<!\\)&', row)
        columns = [fix_multi({'content': c.strip(' \n'), 'rowspan': 1, 'colspan': 1}) for c in columns]
        processed_rows.append(columns)
    max_cols = max([sum([it['colspan'] for it in r]) for r in processed_rows]) if processed_rows else 0
    grid = [[None for _ in range(max_cols)] for _ in range(len(processed_rows))]
    r_idx_bias = 0
    for r_idx, row in enumerate(processed_rows):
        r_idx += r_idx_bias
        while r_idx >= len(grid):
            grid.append([None for _ in range(max_cols)])
        c_idx = 0
        current_row_bias = 10000
        for cell in row:
            while c_idx < len(grid[r_idx]) and grid[r_idx][c_idx] is not None:
                c_idx += 1
            if c_idx >= len(grid[r_idx]):
                break
            current_row_bias = min(current_row_bias, cell['rowspan'])
            grid[r_idx][c_idx] = cell['content']
            for r in range(cell['rowspan']):
                for c in range(cell['colspan']):
                    if r == 0 and c == 0:
                        continue
                    target_r = r_idx + r
                    target_c = c_idx + c
                    if target_r >= len(grid):
                        grid.append([None for _ in range(max_cols)])
                    if target_c < len(grid[target_r]):
                        grid[target_r][target_c] = '^^' if r > 0 else ('<<' if c > 0 else '..')
            c_idx += cell['colspan']
        r_idx_bias += current_row_bias - 1
    grid = [[c if c is not None else '' for c in r] for r in grid]
    return grid

def latex2html(latex_str):
    latex_str = re.sub(r'(?<!\\)%.*$', '', latex_str, flags=re.MULTILINE)
    latex_str = re.sub(r'(?<!\\)\\\\$$.*?$$', '', latex_str, flags=re.DOTALL)
    latex_str = latex_str.replace('\n', '').replace('\t', '')
    try:
        grid = qylatex_to_grid(latex_str)
    except IndexError as e:
        print(f"IndexError: {str(e)}")
        return 
    if not grid:
        return
    return grid2html(grid)

def teds_structure(gt, pred):
    gt_html = latex2html(gt)
    pred_html = latex2html(pred)
    if not pred_html:
        return 0, 0
    structure_teds = TEDS(structure_only=True)
    structure_score = structure_teds(gt_html, pred_html)
    all_teds = TEDS()
    teds_score = all_teds(gt_html, pred_html)
    return structure_score, teds_score

def process_item(args):
    idx, item = args
    try:
        if not isinstance(item, dict):
            print(f"Item {idx}: Invalid data type, skipping")
            return (None, None, None)
        # Check for different possible key combinations
        if 'questionId' in item and 'answer' in item and 'annotation' in item:
            qid = item['questionId']
            pred = item['answer']
            gt = item['annotation']
        elif 'id' in item and 'prediction' in item and 'reference' in item:
            qid = item['id']
            pred = item['prediction']
            gt = item['reference']
        else:
            print(f"Item {idx}: Missing required keys")
            return (None, None, None)
        structure_score, teds_score = teds_structure(gt, pred)
        return (qid, structure_score, teds_score)
    except Exception as e:
        print(f"Error processing item {idx}: {str(e)}")
        return (None, None, None)

def calculate_stats(scores):
    avg_all = sum(scores) / len(scores) if scores else 0
    non_zero_scores = [s for s in scores if s != 0]
    avg_non_zero = sum(non_zero_scores)/len(non_zero_scores) if non_zero_scores else 0
    non_zero_ratio = len(non_zero_scores)/len(scores) if scores else 0
    return avg_all, avg_non_zero, non_zero_ratio

def process_file(input_path):
    output_path = input_path.rsplit('.', 1)[0] + '_eval.txt'
    data = []
    # Determine file type and read data
    if input_path.endswith('.json'):
        try:
            with open(input_path, 'r', encoding='utf-8') as f:
                data = json.load(f)
                if not isinstance(data, list):
                    raise ValueError("JSON root is not an array")
        except Exception as e:
            print(f"Error reading JSON: {str(e)}")
            return
    elif input_path.endswith('.jsonl'):
        with open(input_path, 'r', encoding='utf-8') as f:
            for line in f:
                try:
                    data.append(json.loads(line.strip()))
                except json.JSONDecodeError as e:
                    print(f"JSONL parse error: {str(e)}")
    else:
        print("Unsupported file format. Use .json or .jsonl")
        return
    
    # Process data
    structure_results = {}
    teds_results = {}
    cpu_num = multiprocessing.cpu_count()//2
    pool = multiprocessing.Pool(processes=cpu_num)
    task_args = [(i+1, item) for i, item in enumerate(data)]
    
    processed = 0
    for qid, structure_score, teds_score in pool.imap(process_item, task_args):
        if qid is not None:
            structure_results[qid] = structure_score
            teds_results[qid] = teds_score
        processed += 1
        if processed % 10 == 0:
            print(f"Processed {processed}/{len(data)}")
    
    pool.close()
    pool.join()
    
    # Write results
    structure_stats = calculate_stats(list(structure_results.values()))
    teds_stats = calculate_stats(list(teds_results.values()))
    
    with open(output_path, 'w', encoding='utf-8') as f:
        f.write("ID:Structure_Score,TEDS_Score\n")
        for qid in sorted(structure_results):
            f.write(f"{qid}:{structure_results[qid]:.4f},{teds_results[qid]:.4f}\n")
        
        f.write("\n=== Structure Score ===\n")
        f.write(f"Total: {len(data)}\nValid: {len(structure_results)}\n")
        f.write(f"Non-zero: {structure_stats[2]:.2%}\n")
        f.write(f"Average (All): {structure_stats[0]:.4f}\nAverage (Non-zero): {structure_stats[1]:.4f}\n")
        
        f.write("\n=== TEDS Score ===\n")
        f.write(f"Total: {len(data)}\nValid: {len(teds_results)}\n")
        f.write(f"Non-zero: {teds_stats[2]:.2%}\n")
        f.write(f"Average (All): {teds_stats[0]:.4f}\nAverage (Non-zero): {teds_stats[1]:.4f}\n")

# Example usage
process_file("/home/lingjun/code/InternVL/internvl_chat/results_qwenvl3b_latte/output.jsonl")  # Replace with your file path
# Out:
# Processed 10/2725
# Processed 20/2725
# Processed 30/2725
# Processed 40/2725
# Processed 50/2725
# Processed 60/2725
# Processed 70/2725
# Processed 80/2725
# Processed 90/2725
# Processed 100/2725
# Processed 110/2725
# Processed 120/2725
# Processed 130/2725
# Processed 140/2725
# Processed 150/2725
# Processed 160/2725
# Processed 170/2725
# Processed 180/2725
# Processed 190/2725
# Processed 200/2725
# Processed 210/2725
# Processed 220/2725
# Processed 230/2725
# Processed 240/2725
# Processed 250/2725
# Processed 260/2725
# Processed 270/2725
# Processed 280/2725
# Processed 290/2725
# Processed 300/2725
# Processed 310/2725
# Processed 320/2725
# Processed 330/2725
# Processed 340/2725
# Processed 350/2725
# Processed 360/2725
# Processed 370/2725
# Processed 380/2725
# Processed 390/2725
# Processed 400/2725
# Processed 410/2725
# Processed 420/2725
# Processed 430/2725
# Processed 440/2725
# Processed 450/2725
# Processed 460/2725
# Processed 470/2725
# Processed 480/2725
# Processed 490/2725
# Processed 500/2725
# Processed 510/2725
# Processed 520/2725
# Processed 530/2725
# Processed 540/2725
# Processed 550/2725
# Processed 560/2725
# Processed 570/2725
# Processed 580/2725
# Processed 590/2725
# Processed 600/2725
# Processed 610/2725
# Processed 620/2725
# Processed 630/2725
# Processed 640/2725
# Processed 650/2725
# Processed 660/2725
# Processed 670/2725
# Processed 680/2725
# Processed 690/2725
# Processed 700/2725
# Processed 710/2725
# Processed 720/2725
# Processed 730/2725
# Processed 740/2725
# Processed 750/2725
# Processed 760/2725
# Processed 770/2725
# Processed 780/2725
# Processed 790/2725
# Processed 800/2725
# Processed 810/2725
# Processed 820/2725
# Processed 830/2725
# Processed 840/2725
# Processed 850/2725
# Processed 860/2725
# Processed 870/2725
# Processed 880/2725
# Processed 890/2725
# Processed 900/2725
# Processed 910/2725
# Processed 920/2725
# Processed 930/2725
# Processed 940/2725
# Processed 950/2725
# Processed 960/2725
# Processed 970/2725
# Processed 980/2725
# Processed 990/2725
# Processed 1000/2725
# Processed 1010/2725
# Processed 1020/2725
# Processed 1030/2725
# Processed 1040/2725
# Processed 1050/2725
# Processed 1060/2725
# Processed 1070/2725
# Processed 1080/2725
# Processed 1090/2725
# Processed 1100/2725
# Processed 1110/2725
# Processed 1120/2725
# Processed 1130/2725
# Processed 1140/2725
# Processed 1150/2725
# Processed 1160/2725
# Processed 1170/2725
# Processed 1180/2725
# Processed 1190/2725
# Processed 1200/2725
# Processed 1210/2725
# Processed 1220/2725
# Processed 1230/2725
# Processed 1240/2725
# Processed 1250/2725
# Processed 1260/2725
# Processed 1270/2725
# Processed 1280/2725
# Processed 1290/2725
# Processed 1300/2725
# Processed 1310/2725
# Processed 1320/2725
# Processed 1330/2725
# Processed 1340/2725
# Processed 1350/2725
# Processed 1360/2725
# Processed 1370/2725
# Processed 1380/2725
# Processed 1390/2725
# Processed 1400/2725
# Processed 1410/2725
# Processed 1420/2725
# Processed 1430/2725
# Processed 1440/2725
# Processed 1450/2725
# Processed 1460/2725
# Processed 1470/2725
# Processed 1480/2725
# Processed 1490/2725
# Processed 1500/2725
# Processed 1510/2725
# Processed 1520/2725
# Processed 1530/2725
# Processed 1540/2725
# Processed 1550/2725
# Processed 1560/2725
# Processed 1570/2725
# Processed 1580/2725
# Processed 1590/2725
# Processed 1600/2725
# Processed 1610/2725
# Processed 1620/2725
# Processed 1630/2725
# Processed 1640/2725
# Processed 1650/2725
# Processed 1660/2725
# Processed 1670/2725
# Processed 1680/2725
# Processed 1690/2725
# Processed 1700/2725
# Processed 1710/2725
# Processed 1720/2725
# Processed 1730/2725
# Processed 1740/2725
# Processed 1750/2725
# Processed 1760/2725
# Processed 1770/2725
# Processed 1780/2725
# Processed 1790/2725
# Processed 1800/2725
# Processed 1810/2725
# Processed 1820/2725
# Processed 1830/2725
# Processed 1840/2725
# Processed 1850/2725
# Processed 1860/2725
# Processed 1870/2725
# Processed 1880/2725
# Processed 1890/2725
# Processed 1900/2725
# Processed 1910/2725
# Processed 1920/2725
# Processed 1930/2725
# Processed 1940/2725
# Processed 1950/2725
# Processed 1960/2725
# Processed 1970/2725
# Processed 1980/2725
# Processed 1990/2725
# Processed 2000/2725
# Processed 2010/2725
# Processed 2020/2725
# Processed 2030/2725
# Processed 2040/2725
# Processed 2050/2725
# Processed 2060/2725
# Processed 2070/2725
# Processed 2080/2725
# Processed 2090/2725
# Processed 2100/2725
# Processed 2110/2725
# Processed 2120/2725
# Processed 2130/2725
# Processed 2140/2725
# Processed 2150/2725
# Processed 2160/2725
# Processed 2170/2725
# Processed 2180/2725
# Processed 2190/2725
# Processed 2200/2725
# Processed 2210/2725
# Processed 2220/2725
# Processed 2230/2725
# Processed 2240/2725
# Processed 2250/2725
# Processed 2260/2725
# Processed 2270/2725
# Processed 2280/2725
# Processed 2290/2725
# Processed 2300/2725
# Processed 2310/2725
# Processed 2320/2725
# Processed 2330/2725
# Processed 2340/2725
# Processed 2350/2725
# Processed 2360/2725
# Processed 2370/2725
# Processed 2380/2725
# Processed 2390/2725
# Processed 2400/2725
# Processed 2410/2725
# Processed 2420/2725
# Processed 2430/2725
# Processed 2440/2725
# Processed 2450/2725
# Processed 2460/2725
# Processed 2470/2725
# Processed 2480/2725
# Processed 2490/2725
# Processed 2500/2725
# Processed 2510/2725
# Processed 2520/2725
# Processed 2530/2725
# Processed 2540/2725
# Processed 2550/2725
# Processed 2560/2725
# Processed 2570/2725
# Processed 2580/2725
# Processed 2590/2725
# Processed 2600/2725
# Processed 2610/2725
# Processed 2620/2725
# Processed 2630/2725
# Processed 2640/2725
# Processed 2650/2725
# Processed 2660/2725
# Processed 2670/2725
# Processed 2680/2725
# Processed 2690/2725
# Processed 2700/2725
# Processed 2710/2725
# Processed 2720/2725

# %%
###########Teds_structure_evaluation###########
import re
from table_recognition_metric import TEDS
import multiprocessing
import json
def remove_grid_lines(latex_table):
    # 去除 \hline, \cline, \toprule, \midrule, \bottomrule
    cleaned_table = re.sub(r'\\cmidrule{\s*}|\\cdashline\{[0-9]+(-[0-9]+)?\}\s*|\\cmidrule\((?:lr|r|l)?\)\{[0-9]+\-[0-9]+\}\s*|\\arrayrulecolor{.*?}\s*|\\caption{.*?}\s*|\\centering\s*|\\hline\s*|\\cline{.*?}\s*|\\toprule\s*|\\midrule\s*|\\bottomrule\s*', '', latex_table)
    
    cleaned_table = re.sub(r'\\tabularnewline', r'\\\\', cleaned_table)
    # # 去除注释
    # cleaned_table = re.sub(r'(?<!\\)%.*$', '', cleaned_table, flags=re.MULTILINE)
    # cleaned_table = re.sub(r'(?<!\\)\[[^\[\]]*\]', '', cleaned_table)
    # 合并连续的空行
    cleaned_table = re.sub(r'\n\s*\n', '\n', cleaned_table)
    
    return cleaned_table.strip(' \n')  # 去除首尾空格

def fix_multi(cell):
    multirow_pattern = r'\\multirow{(\d+)}{.*?}{(.*?)}'
    multicol_pattern = r'\\multicolumn{(\d+)}{.*?}{(.*?)}'
    
    match = re.search(multirow_pattern, cell['content'])
    if match:
        cell['rowspan'] = int(match.group(1))
        cell['content'] = cell['content'].replace(match.group(0), match.group(2).strip(), 1).strip()

    match = re.search(multicol_pattern, cell['content'])
    if match:
        cell['colspan'] = int(match.group(1))
        cell['content'] = cell['content'].replace(match.group(0), match.group(2).strip(), 1).strip()

    return cell    

def grid2html(grid):
    def to_td(grid, r, c):
        if grid[r][c] == '<<' or grid[r][c] == '^^' or grid[r][c] == '..':
            return ''
        td = {'text': grid[r][c], 'rowspan':1, 'colspan': 1}
        #计算行跨度
        for i in range(r + 1, len(grid)):
            if grid[i][c] == '^^':
                td['rowspan'] += 1
            else:
                break
        #就算列跨度    
        for j in range(c + 1, len(grid[r])):
            if grid[r][j] == '<<':
                td['colspan'] += 1
            else:
                break
        return f'<td rowspan={td["rowspan"]} colspan={td["colspan"]}> {td["text"]} </td>'.replace('rowspan=1', '').replace('colspan=1', '')
        
    
    html = []
    for r in range(len(grid)):
        row = []
        for c in range(len(grid[0])):
            row.append(to_td(grid, r, c))
        html.append(f'<tr> {"".join(row)} </tr>')
    # for row in grid:
    #     html.append('<tr>' + ''.join([to_td(c) for c in row]) + '</tr>')
    
    return '<html><body><table>' + '\n'.join(html) + '</table></body></html>'


def qylatex_to_grid(latex):
    # 提取表格内容
    if not re.search(r'\\end{tabular[x]*\*?\}', latex):
        return  # 如果不匹配，返回
    pattern = r'\\begin\{tabular[x]*\*?\}.*?\\end\{tabular[x]*\*?\}'

    matches = re.findall(pattern, latex, re.DOTALL)
    if matches:
        table_content = matches[0]
    else:
        return
    # 提取表格内容

    content = remove_grid_lines(table_content)
    # 获取表格内部的内容
    
    # 将行和列分割
    rows = content.strip(' \n').split(r'\\')

    processed_rows = []

    for row in rows:
        # 去除空行
        if not row.strip():
            continue

        # 用 & 分割列
        columns = re.split(r'(?<!\\)&', row)
         # 去除多余的空格并确定每一列的跨度以构建行
        columns = [fix_multi({'content': c.strip(' \n'), 'rowspan': 1, 'colspan': 1}) for c in columns]
       
        processed_rows.append(columns)
    # # 如果最后一行为空, 删除
    # while len(processed_rows) > 0 and len(processed_rows[-1]) == 0:
    #     processed_rows.pop()
    rows = processed_rows
    max_cols = max([sum([it['colspan'] for it in r]) for r in rows])
    # 创建一个空白网格
    grid = [[None for _ in range(max_cols)] for _ in range(len(rows))]
    col_char_num = [[1] for _ in range(max_cols)]
    # 填充网格，处理 rowspan 和 colspan
    r_idx_bias = 0
    for r_idx, row in enumerate(rows):
        r_idx += r_idx_bias
        while r_idx >= len(grid):
            grid.append([None for _ in range(max_cols)])
        c_idx = 0
        current_row_bias = 10000
        for cell in row:
            # 找到第一个未填充的单元格
            if grid[r_idx][c_idx] is not None:
                if cell['content']:
                    while grid[r_idx][c_idx] == '..':
                        c_idx += 1
                else:
                    c_idx += 1
                    continue

            current_row_bias = min(current_row_bias, cell['rowspan'])
            # 填充内容
            grid[r_idx][c_idx] = cell['content']
            col_char_num[c_idx].append(len(cell['content']))
            
            # 处理 rowspan 和 colspan
            for r in range(cell['rowspan']):
                for c in range(cell['colspan']):
                    if r == 0 and c == 0:
                        continue
                    if r == 0:
                        grid[r_idx][c_idx + c] = '<<'
                    elif c == 0:
                    
                        while r_idx+r >= len(grid):
                            grid.append([None for _ in range(max_cols)])
                        grid[r_idx + r][c_idx] = '^^'
                    else:
                        grid[r_idx + r][c_idx + c] = '..'                  
            c_idx += cell['colspan']
        r_idx_bias += current_row_bias - 1
    grid = [[c if c is not None else '' for c in r] for r in grid]
    return grid


def latex2html(latex_str):
    # 去除注释
    latex_str = re.sub(r'(?<!\\)%.*$', '', latex_str, flags=re.MULTILINE)
    # 去除"\\\\[...]"
    latex_str = re.sub(r'(?<!\\)\\\\\[.*?\]', '', latex_str, flags=re.DOTALL)

    latex_str = latex_str.replace('\n', '').replace('\t', '')
    try:
        grid = qylatex_to_grid(latex_str)
    except IndexError as e:
        print(f"IndexError: {str(e)}")
        return 
    if not grid:
        return
    html = grid2html(grid)
    return html

def teds_structure(gt, pred):
    """计算TEDS"""
    gt_html = latex2html(gt)
    pred_html = latex2html(pred)
    if not pred_html:
        # print("Prediction LaTeX to HTML conversion failed.")
        return 0, 0
    structure_teds = TEDS(structure_only=True)
    structure_score = structure_teds(gt_html, pred_html)
    all_teds = TEDS()
    teds_score = all_teds(gt_html, pred_html)
    return structure_score, teds_score

def process_item(args):
    """包装处理函数用于多进程"""
    idx, item = args
    try:
        if not isinstance(item, dict):
            print(f"Item {idx}: Invalid data type ({type(item)}), skipping")
            return (None, None, None)
            
        required_keys = ['id', 'prediction', 'reference']
        for key in required_keys:
            if key not in item:
                print(f"Item {idx}: Missing key '{key}', skipping")
                return (None, None, None)

        qid = item['id']
        gt = item['reference']
        pred = item['prediction']
        structure_score, teds_score = teds_structure(gt, pred)  # 正确解构两个返回值
        return (qid, structure_score, teds_score)
        
    except Exception as e:
        print(f"Error processing item {idx}: {str(e)}")
        return (None, None, None)

def process_item_json(args):
    """包装处理函数用于多进程"""
    idx, item = args
    try:
        if not isinstance(item, dict):
            print(f"Item {idx}: Invalid data type ({type(item)}), skipping")
            return (None, None, None)
            
        required_keys = ['questionId', 'answer', 'annotation']
        if not all(key in item for key in required_keys):
            print(f"Item {idx}: Missing required keys")
            return None


        qid = item['questionId']
        gt = item['annotation']
        pred = item['answer']
        structure_score, teds_score = teds_structure(gt, pred)  # 正确解构两个返回值
        return (qid, structure_score, teds_score)
        
    except Exception as e:
        print(f"Error processing item {idx}: {str(e)}")
        return (None, None, None)
    
def process_json(input_path):
    output_path = input_path.rsplit('.', 1)[0] + '_eval.txt'
    structure_results = {}
    teds_results = {}
    # 读取整个JSON文件
    with open(input_path, 'r', encoding='utf-8') as f:
        try:
            data = json.load(f)
            if not isinstance(data, list):
                raise ValueError("Root element is not an array")
        except Exception as e:
            print(f"Failed to parse JSON: {str(e)}")
            return

    # 创建进程池
    cpu_num = multiprocessing.cpu_count()
    pool = multiprocessing.Pool(processes=cpu_num)
    
    # 准备参数 (添加索引)
    task_args = [(i+1, item) for i, item in enumerate(data)]
    
    # 使用imap获取结果
    processed = 0
    for qid, structure_score, teds_score in pool.imap(process_item_json, task_args):
        if qid is not None:
            structure_results[qid] = structure_score
            teds_results[qid] = teds_score
        processed += 1
        if processed % 10 == 0:
            print(f"Processed {processed}/{len(data)} items")
    
    pool.close()
    pool.join()

    # 统计计算和结果写入
    structure_stats = calculate_stats(list(structure_results.values()))
    teds_stats = calculate_stats(list(teds_results.values()))

    with open(output_path, 'w', encoding='utf-8') as f:
        # 写入明细结果
        f.write("ID:Structure_Score, TEDS_Score\n")
        for qid in sorted(structure_results.keys()):
            f.write(f"{qid}:{structure_results[qid]:.4f}, {teds_results[qid]:.4f}\n")
        
        # 写入统计信息
        f.write("\n=== Structure Score Statistics ===\n")
        f.write(f"Total samples: {len(data)}\n")
        f.write(f"Valid samples: {len(structure_results)}\n")
        f.write(f"Non-zero ratio: {structure_stats[2]:.4f}\n")
        f.write(f"Average Score (All): {structure_stats[0]:.4f}\n")
        f.write(f"Average Score (Non-zero): {structure_stats[1]:.4f}\n")
        
        f.write("\n=== TEDS Score Statistics ===\n")
        f.write(f"Total samples: {len(data)}\n")
        f.write(f"Valid samples: {len(teds_results)}\n")
        f.write(f"Non-zero ratio: {teds_stats[2]:.4f}\n")
        f.write(f"Average Score (All): {teds_stats[0]:.4f}\n")
        f.write(f"Average Score (Non-zero): {teds_stats[1]:.4f}\n")

def calculate_stats(scores):
    avg_all = sum(scores) / len(scores) if scores else 0
    non_zero_scores = [s for s in scores if s != 0]
    avg_non_zero = sum(non_zero_scores)/len(non_zero_scores) if non_zero_scores else 0
    non_zero_ratio = len(non_zero_scores) / len(scores) if scores else 0
    return avg_all, avg_non_zero, non_zero_ratio

def process_jsonl(input_path):
    """处理jsonl文件并自动生成输出路径"""
    # 自动生成输出路径
    output_path = input_path.rsplit('.', 1)[0] + '_eval.txt'
    
    structure_results = {}
    teds_results = {}
    
    # 读取JSONL文件
    data = []
    with open(input_path, 'r', encoding='utf-8') as f:
        for line in f:
            try:
                item = json.loads(line.strip())
                data.append(item)
            except json.JSONDecodeError as e:
                print(f"Failed to parse line: {str(e)}")
                continue

    print(f"Processing {len(data)} items from {input_path}")
    print(f"Results will be saved to {output_path}")

    # 创建进程池
    cpu_num = multiprocessing.cpu_count()
    pool = multiprocessing.Pool(processes=cpu_num)
    
    # 准备参数 (添加索引)
    task_args = [(i+1, item) for i, item in enumerate(data)]
    
    # 使用imap获取结果 
    processed = 0
    for qid, structure_score, teds_score in pool.imap(process_item, task_args):
        if qid is not None:
            structure_results[qid] = structure_score
            teds_results[qid] = teds_score
        processed += 1
        if processed % 10 == 0:
            print(f"Processed {processed}/{len(data)} items")
    
    pool.close()
    pool.join()

    # 统计计算和结果写入
    structure_stats = calculate_stats(list(structure_results.values()))
    teds_stats = calculate_stats(list(teds_results.values()))

    with open(output_path, 'w', encoding='utf-8') as f:
        # 写入明细结果
        f.write("ID:Structure_Score, TEDS_Score\n")
        for qid in sorted(structure_results.keys()):
            f.write(f"{qid}:{structure_results[qid]:.4f}, {teds_results[qid]:.4f}\n")
        
        # 写入统计信息
        f.write("\n=== Structure Score Statistics ===\n")
        f.write(f"Total samples: {len(data)}\n")
        f.write(f"Valid samples: {len(structure_results)}\n")
        f.write(f"Non-zero ratio: {structure_stats[2]:.4f}\n")
        f.write(f"Average Score (All): {structure_stats[0]:.4f}\n")
        f.write(f"Average Score (Non-zero): {structure_stats[1]:.4f}\n")
        
        f.write("\n=== TEDS Score Statistics ===\n")
        f.write(f"Total samples: {len(data)}\n")
        f.write(f"Valid samples: {len(teds_results)}\n")
        f.write(f"Non-zero ratio: {teds_stats[2]:.4f}\n")
        f.write(f"Average Score (All): {teds_stats[0]:.4f}\n")
        f.write(f"Average Score (Non-zero): {teds_stats[1]:.4f}\n")
        
process_jsonl("/home/lingjun/code/InternVL/internvl_chat/results_qwenvl3b_simple_grpo_1epoch/output.jsonl")  # 修改此处为你的JSONL文件路径
# Out:
# Processing 500 items from /home/lingjun/code/InternVL/internvl_chat/results_qwenvl3b_simple_grpo_1epoch/output.jsonl
# Results will be saved to /home/lingjun/code/InternVL/internvl_chat/results_qwenvl3b_simple_grpo_1epoch/output_eval.txt
# Processed 10/500 items
# Processed 20/500 items
# Processed 30/500 items
# Processed 40/500 items
# Processed 50/500 items
# Processed 60/500 items
# Processed 70/500 items
# Processed 80/500 items
# Processed 90/500 items
# Processed 100/500 items
# Processed 110/500 items
# Processed 120/500 items
# Processed 130/500 items
# Processed 140/500 items
# Processed 150/500 items
# Processed 160/500 items
# Processed 170/500 items
# Processed 180/500 items
# Processed 190/500 items
# Processed 200/500 items
# Processed 210/500 items
# Processed 220/500 items
# Processed 230/500 items
# Processed 240/500 items
# Processed 250/500 items
# Processed 260/500 items
# Processed 270/500 items
# Processed 280/500 items
# Processed 290/500 items
# Processed 300/500 items
# Processed 310/500 items
# Processed 320/500 items
# Processed 330/500 items
# Processed 340/500 items
# Processed 350/500 items
# Processed 360/500 items
# Processed 370/500 items
# Processed 380/500 items
# Processed 390/500 items
# Processed 400/500 items
# Processed 410/500 items
# Processed 420/500 items
# Processed 430/500 items
# Processed 440/500 items
# Processed 450/500 items
# Processed 460/500 items
# Processed 470/500 items
# Processed 480/500 items
# Processed 490/500 items
# Processed 500/500 items

# %%
import os
import subprocess
from pdf2image import convert_from_path
from PIL import Image
from multiprocessing import Pool
import uuid
import glob
import concurrent.futures
import numpy as np

# LaTeX preamble with UTF-8 support and table formatting
latex_preamble = r"""
\documentclass[standalone]{article}
\usepackage[utf8]{inputenc}
\usepackage[T1]{fontenc}
\usepackage{amsmath, amsthm, amssymb, graphicx, geometry, array}
\usepackage{booktabs, multirow,natbib,tabularx, multicol, bm}
\pagenumbering{gobble}
\begin{document}
\begin{table}[htp]
\centering
\resizebox*{0.5\columnwidth}{!}{ 
"""
latex_end = r"}\end{table}\end{document}"

def render_content_to_pdf(content, output_pdf_path, timeout=20):
    """Render LaTeX content to PDF with error handling and cleanup"""
    full_tex_content = latex_preamble + content + latex_end
    
    # Generate unique temporary filename
    temp_tex_filename = f"temp_{uuid.uuid4().hex}.tex"
    temp_tex_path = os.path.join(os.path.dirname(output_pdf_path), temp_tex_filename)
    
    try:
        with open(temp_tex_path, "w") as temp_file:
            temp_file.write(full_tex_content)

        result = subprocess.run(
            ["pdflatex", "-interaction=nonstopmode", "-output-directory", os.path.dirname(output_pdf_path), temp_tex_path],
            check=False,
            capture_output=True,
            text=True,
            encoding='latin-1',
            timeout=timeout
        )

        temp_pdf_path = temp_tex_path.replace(".tex", ".pdf")
        if os.path.exists(temp_pdf_path):
            os.rename(temp_pdf_path, output_pdf_path)
            print(f"Rendered PDF saved to {output_pdf_path}")
        else:
            print(f"PDF generation failed for {output_pdf_path}. Errors:\n{result.stdout}")
    except subprocess.TimeoutExpired:
        print(f"Timeout expired for {output_pdf_path}")
    except Exception as e:
        print(f"Error processing {output_pdf_path}: {str(e)}")
    finally:
        # Cleanup temporary files
        for ext in [".aux", ".log", ".out", ".tex"]:
            file_path = temp_tex_path.replace(".tex", ext)
            if os.path.exists(file_path):
                try:
                    os.remove(file_path)
                except:
                    pass

def convert_pdf_to_png(pdf_path, png_path, dpi=300):
    """Convert PDF to PNG with error handling"""
    try:
        images = convert_from_path(pdf_path, dpi=dpi)
        if images:
            images[0].save(png_path, "PNG")
            print(f"Converted {pdf_path} to {png_path}")
        else:
            print(f"Error: Empty PDF {pdf_path}")
    except Exception as e:
        print(f"Conversion failed for {pdf_path}: {str(e)}")

def find_matching_pairs(gt_dir, gen_dir):
    """Find matching file pairs between groundtruth and generated directories"""
    gt_files = glob.glob(os.path.join(gt_dir, "*.tex"))
    pairs = []
    
    for gt_path in gt_files:
        base_name = os.path.splitext(os.path.basename(gt_path))[0]
        gen_path = os.path.join(gen_dir, f"{base_name}.txt")
        
        if os.path.exists(gen_path):
            pairs.append((gt_path, gen_path))
        else:
            print(f"Warning: Missing generated file for {base_name}")
    
    print(f"Found {len(pairs)} valid file pairs")
    return pairs

def process_pair(pair):
    """Process a matched file pair with error handling"""
    gt_path, gen_path = pair
    base_name = os.path.splitext(os.path.basename(gt_path))[0]
    
    try:
        # Process groundtruth
        with open(gt_path, "r") as f:
            gt_content = f.read()
        
        gt_pdf = os.path.join(pdf_output_dir, f"{base_name}_gt.pdf")
        gt_png = os.path.join(png_output_dir, f"{base_name}_gt.png")
        render_content_to_pdf(gt_content, gt_pdf)
        if os.path.exists(gt_pdf):
            convert_pdf_to_png(gt_pdf, gt_png)

        # Process generated
        with open(gen_path, "r") as f:
            gen_content = f.read()
        
        gen_pdf = os.path.join(pdf_output_dir, f"{base_name}_gen.pdf")
        gen_png = os.path.join(png_output_dir, f"{base_name}_gen.png")
        render_content_to_pdf(gen_content, gen_pdf)
        if os.path.exists(gen_pdf):
            convert_pdf_to_png(gen_pdf, gen_png)

        return True
    except Exception as e:
        print(f"Failed to process {base_name}: {str(e)}")
        return False

def dwt2_simple(img_array):
    """Performs a simple 2D discrete wavelet transform with even-size check"""
    rows, cols = img_array.shape
    rows = rows - rows % 2
    cols = cols - cols % 2
    img_array = img_array[:rows, :cols]
    
    blocks = img_array.reshape(rows//2, 2, cols//2, 2).transpose(0, 2, 1, 3)
    a = blocks[..., 0, 0]
    b = blocks[..., 0, 1]
    c = blocks[..., 1, 0]
    d = blocks[..., 1, 1]
    
    cA = (a + b + c + d) * 0.25
    cH = (a - c) * 0.5
    cV = (a - b) * 0.5
    cD = (a - d) * 0.5
    return cA, cH, cV, cD

def calculate_ssim(img1, img2):
    img1_flat = img1.ravel()
    img2_flat = img2.ravel()
    n = img1_flat.size
    
    sum1 = img1_flat.sum()
    sum2 = img2_flat.sum()
    sum12 = (img1_flat * img2_flat).sum()
    sum1_sq = (img1_flat** 2).sum()
    sum2_sq = (img2_flat** 2).sum()
    
    mean1 = sum1 / n
    mean2 = sum2 / n
    var1 = (sum1_sq - sum1**2 / n) / n
    var2 = (sum2_sq - sum2**2 / n) / n
    
    covar = (sum12 - sum1 * sum2 / n) / (n - 1) if n > 1 else 0.0
    
    C1, C2 = 6.5025, 58.5225
    numerator = (2 * mean1 * mean2 + C1) * (2 * covar + C2)
    denominator = (mean1**2 + mean2**2 + C1) * (var1 + var2 + C2)
    return numerator / denominator

def calculate_cwssim(image1_path, image2_path):
    """Compares two images using Complex Wavelet Structural Similarity Index (CW-SSIM)"""
    try:
        image1 = Image.open(image1_path).convert('L')
        image2 = Image.open(image2_path).convert('L')
        image1 = image1.resize(image2.size)
        
        img1_array = np.array(image1)
        img2_array = np.array(image2)
        
        cA1, cH1, cV1, cD1 = dwt2_simple(img1_array)
        cA2, cH2, cV2, cD2 = dwt2_simple(img2_array)
        
        ssim_cA = calculate_ssim(cA1, cA2)
        ssim_cH = calculate_ssim(cH1, cH2)
        ssim_cV = calculate_ssim(cV1, cV2)
        ssim_cD = calculate_ssim(cD1, cD2)
        cwssim_score = (ssim_cA + ssim_cH + ssim_cV + ssim_cD) / 4
        
        return cwssim_score
    except Exception as e:
        print(f"Error comparing images {image1_path} and {image2_path}: {e}")
        return 0.0

def process_prefix(prefix, output_png_dir, gt_images, gen_images):
    gt_image_path = os.path.join(output_png_dir, gt_images[prefix])
    if prefix in gen_images:
        gen_image_path = os.path.join(output_png_dir, gen_images[prefix])
        cwssim_score = calculate_cwssim(gen_image_path, gt_image_path)
        return f"{prefix}: {cwssim_score:.4f}\n"
    else:
        return f"{prefix}: 0.0000\n"

def compare_images_and_save_results(output_dir):
    output_png_dir = os.path.join(output_dir, "png_results")
    result_file_path = os.path.join(output_dir, "cwssim_results.txt")
    
    image_files = os.listdir(output_png_dir)
    gt_images = {f.split('_')[0]: f for f in image_files if f.endswith('_gt.png')}
    gen_images = {f.split('_')[0]: f for f in image_files if f.endswith('_gen.png')}
    
    with open(result_file_path, "w") as result_file:
        with concurrent.futures.ProcessPoolExecutor() as executor:
            futures = [
                executor.submit(process_prefix, prefix, output_png_dir, gt_images, gen_images)
                for prefix in gt_images
            ]
            for future in concurrent.futures.as_completed(futures):
                result_line = future.result()
                result_file.write(result_line)
                print(result_line.strip())
    
    print(f"Results saved to {result_file_path}")
    return result_file_path

def sort_txt_file(input_file):
    try:
        with open(input_file, 'r') as f:
            lines = [line.strip() for line in f if line.strip()]
        
        sorted_lines = sorted(lines, key=lambda x: int(x.split(':')[0]))
        output_file = input_file.replace('.txt', '_sorted.txt')
        
        with open(output_file, 'w') as f:
            f.write('\n'.join(sorted_lines))
        
        print(f"Sorted results saved to {output_file}")
        return output_file
    except Exception as e:
        print(f"Sorting failed: {str(e)}")
        return input_file

def calculate_average_and_ratio(file_path):
    try:
        total_score = 0.0
        valid_count = 0
        non_zero_count = 0
        
        with open(file_path, 'r') as file:
            for line in file:
                if not line.strip():
                    continue
                
                parts = line.rsplit(':', 1)
                if len(parts) != 2:
                    continue
                
                try:
                    score = float(parts[1].strip())
                except ValueError:
                    continue
                
                valid_count += 1
                if not np.isclose(score, 0.0):
                    non_zero_count += 1
                    total_score += score

        avg = total_score / non_zero_count if non_zero_count > 0 else 0.0
        ratio = non_zero_count / valid_count if valid_count > 0 else 0.0
        
        return avg, ratio
    except Exception as e:
        print(f"处理文件时发生错误: {e}")
        return None, None

def calculate_average_score(file_path):
    """Calculates the average score from a file with id:score format."""
    try:
        with open(file_path, 'r') as file:
            total_score = 0
            count = 0
            for line in file:
                # Split by ':' and strip whitespace, convert the score to float
                parts = line.split(":")
                if len(parts) == 2:
                    score = float(parts[1].strip())
                    total_score += score
                    count += 1

            # Calculate and return the average score
            if count > 0:
                average_score = total_score / count
                return average_score
            else:
                return 0.0
    except Exception as e:
        print(f"Error reading the file: {e}")
        return None
    
    # 用户只需设置以下两个路径
gt_dir = "/home/lingjun/code/InternVL/internvl_chat/val_data/complex/label"  # 修改为你的GT路径
gen_dir = "/home/lingjun/code/InternVL/internvl_chat/val_data/easy/pred_1B-v5-2570"   # 修改为你的生成文件路径

# 自动生成输出路径
output_dir = os.path.join(os.path.dirname(gen_dir), "output_" + os.path.basename(gen_dir))
os.makedirs(output_dir, exist_ok=True)

# 创建子目录
global pdf_output_dir, png_output_dir
pdf_output_dir = os.path.join(output_dir, "pdf_results")
png_output_dir = os.path.join(output_dir, "png_results")
os.makedirs(pdf_output_dir, exist_ok=True)
os.makedirs(png_output_dir, exist_ok=True)

# 处理文件对
file_pairs = find_matching_pairs(gt_dir, gen_dir)
num_workers = max(1, os.cpu_count() // 2)

with Pool(processes=num_workers) as pool:
    results = pool.imap_unordered(process_pair, file_pairs)
    success_count = 0
    for i, result in enumerate(results, 1):
        if result:
            success_count += 1
        print(f"Processed {i}/{len(file_pairs)} pairs ({success_count} successful)")

# 图像比较和分数计算
result_file = compare_images_and_save_results(output_dir)
sorted_file = sort_txt_file(result_file)

# 计算统计指标
result_file_path = os.path.join(output_dir, "cwssim_results.txt")
average_score, non_zero_ratio = calculate_average_and_ratio(result_file_path)

overall_avg = calculate_average_score(result_file)
if overall_avg is not None:
    print(f"\n整体平均分: {overall_avg:.4f}")

# 非零分数统计
avg_non_zero, non_zero_ratio = calculate_average_and_ratio(result_file)
if avg_non_zero is not None and non_zero_ratio is not None:
    print(f"非零分数平均分: {avg_non_zero:.4f}")
    print(f"有效生成占比: {non_zero_ratio:.2%}")

# %%
import os
import subprocess
import json
from pdf2image import convert_from_path
from PIL import Image
from multiprocessing import Pool
import uuid
from skimage.metrics import structural_similarity as cw_ssim
# Updated LaTeX preamble with UTF-8 support
latex_preamble = r"""
\documentclass[standalone]{article}
\usepackage[utf8]{inputenc}
\usepackage[T1]{fontenc}
\usepackage{amsmath, amsthm, amssymb, graphicx, geometry, array}
\usepackage{booktabs, multirow,natbib,tabularx, multicol, bm}
\pagenumbering{gobble}
\begin{document}
\begin{table}[htp]
\centering
\resizebox*{0.5\columnwidth}{!}{ 
"""
latex_end = r"}\end{table}\end{document}"

def render_tex_to_pdf(tex_path, output_pdf_path, timeout=20):
    """Render a LaTeX file to PDF with unique temporary files for parallel processing"""
    with open(tex_path, "r") as file:
        tex_content = file.read()
    
    full_tex_content = latex_preamble + tex_content + latex_end
    
    # Generate unique temporary filename using UUID
    temp_tex_filename = f"temp_{uuid.uuid4().hex}.tex"
    temp_tex_path = os.path.join(os.path.dirname(output_pdf_path), temp_tex_filename)
    
    with open(temp_tex_path, "w") as temp_file:
        temp_file.write(full_tex_content)
    
    try:
        result = subprocess.run(
            ["pdflatex", "-interaction=nonstopmode", "-output-directory", os.path.dirname(output_pdf_path), temp_tex_path],
            check=False,
            capture_output=True,
            text=True,
            encoding='latin-1',
            timeout=timeout
        )
        
        # Get the actual output PDF path from LaTeX compilation
        temp_pdf_path = temp_tex_path.replace(".tex", ".pdf")
        
        if os.path.exists(temp_pdf_path):
            os.rename(temp_pdf_path, output_pdf_path)
            print(f"Successfully rendered {tex_path} to PDF at {output_pdf_path}.")
        else:
            print(f"Error: PDF not generated for {tex_path}. LaTeX output:\n{result.stdout}")
    except subprocess.TimeoutExpired:
        print(f"Timeout expired while rendering {tex_path}. Skipping this file.")
    except Exception as e:
        print(f"Unexpected error rendering {tex_path}: {str(e)}")
    finally:
        # Cleanup temporary files
        for ext in [".aux", ".log", ".out", ".tex"]:
            file_path = temp_tex_path.replace(".tex", ext)
            if os.path.exists(file_path):
                try:
                    os.remove(file_path)
                except Exception as e:
                    print(f"Warning: Could not delete temporary file {file_path}: {str(e)}")

def convert_pdf_to_png(pdf_path, png_path, dpi=300):
    """Convert PDF to PNG with error handling"""
    try:
        images = convert_from_path(pdf_path, dpi=dpi)
        if images:
            images[0].save(png_path, "PNG")
            print(f"Converted {pdf_path} to {png_path}")
        else:
            print(f"Error: No pages found in {pdf_path}")
    except Exception as e:
        print(f"Error converting {pdf_path} to PNG: {str(e)}")

def process_entry(entry):
    """Process a single JSON entry with full error handling"""
    try:
        question_id = entry["questionId"]
        print(f"Processing {question_id}...")
        
        # Create output filenames
        base_files = {
            "answer": (entry["answer"], f"{question_id}_answer"),
            "annotation": (entry["annotation"], f"{question_id}_annotation")
        }
        
        for content_type, (content, base_name) in base_files.items():
            # Generate LaTeX file
            tex_path = os.path.join(table_dir, f"{base_name}.tex")
            with open(tex_path, "w") as f:
                f.write(content)
            
            # Generate PDF
            pdf_path = os.path.join(output_pdf_dir, f"{base_name}.pdf")
            render_tex_to_pdf(tex_path, pdf_path)
            
            # Convert to PNG
            if os.path.exists(pdf_path):
                png_path = os.path.join(output_png_dir, f"{base_name}.png")
                convert_pdf_to_png(pdf_path, png_path)
            else:
                print(f"Skipping PNG conversion for {base_name} - PDF not found")
        
        print(f"Completed processing {question_id}")
        return True
    except Exception as e:
        print(f"Error processing {entry.get('questionId', 'unknown')}: {str(e)}")
        return False

def process_json(json_file):
    """Main processing function with parallel execution"""
    with open(json_file, "r") as file:
        data = json.load(file)
    
    # Create necessary directories
    os.makedirs(table_dir, exist_ok=True)
    os.makedirs(output_pdf_dir, exist_ok=True)
    os.makedirs(output_png_dir, exist_ok=True)
    
    # Use half of available CPUs for resource balancing
    num_workers = max(1, os.cpu_count() // 2)
    
    with Pool(processes=num_workers) as pool:
        results = pool.imap_unordered(process_entry, data)
        
        # Monitor progress
        success_count = 0
        for i, result in enumerate(results, 1):
            if result:
                success_count += 1
            print(f"Processed {i}/{len(data)} entries ({success_count} successes)")
    
    print(f"\nProcessing complete. Success rate: {success_count}/{len(data)}")

if __name__ == "__main__":
    # Configuration paths
    json_file = "/home/lingjun/code/InternVL/internvl_chat/results_v1_5epoch/Table2Latex_250401040709.json"
    base_dir = os.path.dirname(json_file)
    extracted_tables_dir = os.path.join(base_dir, "extracted_tables")
    
    # Initialize directory paths
    table_dir = os.path.join(extracted_tables_dir, "latex_tables")
    output_pdf_dir = os.path.join(extracted_tables_dir, "pdf_tables_full")
    output_png_dir = os.path.join(extracted_tables_dir, "png_tables_full")
    
    # Start processing
    process_json(json_file)
    print("Rendering and conversion complete!")

# %%
#####################文件形式
import os
import subprocess
from pdf2image import convert_from_path
from PIL import Image
from multiprocessing import Pool
import uuid
import glob

# LaTeX preamble with UTF-8 support and table formatting
latex_preamble = r"""
\documentclass[standalone]{article}
\usepackage[utf8]{inputenc}
\usepackage[T1]{fontenc}
\usepackage{amsmath, amsthm, amssymb, graphicx, geometry, array}
\usepackage{booktabs, multirow,natbib,tabularx, multicol, bm}
\pagenumbering{gobble}
\begin{document}
\begin{table}[htp]
\centering
\resizebox*{0.5\columnwidth}{!}{ 
"""
latex_end = r"}\end{table}\end{document}"

def render_content_to_pdf(content, output_pdf_path, timeout=20):
    """Render LaTeX content to PDF with error handling and cleanup"""
    full_tex_content = latex_preamble + content + latex_end
    
    # Generate unique temporary filename
    temp_tex_filename = f"temp_{uuid.uuid4().hex}.tex"
    temp_tex_path = os.path.join(os.path.dirname(output_pdf_path), temp_tex_filename)
    
    try:
        with open(temp_tex_path, "w") as temp_file:
            temp_file.write(full_tex_content)

        result = subprocess.run(
            ["pdflatex", "-interaction=nonstopmode", "-output-directory", os.path.dirname(output_pdf_path), temp_tex_path],
            check=False,
            capture_output=True,
            text=True,
            encoding='latin-1',
            timeout=timeout
        )

        temp_pdf_path = temp_tex_path.replace(".tex", ".pdf")
        if os.path.exists(temp_pdf_path):
            os.rename(temp_pdf_path, output_pdf_path)
            print(f"Rendered PDF saved to {output_pdf_path}")
        else:
            print(f"PDF generation failed for {output_pdf_path}. Errors:\n{result.stdout}")
    except subprocess.TimeoutExpired:
        print(f"Timeout expired for {output_pdf_path}")
    except Exception as e:
        print(f"Error processing {output_pdf_path}: {str(e)}")
    finally:
        # Cleanup temporary files
        for ext in [".aux", ".log", ".out", ".tex"]:
            file_path = temp_tex_path.replace(".tex", ext)
            if os.path.exists(file_path):
                try:
                    os.remove(file_path)
                except:
                    pass

def convert_pdf_to_png(pdf_path, png_path, dpi=160):
    """Convert PDF to PNG with error handling"""
    try:
        images = convert_from_path(pdf_path, dpi=dpi)
        if images:
            images[0].save(png_path, "PNG")
            print(f"Converted {pdf_path} to {png_path}")
        else:
            print(f"Error: Empty PDF {pdf_path}")
    except Exception as e:
        print(f"Conversion failed for {pdf_path}: {str(e)}")

def find_matching_pairs(gt_dir, gen_dir):
    """Find matching file pairs between groundtruth and generated directories"""
    gt_files = glob.glob(os.path.join(gt_dir, "*.tex"))
    pairs = []
    
    for gt_path in gt_files:
        base_name = os.path.splitext(os.path.basename(gt_path))[0]
        gen_path = os.path.join(gen_dir, f"{base_name}.txt")
        
        if os.path.exists(gen_path):
            pairs.append((gt_path, gen_path))
        else:
            print(f"Warning: Missing generated file for {base_name}")
    
    print(f"Found {len(pairs)} valid file pairs")
    return pairs

def process_pair(pair):
    """Process a matched file pair with error handling"""
    gt_path, gen_path = pair
    base_name = os.path.splitext(os.path.basename(gt_path))[0]
    
    try:
        # Process groundtruth
        with open(gt_path, "r") as f:
            gt_content = f.read()
        
        gt_pdf = os.path.join(pdf_output_dir, f"{base_name}_gt.pdf")
        gt_png = os.path.join(png_output_dir, f"{base_name}_gt.png")
        render_content_to_pdf(gt_content, gt_pdf)
        if os.path.exists(gt_pdf):
            convert_pdf_to_png(gt_pdf, gt_png)

        # Process generated
        with open(gen_path, "r") as f:
            gen_content = f.read()
        
        gen_pdf = os.path.join(pdf_output_dir, f"{base_name}_gen.pdf")
        gen_png = os.path.join(png_output_dir, f"{base_name}_gen.png")
        render_content_to_pdf(gen_content, gen_pdf)
        if os.path.exists(gen_pdf):
            convert_pdf_to_png(gen_pdf, gen_png)

        return True
    except Exception as e:
        print(f"Failed to process {base_name}: {str(e)}")
        return False

if __name__ == "__main__":
    # Configuration paths
    gt_dir = "/home/lingjun/code/InternVL/internvl_chat/val_data/complex/label"          # Groundtruth .tex files
    gen_dir = "/home/lingjun/code/InternVL/internvl_chat/val_data/complex/pred_1B-v5-38555"         # Generated .txt files
    output_dir = "/home/lingjun/code/InternVL/internvl_chat/val_data/complex/output_pred_1B-v5-38555" # Main output directory
    
    # Create output directories
    pdf_output_dir = os.path.join(output_dir, "pdf_results")
    png_output_dir = os.path.join(output_dir, "png_results")
    os.makedirs(pdf_output_dir, exist_ok=True)
    os.makedirs(png_output_dir, exist_ok=True)

    # Find and process matching pairs
    file_pairs = find_matching_pairs(gt_dir, gen_dir)
    
    # Use half of available CPUs
    num_workers = max(1, os.cpu_count() // 2)
    
    # Process pairs in parallel
    with Pool(processes=num_workers) as pool:
        results = pool.imap_unordered(process_pair, file_pairs)
        
        success_count = 0
        for i, result in enumerate(results, 1):
            if result:
                success_count += 1
            print(f"Processed {i}/{len(file_pairs)} pairs ({success_count} successful)")

    print(f"\nProcessing completed. Success rate: {success_count}/{len(file_pairs)}")
    print(f"PDF outputs: {pdf_output_dir}")
    print(f"PNG outputs: {png_output_dir}")

# %%
from numpy.lib.stride_tricks import sliding_window_view
import os
import concurrent
import numpy as np
from PIL import Image
import cv2

def dwt2_simple(img_array):
    """Performs a simple 2D discrete wavelet transform with even-size check"""
    # Ensure rows and cols are even by cropping
    rows, cols = img_array.shape
    rows = rows - rows % 2  # 裁剪到最近的偶数
    cols = cols - cols % 2
    img_array = img_array[:rows, :cols]  # 保留能被2整除的部分
    
    # 重塑为块结构 (rows//2, cols//2, 2, 2)
    blocks = img_array.reshape(rows//2, 2, cols//2, 2).transpose(0, 2, 1, 3)
    a = blocks[..., 0, 0]
    b = blocks[..., 0, 1]
    c = blocks[..., 1, 0]
    d = blocks[..., 1, 1]
    
    # 计算系数
    cA = (a + b + c + d) * 0.25
    cH = (a - c) * 0.5
    cV = (a - b) * 0.5
    cD = (a - d) * 0.5
    return cA, cH, cV, cD

# Function to calculate Structural Similarity Index (SSIM)
def calculate_ssim(img1, img2):
    img1_flat = img1.ravel()
    img2_flat = img2.ravel()
    n = img1_flat.size
    
    # 一次性计算所有总和
    sum1 = img1_flat.sum()
    sum2 = img2_flat.sum()
    sum12 = (img1_flat * img2_flat).sum()
    sum1_sq = (img1_flat** 2).sum()
    sum2_sq = (img2_flat** 2).sum()
    
    # 均值和方差
    mean1 = sum1 / n
    mean2 = sum2 / n
    var1 = (sum1_sq - sum1**2 / n) / n  # ddof=0
    var2 = (sum2_sq - sum2**2 / n) / n
    
    # 协方差（样本协方差，ddof=1）
    covar = (sum12 - sum1 * sum2 / n) / (n - 1) if n > 1 else 0.0
    
    # SSIM公式
    C1, C2 = 6.5025, 58.5225
    numerator = (2 * mean1 * mean2 + C1) * (2 * covar + C2)
    denominator = (mean1**2 + mean2**2 + C1) * (var1 + var2 + C2)
    return numerator / denominator

# Function to calculate Complex Wavelet Structural Similarity Index (CW-SSIM)
def calculate_cwssim(image1_path, image2_path):
    """Compares two images using Complex Wavelet Structural Similarity Index (CW-SSIM)"""
    try:
        # Open both images
        image1 = Image.open(image1_path).convert('L')  # Convert to grayscale
        image2 = Image.open(image2_path).convert('L')  # Convert to grayscale
        
        # Resize the images to the same size if necessary
        image1 = image1.resize(image2.size)
        
        # Convert images to numpy arrays
        img1_array = np.array(image1)
        img2_array = np.array(image2)
        
        # Perform simple 2D DWT (discrete wavelet transform)
        cA1, cH1, cV1, cD1 = dwt2_simple(img1_array)
        cA2, cH2, cV2, cD2 = dwt2_simple(img2_array)
        
        # Compute SSIM for the approximation and detail coefficients
        ssim_cA = calculate_ssim(cA1, cA2)
        ssim_cH = calculate_ssim(cH1, cH2)
        ssim_cV = calculate_ssim(cV1, cV2)
        ssim_cD = calculate_ssim(cD1, cD2)
        cwssim_score = (ssim_cA + ssim_cH + ssim_cV + ssim_cD) / 4
        
        return cwssim_score
    
    except Exception as e:
        print(f"Error comparing images {image1_path} and {image2_path}: {e}")
        return 0.0

def process_prefix(prefix, output_png_dir, gt_images, gen_images):
    gt_image_path = os.path.join(output_png_dir, gt_images[prefix])
    if prefix in gen_images:
        gen_image_path = os.path.join(output_png_dir, gen_images[prefix])
        cwssim_score = calculate_cwssim(gen_image_path, gt_image_path)
        return f"{prefix}: {cwssim_score:.4f}\n"
    else:
        return f"{prefix}: 0.0000\n"

def compare_images_and_save_results():
    # 更新路径到新的图片存储位置
    output_png_dir = "/home/lingjun/code/InternVL/internvl_chat/results_qwenvl3b-complex-checkpoint-9450/extracted_tables/pdf_tables_full"
    result_file_path = "/home/lingjun/code/InternVL/internvl_chat/results_qwenvl3b-complex-checkpoint-9450/cwssim_results.txt"
    
    # 获取图片文件列表
    image_files = os.listdir(output_png_dir)
    
    # 按新格式过滤文件：前缀_gt.png 和 前缀_gen.png
    gt_images = {f.split('_')[0]: f for f in image_files if f.endswith('_reference.png')}
    gen_images = {f.split('_')[0]: f for f in image_files if f.endswith('_prediction.png')}
    
    with open(result_file_path, "w") as result_file:
        with concurrent.futures.ProcessPoolExecutor() as executor:
            futures = [
                executor.submit(process_prefix, prefix, output_png_dir, gt_images, gen_images)
                for prefix in gt_images
            ]
            for future in concurrent.futures.as_completed(futures):
                result_line = future.result()
                result_file.write(result_line)
                print(result_line.strip())
    
    print(f"Results saved to {result_file_path}")
    return result_file_path



def sort_txt_file(input_file):
    """排序结果文件"""
    try:
        with open(input_file, 'r') as f:
            lines = [line.strip() for line in f if line.strip()]
        
        # 按前缀数字排序
        sorted_lines = sorted(lines, key=lambda x: int(x.split(':')[0]))
        
        # 生成排序后的文件名
        output_file = input_file.replace('.txt', '_sorted.txt')
        
        with open(output_file, 'w') as f:
            f.write('\n'.join(sorted_lines))
        
        print(f"Sorted results saved to {output_file}")
        return output_file
    except Exception as e:
        print(f"Sorting failed: {str(e)}")
        return input_file

# 执行流程
if __name__ == "__main__":
    result_file = compare_images_and_save_results()
    sorted_file = sort_txt_file(result_file)
    print(f"Final sorted results: {sorted_file}")
    print("Image comparison complete!")
# Out:
# Results saved to /home/lingjun/code/InternVL/internvl_chat/results_qwenvl3b-complex-checkpoint-9450/cwssim_results.txt
# Sorted results saved to /home/lingjun/code/InternVL/internvl_chat/results_qwenvl3b-complex-checkpoint-9450/cwssim_results_sorted.txt
# Final sorted results: /home/lingjun/code/InternVL/internvl_chat/results_qwenvl3b-complex-checkpoint-9450/cwssim_results_sorted.txt
# Image comparison complete!

# %%
import os
import concurrent
import numpy as np
from PIL import Image


def dwt2_simple(img_array):
    """Performs a simple 2D discrete wavelet transform with even-size check"""
    # Ensure rows and cols are even by cropping
    rows, cols = img_array.shape
    rows = rows - rows % 2  # 裁剪到最近的偶数
    cols = cols - cols % 2
    img_array = img_array[:rows, :cols]  # 保留能被2整除的部分
    
    # 重塑为块结构 (rows//2, cols//2, 2, 2)
    blocks = img_array.reshape(rows//2, 2, cols//2, 2).transpose(0, 2, 1, 3)
    a = blocks[..., 0, 0]
    b = blocks[..., 0, 1]
    c = blocks[..., 1, 0]
    d = blocks[..., 1, 1]
    
    # 计算系数
    cA = (a + b + c + d) * 0.25
    cH = (a - c) * 0.5
    cV = (a - b) * 0.5
    cD = (a - d) * 0.5
    return cA, cH, cV, cD

# Function to calculate Structural Similarity Index (SSIM)
def calculate_ssim(img1, img2):
    img1_flat = img1.ravel()
    img2_flat = img2.ravel()
    n = img1_flat.size
    
    # 一次性计算所有总和
    sum1 = img1_flat.sum()
    sum2 = img2_flat.sum()
    sum12 = (img1_flat * img2_flat).sum()
    sum1_sq = (img1_flat** 2).sum()
    sum2_sq = (img2_flat** 2).sum()
    
    # 均值和方差
    mean1 = sum1 / n
    mean2 = sum2 / n
    var1 = (sum1_sq - sum1**2 / n) / n  # ddof=0
    var2 = (sum2_sq - sum2**2 / n) / n
    
    # 协方差（样本协方差，ddof=1）
    covar = (sum12 - sum1 * sum2 / n) / (n - 1) if n > 1 else 0.0
    
    # SSIM公式
    C1, C2 = 6.5025, 58.5225
    numerator = (2 * mean1 * mean2 + C1) * (2 * covar + C2)
    denominator = (mean1**2 + mean2**2 + C1) * (var1 + var2 + C2)
    return numerator / denominator

# Function to calculate Complex Wavelet Structural Similarity Index (CW-SSIM)
def calculate_cwssim(image1_path, image2_path):
    """Compares two images using Complex Wavelet Structural Similarity Index (CW-SSIM)"""
    try:
        # Open both images
        image1 = Image.open(image1_path).convert('L')  # Convert to grayscale
        image2 = Image.open(image2_path).convert('L')  # Convert to grayscale
        
        # Resize the images to the same size if necessary
        image1 = image1.resize(image2.size)
        
        # Convert images to numpy arrays
        img1_array = np.array(image1)
        img2_array = np.array(image2)
        
        # Perform simple 2D DWT (discrete wavelet transform)
        cA1, cH1, cV1, cD1 = dwt2_simple(img1_array)
        cA2, cH2, cV2, cD2 = dwt2_simple(img2_array)
        
        # Compute SSIM for the approximation and detail coefficients
        ssim_cA = calculate_ssim(cA1, cA2)
        ssim_cH = calculate_ssim(cH1, cH2)
        ssim_cV = calculate_ssim(cV1, cV2)
        ssim_cD = calculate_ssim(cD1, cD2)
        cwssim_score = (ssim_cA + ssim_cH + ssim_cV + ssim_cD) / 4
        
        return cwssim_score
    
    except Exception as e:
        print(f"Error comparing images {image1_path} and {image2_path}: {e}")
        return 0.0

def process_prefix(prefix, output_png_dir, annotation_images, answer_images):
    annotation_image_path = os.path.join(output_png_dir, annotation_images[prefix])
    if prefix in answer_images:
        answer_image_path = os.path.join(output_png_dir, answer_images[prefix])
        cwssim_score = calculate_cwssim(answer_image_path, annotation_image_path)
        return f"{prefix}: {cwssim_score:.4f}\n"
    else:
        return f"{prefix}: 0.0000\n"

def compare_images_and_save_results():
    output_png_dir = "/home/lingjun/code/InternVL/internvl_chat/results_qwenvl_1epoch_complex/extracted_tables/png_tables_full"
    result_file_path = "/home/lingjun/code/InternVL/internvl_chat/results_qwenvl_1epoch_complex/extracted_tables/png_tables_full/cwssim_results.txt"
    image_files = os.listdir(output_png_dir)
    answer_images = {f.split('_')[0]: f for f in image_files if '_answer.png' in f}
    annotation_images = {f.split('_')[0]: f for f in image_files if '_annotation.png' in f}
    
    with open(result_file_path, "w") as result_file:
        with concurrent.futures.ProcessPoolExecutor() as executor:
            futures = [executor.submit(process_prefix, prefix, output_png_dir, annotation_images, answer_images) 
                       for prefix in annotation_images]
            for future in concurrent.futures.as_completed(futures):
                result_line = future.result()
                result_file.write(result_line)
                print(result_line.strip())
    print(f"Results saved to {result_file_path}")



def sort_txt_file(input_file, output_file=None):
    """
    读取并排序文本文件中的数字对
    :param input_file: 输入文件名（如"data.txt"）
    :param output_file: 输出文件名，默认添加"_sorted"后缀
    """
    try:
        # 读取原始文件
        with open(input_file, 'r') as f:
            lines = [line.strip() for line in f if line.strip()]  # 移除空行和空白字符

        # 定义排序规则：按冒号左侧的数字升序排列
        def sort_key(line):
            left_num = line.split(':', 1)[0].strip()  # 分割并取左边数字
            return int(left_num)

        # 执行排序
        sorted_lines = sorted(lines, key=sort_key)

        # 生成输出文件名
        output = output_file or input_file.replace('.txt', '_sorted.txt')

        # 写入新文件
        with open(output, 'w') as f:
            f.write('\n'.join(sorted_lines))

        print(f"文件已排序并保存为：{output}")
        return True

    except FileNotFoundError:
        print(f"错误：文件 {input_file} 不存在")
    except Exception as e:
        print(f"处理时发生错误：{str(e)}")
    return False

compare_images_and_save_results()
sort_txt_file("/home/lingjun/code/InternVL/internvl_chat/results_qwenvl_1epoch_complex/extracted_tables/png_tables_full/cwssim_results_sorted.txt")
print("Image comparison complete!")

# %%
def calculate_average_score(file_path):
    """Calculates the average score from a file with id:score format."""
    try:
        with open(file_path, 'r') as file:
            total_score = 0
            count = 0
            for line in file:
                # Split by ':' and strip whitespace, convert the score to float
                parts = line.split(":")
                if len(parts) == 2:
                    score = float(parts[1].strip())
                    total_score += score
                    count += 1

            # Calculate and return the average score
            if count > 0:
                average_score = total_score / count
                return average_score
            else:
                return 0.0
    except Exception as e:
        print(f"Error reading the file: {e}")
        return None

# Example usage
file_path = "/home/lingjun/code/InternVL/internvl_chat/results_v1_5epoch/ssim_comparison_results_complex_sorted.txt"
average_score = calculate_average_score(file_path)

if average_score is not None:
    print(f"The average score is: {average_score:.4f}")
# Out:
# The average score is: 0.5582

# %%
def calculate_average_and_ratio(file_path):
    """计算非零分数的平均值和非零分数占比
    Args:
        file_path: 包含评分结果的文本文件路径，每行格式为 "前缀: 分数"
    
    Returns:
        tuple: (平均分, 非零分数占比) 或 (None, None) 当出现错误时
    """
    try:
        total_score = 0.0
        valid_count = 0
        non_zero_count = 0
        
        with open(file_path, 'r') as file:
            for line in file:
                # 跳过空行
                if not line.strip():
                    continue
                
                # 安全分割数据
                parts = line.rsplit(':', 1)  # 从右边最多分割1次
                if len(parts) != 2:
                    continue  # 跳过格式错误行
                
                try:
                    score = float(parts[1].strip())
                except ValueError:
                    continue  # 跳过无法转换为浮点数的行
                
                valid_count += 1
                if not np.isclose(score, 0.0):  # 使用近似零判断
                    non_zero_count += 1
                    total_score += score

        # 计算统计值
        avg = total_score / non_zero_count if non_zero_count > 0 else 0.0
        ratio = non_zero_count / valid_count if valid_count > 0 else 0.0
        
        return avg, ratio
    
    except Exception as e:
        print(f"处理文件时发生错误: {e}")
        return None, None

file_path = "/home/lingjun/code/InternVL/internvl_chat/results_v1_5epoch/ssim_comparison_results_complex_sorted.txt"
average_score, non_zero_ratio = calculate_average_and_ratio(file_path)

if average_score is not None and non_zero_ratio is not None:
    print(f"非零分数平均值: {average_score:.4f}")
    print(f"非零分数占比: {non_zero_ratio:.2%}")
else:
    print("无法计算结果，请检查文件路径和格式")
# Out:
# 非零分数平均值: 0.6051
# 非零分数占比: 92.24%

# %%
###########Teds_structure_evaluation###########
import re
from table_recognition_metric import TEDS
import multiprocessing
import json
def remove_grid_lines(latex_table):
    # 去除 \hline, \cline, \toprule, \midrule, \bottomrule
    cleaned_table = re.sub(r'\\cmidrule{\s*}|\\cdashline\{[0-9]+(-[0-9]+)?\}\s*|\\cmidrule\((?:lr|r|l)?\)\{[0-9]+\-[0-9]+\}\s*|\\arrayrulecolor{.*?}\s*|\\caption{.*?}\s*|\\centering\s*|\\hline\s*|\\cline{.*?}\s*|\\toprule\s*|\\midrule\s*|\\bottomrule\s*', '', latex_table)
    
    cleaned_table = re.sub(r'\\tabularnewline', r'\\\\', cleaned_table)
    # # 去除注释
    # cleaned_table = re.sub(r'(?<!\\)%.*$', '', cleaned_table, flags=re.MULTILINE)
    # cleaned_table = re.sub(r'(?<!\\)\[[^\[\]]*\]', '', cleaned_table)
    # 合并连续的空行
    cleaned_table = re.sub(r'\n\s*\n', '\n', cleaned_table)
    
    return cleaned_table.strip(' \n')  # 去除首尾空格

def fix_multi(cell):
    multirow_pattern = r'\\multirow{(\d+)}{.*?}{(.*?)}'
    multicol_pattern = r'\\multicolumn{(\d+)}{.*?}{(.*?)}'
    
    match = re.search(multirow_pattern, cell['content'])
    if match:
        cell['rowspan'] = int(match.group(1))
        cell['content'] = cell['content'].replace(match.group(0), match.group(2).strip(), 1).strip()

    match = re.search(multicol_pattern, cell['content'])
    if match:
        cell['colspan'] = int(match.group(1))
        cell['content'] = cell['content'].replace(match.group(0), match.group(2).strip(), 1).strip()

    return cell    

def grid2html(grid):
    def to_td(grid, r, c):
        if grid[r][c] == '<<' or grid[r][c] == '^^' or grid[r][c] == '..':
            return ''
        td = {'text': grid[r][c], 'rowspan':1, 'colspan': 1}

        for i in range(r + 1, len(grid)):
            if grid[i][c] == '^^':
                td['rowspan'] += 1
            else:
                break
        
        for j in range(c + 1, len(grid[r])):
            if grid[r][j] == '<<':
                td['colspan'] += 1
            else:
                break
        return f'<td rowspan={td["rowspan"]} colspan={td["colspan"]}> {td["text"]} </td>'.replace('rowspan=1', '').replace('colspan=1', '')
        
    
    html = []
    for r in range(len(grid)):
        row = []
        for c in range(len(grid[0])):
            row.append(to_td(grid, r, c))
        html.append(f'<tr> {"".join(row)} </tr>')
    # for row in grid:
    #     html.append('<tr>' + ''.join([to_td(c) for c in row]) + '</tr>')
    
    return '<html><body><table>' + '\n'.join(html) + '</table></body></html>'


def qylatex_to_grid(latex):
    # 提取表格内容
    if not latex.endswith('\\end{tabular}'):
        return 
    pattern = r'\\begin\{tabular\}\s*\{.*?\}(.*?)\\end\{tabular\}'
    matches = re.findall(pattern, latex, re.DOTALL)
    if matches:
        table_content = matches[0]
    else:
        return
    # 提取表格内容

    content = remove_grid_lines(table_content)
    # 获取表格内部的内容
    
    # 将行和列分割
    rows = content.strip(' \n').split(r'\\')

    processed_rows = []

    for row in rows:
        # 去除空行
        if not row.strip():
            continue
        # 处理 multirow 和 multicolumn
        # row = re.sub(r'\\multirow{(\d+)}{.*?}{(.*?)}', lambda m: f"{m.group(2)}" + ("<< " * (int(m.group(1)) - 1)), row)
        # row = re.sub(r'\\multicolumn{(\d+)}{.*?}{(.*?)}', lambda m: f"{m.group(2)}" + ("| " * (int(m.group(1)) - 1)), row)

        # 用 & 分割列
        columns = re.split(r'(?<!\\)&', row)
        columns = [fix_multi({'content': c.strip(' \n'), 'rowspan': 1, 'colspan': 1}) for c in columns]
        # 去除多余的空格并构建行
        processed_rows.append(columns)
    # # 如果最后一行为空, 删除
    # while len(processed_rows) > 0 and len(processed_rows[-1]) == 0:
    #     processed_rows.pop()
    rows = processed_rows
    max_cols = max([sum([it['colspan'] for it in r]) for r in rows])
    # 创建一个空白网格
    grid = [[None for _ in range(max_cols)] for _ in range(len(rows))]
    col_char_num = [[1] for _ in range(max_cols)]
    # 填充网格，处理 rowspan 和 colspan
    r_idx_bias = 0
    for r_idx, row in enumerate(rows):
        r_idx += r_idx_bias
        if r_idx >= len(grid):
            grid.append([None for _ in range(max_cols)])
        c_idx = 0
        current_row_bias = 10000
        for cell in row:
            # 找到第一个未填充的单元格
            if grid[r_idx][c_idx] is not None:
                if cell['content']:
                    while grid[r_idx][c_idx] == '..':
                        c_idx += 1
                else:
                    c_idx += 1
                    continue

            current_row_bias = min(current_row_bias, cell['rowspan'])
            # 填充内容
            grid[r_idx][c_idx] = cell['content']
            col_char_num[c_idx].append(len(cell['content']))
            
            # 处理 rowspan 和 colspan
            for r in range(cell['rowspan']):
                for c in range(cell['colspan']):
                    if r == 0 and c == 0:
                        continue
                    if r == 0:
                        grid[r_idx][c_idx + c] = '<<'
                    elif c == 0:
                        grid[r_idx + r][c_idx] = '^^'
                    else:
                        grid[r_idx + r][c_idx + c] = '..'
            c_idx += cell['colspan']
        r_idx_bias += current_row_bias - 1
    grid = [[c if c is not None else '' for c in r] for r in grid]
    
    return grid


def latex2html(latex_str):
    # 去除注释
    latex_str = re.sub(r'(?<!\\)%.*$', '', latex_str, flags=re.MULTILINE)
    # 去除"\\\\[...]"
    latex_str = re.sub(r'(?<!\\)\\\\\[.*?\]', '', latex_str, flags=re.DOTALL)

    latex_str = latex_str.replace('\n', '').replace('\t', '')
    try:
        grid = qylatex_to_grid(latex_str)
    except IndexError:
        return 
    if not grid:
        return
    html = grid2html(grid)
    return html

def teds_structure(gt, pred):
    """计算结构相似度"""
    gt_html = latex2html(gt)
    pred_html = latex2html(pred)
    if not pred_html:
        # print("Prediction LaTeX to HTML conversion failed.")
        return 0
    structure_teds = TEDS(structure_only=True)
    structure_score = structure_teds(gt_html, pred_html)

    return structure_score

def process_item(args):
    """包装处理函数用于多进程"""
    idx, item = args
    try:
        # 有效性检查
        if not isinstance(item, dict):
            print(f"Item {idx}: Invalid data type ({type(item)}), skipping")
            return (None, None)
            
        required_keys = ['id', 'prediction', 'reference']
        for key in required_keys:
            if key not in item:
                print(f"Item {idx}: Missing key '{key}', skipping")
                return (None, None)

        # 处理数据
        qid = item['id']
        gt = item['reference']
        pred = item['prediction']
        score = teds_structure(gt, pred)
        return (qid, score)
        
    except Exception as e:
        print(f"Error processing item {idx}: {str(e)}")
        return (None, None)

def process_json(input_path, output_path):
    results = {}
    
    # 读取整个JSON文件
    with open(input_path, 'r', encoding='utf-8') as f:
        try:
            data = json.load(f)
            if not isinstance(data, list):
                raise ValueError("Root element is not an array")
        except Exception as e:
            print(f"Failed to parse JSON: {str(e)}")
            return

    # 创建进程池
    cpu_num = multiprocessing.cpu_count()
    pool = multiprocessing.Pool(processes=cpu_num)
    
    # 准备参数 (添加索引)
    task_args = [(i+1, item) for i, item in enumerate(data)]
    
    # 使用imap获取结果
    processed = 0
    for qid, score in pool.imap(process_item, task_args):
        if qid is not None and score is not None:
            results[qid] = score
        processed += 1
        if processed % 10 == 0:  # 每处理10个显示进度
            print(f"Processed {processed}/{len(data)} items")
    
    pool.close()
    pool.join()

    # 新增统计计算和结果写入部分
    scores = list(results.values())
    avg_all = sum(scores) / len(scores) if scores else 0
    non_zero_scores = [s for s in scores if s != 0]
    avg_non_zero = sum(non_zero_scores)/len(non_zero_scores) if non_zero_scores else 0

    with open(output_path, 'w', encoding='utf-8') as f:
        # 写入明细结果
        for qid in sorted(results.keys()):
            f.write(f"{qid}:{results[qid]:.4f}\n")
        
        # 写入统计信息
        f.write("\n=== Statistical Results ===\n")
        f.write(f"Total samples: {len(data)}\n")
        f.write(f"Valid samples: {len(scores)}\n")
        f.write(f"Average TEDS (All): {avg_all:.4f}\n")
        f.write(f"Average TEDS (Non-zero): {avg_non_zero:.4f}\n")

def process_jsonl(input_path, output_path):
    results = {}
    
    # 读取JSONL文件
    data = []
    with open(input_path, 'r', encoding='utf-8') as f:
        for line in f:
            try:
                item = json.loads(line.strip())
                data.append(item)
            except json.JSONDecodeError as e:
                print(f"Failed to parse line: {str(e)}")
                continue

    # 创建进程池
    cpu_num = multiprocessing.cpu_count()
    pool = multiprocessing.Pool(processes=cpu_num)
    
    # 准备参数 (添加索引)
    task_args = [(i+1, item) for i, item in enumerate(data)]
    
    # 使用imap获取结果 
    processed = 0
    for qid, score in pool.imap(process_item, task_args):
        if qid is not None and score is not None:
            results[qid] = score
        processed += 1
        if processed % 10 == 0:  # 每处理10个显示进度
            print(f"Processed {processed}/{len(data)} items")
    
    pool.close()
    pool.join()

    # 统计计算和结果写入
    scores = list(results.values())
    avg_all = sum(scores) / len(scores) if scores else 0
    non_zero_scores = [s for s in scores if s != 0]
    avg_non_zero = sum(non_zero_scores)/len(non_zero_scores) if non_zero_scores else 0
    non_zero_ratio = len(non_zero_scores) / len(scores) if scores else 0  # 计算非0比例

    with open(output_path, 'w', encoding='utf-8') as f:
        # 写入明细结果
        for qid in sorted(results.keys()):
            f.write(f"{qid}:{results[qid]:.4f}\n")
        
        # 写入统计信息
        f.write("\n=== Statistical Results ===\n")
        f.write(f"Total samples: {len(data)}\n")
        f.write(f"Valid samples: {len(scores)}\n")
        f.write(f"Non-zero ratio: {non_zero_ratio:.4f}\n")  # 添加非0比例输出
        f.write(f"Average TEDS (All): {avg_all:.4f}\n")
        f.write(f"Average TEDS (Non-zero): {avg_non_zero:.4f}\n")
process_jsonl("/home/lingjun/code/InternVL/internvl_chat/results_qwenvl_1epoch_complex/output.jsonl", "/home/lingjun/code/InternVL/internvl_chat/results_qwenvl_1epoch_complex/output_output.txt")

# %%
import json

def filter_by_length(input_path, output_path, max_length=3500):
    """筛选gpt回复长度小于指定值的数据
    
    :param input_path: 输入文件路径
    :param output_path: 输出文件路径
    :param max_length: 最大允许长度（默认3500）
    """
    with open(input_path, 'r') as infile, \
         open(output_path, 'w', encoding='utf-8') as outfile:

        for i, line in enumerate(infile, 1):
            try:
                # 解析JSON对象
                data = json.loads(line)
                valid = True

                # 遍历对话检查长度
                for conv in data.get('conversations', []):
                    if conv.get('from') == 'gpt':
                        if len(conv.get('value', '')) >= max_length:
                            valid = False
                            break  # 发现超长立即终止检查

                # 符合条件则写入新文件
                if valid:
                    outfile.write(line)

            except Exception as e:
                print(f"Error processing line {i}: {str(e)}")
                continue

if __name__ == '__main__':
    input_file = "/home/Datasets/Table2Latex/Table2Latex/train/table2latex_grpo_hard.jsonl"   # 输入文件路径
    output_file = "/home/Datasets/Table2Latex/Table2Latex/train/table2latex_grpo_hard_select.jsonl" # 输出文件路径
    
    filter_by_length(input_file, output_file)
    print("数据筛选完成，结果已保存至", output_file)

# %%
import json

def meets_criteria(value):
    # 统计LaTeX多行/多列命令数量
    multirow = value.count('\\multirow')
    multicolumn = value.count('\\multicolumn')
    # 统计&符号数量
    ampersands = value.count('&')
    # 判断条件：多行命令总数≥2 且 &≥100
    return (multirow + multicolumn) >= 2 and ampersands >= 160

def filter_jsonl(input_file, output_file):
    with open(input_file, 'r', encoding='utf-8') as infile, \
         open(output_file, 'w', encoding='utf-8') as outfile:
        
        for line in infile:
            try:
                item = json.loads(line.strip())
                # 检查所有gpt对话内容
                for conv in item.get('conversations', []):
                    if conv.get('from') == 'gpt':
                        if meets_criteria(conv.get('value', '')):
                            # 满足条件则写入新文件
                            outfile.write(json.dumps(item, ensure_ascii=False) + '\n')
                            break  # 找到即停止检查当前item
            except json.JSONDecodeError:
                print(f"Warning: 解析失败的行: {line}")

# 使用示例
filter_jsonl('/home/Datasets/Table2Latex/Table2Latex/train/table2latex.jsonl', '/home/Datasets/Table2Latex/Table2Latex/train/table2latex_grpo_hard.jsonl')

# %%
import json

def load_image_set(jsonl2_path):
    """加载第二个JSONL文件中的所有图片路径到集合"""
    image_set = set()
    with open(jsonl2_path, 'r', encoding='utf-8') as f:
        for line in f:
            data = json.loads(line.strip())
            image_set.add(data['image'])
    return image_set

def clean_jsonl(jsonl1_path, jsonl2_path, output_path):
    """清理第一个JSONL文件中重复的图片项"""
    # 读取第二个文件的图片路径
    image_set = load_image_set(jsonl2_path)
    
    # 处理第一个文件并写入结果
    with open(jsonl1_path, 'r', encoding='utf-8') as f_in, \
         open(output_path, 'w', encoding='utf-8') as f_out:
        for line in f_in:
            data = json.loads(line.strip())
            if data['image'] not in image_set:
                f_out.write(json.dumps(data, ensure_ascii=False) + '\n')

# 示例用法
clean_jsonl('/home/Datasets/Table2Latex/Table2Latex/train/table2latex_grpo_hard_select.jsonl', '/home/Datasets/Table2Latex/Table2Latex/separated/complex/table2latex.jsonl', '/home/Datasets/Table2Latex/Table2Latex/train/table2latex_grpo_hard_final.jsonl')

# %%
import json
import os
import shutil

def copy_images_from_jsonl(jsonl_path, output_dir):
    """
    从JSONL文件中提取图片路径并复制到目标文件夹
    
    参数:
        jsonl_path (str): JSONL文件路径
        output_dir (str): 图片输出目录
    """
    # 创建输出目录（如果不存在）
    os.makedirs(output_dir, exist_ok=True)
    
    # 统计变量
    copied_count = 0
    error_count = 0
    
    with open(jsonl_path, 'r') as f:
        for line_num, line in enumerate(f, 1):
            try:
                # 解析JSON数据
                data = json.loads(line.strip())
                
                # 获取原始图片路径
                src_path = data['image']
                
                # 生成目标路径
                filename = os.path.basename(src_path)
                dest_path = os.path.join(output_dir, filename)
                
                # 复制文件
                shutil.copy2(src_path, dest_path)
                copied_count += 1
                print(f"行 {line_num}: 成功复制 {filename}")
                
            except KeyError:
                print(f"行 {line_num}: 错误 - 缺少 'image' 字段")
                error_count += 1
            except FileNotFoundError:
                print(f"行 {line_num}: 错误 - 文件不存在 {src_path}")
                error_count += 1
            except json.JSONDecodeError:
                print(f"行 {line_num}: 错误 - JSON解析失败")
                error_count += 1
            except Exception as e:
                print(f"行 {line_num}: 发生意外错误 - {str(e)}")
                error_count += 1
    
    print("\n操作完成:")
    print(f"成功复制文件数: {copied_count}")
    print(f"失败数量: {error_count}")

# 使用示例
if __name__ == "__main__":
    # 配置路径（根据实际情况修改）
    jsonl_file = "/home/Datasets/Table2Latex/Table2Latex/train/table2latex_grpo_hard_select.jsonl"   # 输入的JSONL文件路径
    output_folder = "/home/Datasets/Table2Latex/Table2Latex/train/output_images"  # 输出目录
    
    copy_images_from_jsonl(jsonl_file, output_folder)

# %%
from PIL import Image
import cv2
import os
import numpy as np
from numpy.lib.stride_tricks import sliding_window_view  # 添加缺失的导入
import cv2
import numpy as np
from skimage.metrics import structural_similarity as ssim
import matplotlib.pyplot as plt



def dwt2_simple(img_array):
    """Performs a simple 2D discrete wavelet transform using averaging and differencing"""
    rows, cols = img_array.shape
    # 确保图像尺寸为偶数，避免索引错误
    rows = rows // 2 * 2
    cols = cols // 2 * 2
    cA = np.zeros((rows//2, cols//2))
    cH = np.zeros((rows//2, cols//2))
    cV = np.zeros((rows//2, cols//2))
    cD = np.zeros((rows//2, cols//2))

    for i in range(0, rows, 2):
        for j in range(0, cols, 2):
            avg = (img_array[i,j] + img_array[i+1,j] + img_array[i,j+1] + img_array[i+1,j+1]) / 4
            diff_h = (img_array[i,j] + img_array[i,j+1] - img_array[i+1,j] - img_array[i+1,j+1]) / 4
            diff_v = (img_array[i,j] + img_array[i+1,j] - img_array[i,j+1] - img_array[i+1,j+1]) / 4
            diff_d = (img_array[i,j] - img_array[i,j+1] - img_array[i+1,j] + img_array[i+1,j+1]) / 4

            cA[i//2, j//2] = avg
            cH[i//2, j//2] = diff_h
            cV[i//2, j//2] = diff_v
            cD[i//2, j//2] = diff_d

    return cA, cH, cV, cD

def calculate_ssim(img1, img2):
    """Calculate SSIM between two images"""
    mean1, mean2 = np.mean(img1), np.mean(img2)
    var1, var2 = np.var(img1), np.var(img2)
    covar = np.cov(img1.flatten(), img2.flatten())[0, 1]

    C1 = (0.01 * 255)**2
    C2 = (0.03 * 255) ** 2

    numerator = (2 * mean1 * mean2 + C1) * (2 * covar + C2)
    denominator = (mean1**2 + mean2**2 + C1) * (var1 + var2 + C2)
    return numerator / denominator if denominator != 0 else 0.0

def calculate_cwssim(image1_path, image2_path):
    """Compares two images using Complex Wavelet Structural Similarity Index (CW-SSIM)"""
    # 统一调整为256x256并转为灰度
    image1 = Image.open(image1_path).convert('L').resize((256, 256))
    image2 = Image.open(image2_path).convert('L').resize((256, 256))
    
    img1_array = np.array(image1, dtype=np.float64)
    img2_array = np.array(image2, dtype=np.float64)
    
    # 执行小波变换
    cA1, cH1, cV1, cD1 = dwt2_simple(img1_array)
    cA2, cH2, cV2, cD2 = dwt2_simple(img2_array)
    
    # 计算各子带的SSIM
    ssim_scores = [
        calculate_ssim(cA1, cA2),
        calculate_ssim(cH1, cH2),
        calculate_ssim(cV1, cV2),
        calculate_ssim(cD1, cD2)
    ]
    
    # 取平均值作为CW-SSIM结果
    cwssim_score = np.mean(ssim_scores)
    return max(0.0, min(cwssim_score, 1.0))
    
def calculate_similarity(image1_path, image2_path):
    # 读取图像
    image1 = cv2.imread(image1_path, cv2.IMREAD_GRAYSCALE)
    image2 = cv2.imread(image2_path, cv2.IMREAD_GRAYSCALE)

    # 检查图像是否加载成功
    if image1 is None or image2 is None:
        raise ValueError("无法加载图像，请检查路径是否正确。")

    # 确保图像大小相同
    if image1.shape != image2.shape:
        # 调整图像大小到较小的那个
        min_height = min(image1.shape[0], image2.shape[0])
        min_width = min(image1.shape[1], image2.shape[1])
        image1 = cv2.resize(image1, (min_width, min_height))
        image2 = cv2.resize(image2, (min_width, min_height))

    # 计算均方误差 (MSE)
    mse = np.mean((image1 - image2) ** 2)

    # 计算峰值信噪比 (PSNR)
    max_pixel = 255.0
    psnr = 20 * np.log10(max_pixel / np.sqrt(mse))

    # 计算结构相似性指数 (SSIM)
    ssim_index, ssim_image = ssim(image1, image2, full=True)
    ssim_image = (ssim_image * 255).astype("uint8")

    # 边缘检测
    edges1 = cv2.Canny(image1, 100, 200)
    edges2 = cv2.Canny(image2, 100, 200)
    edge_mse = np.mean((edges1 - edges2) ** 2)
    edge_psnr = 20 * np.log10(max_pixel / np.sqrt(edge_mse))

    # 综合评估
    similarity_score = (ssim_index * 0.5) + (psnr / 100 * 0.3) + (edge_psnr / 100 * 0.2)

    # 显示结果
    plt.figure(figsize=(12, 6))
    plt.subplot(2, 3, 1), plt.imshow(image1, cmap='gray')
    plt.title('Image 1'), plt.axis('off')
    plt.subplot(2, 3, 2), plt.imshow(image2, cmap='gray')
    plt.title('Image 2'), plt.axis('off')
    plt.subplot(2, 3, 3), plt.imshow(ssim_image, cmap='gray')
    plt.title('SSIM Map'), plt.axis('off')
    plt.subplot(2, 3, 4), plt.imshow(edges1, cmap='gray')
    plt.title('Edges 1'), plt.axis('off')
    plt.subplot(2, 3, 5), plt.imshow(edges2, cmap='gray')
    plt.title('Edges 2'), plt.axis('off')
    plt.subplot(2, 3, 6), plt.imshow(cv2.absdiff(edges1, edges2), cmap='gray')
    plt.title('Edge Difference'), plt.axis('off')
    plt.tight_layout()
    plt.show()

    # 打印结果
    print(f"均方误差 (MSE): {mse:.2f}")
    print(f"峰值信噪比 (PSNR): {psnr:.2f} dB")
    print(f"结构相似性指数 (SSIM): {ssim_index:.4f}")
    print(f"边缘均方误差 (Edge MSE): {edge_mse:.2f}")
    print(f"边缘峰值信噪比 (Edge PSNR): {edge_psnr:.2f} dB")
    print(f"综合相似性分数: {similarity_score:.4f}")

    return similarity_score
def run_tests():
    
    try:


        # 测试1: 相同图像
        calculate_similarity("/home/lingjun/code/InternVL/internvl_chat/test_images/6_annotation.png", "/home/lingjun/code/InternVL/internvl_chat/test_images/6_annotation.png")
        score = calculate_cwssim("/home/lingjun/code/InternVL/internvl_chat/test_images/6_annotation.png", "/home/lingjun/code/InternVL/internvl_chat/test_images/6_annotation.png")
        print(f"测试1（相同图像）: 得分为{score:.4f}")
        try:
            assert abs(score - 1.0) < 0.01
            print("测试1（相同图像）: 通过")
        except AssertionError:
            print(f"测试1（相同图像）: 失败，得分为{score:.4f}")

        # 测试2: 不同图像
        try:
            calculate_similarity("/home/lingjun/code/InternVL/internvl_chat/test_images/6_annotation.png", "/home/lingjun/code/InternVL/internvl_chat/test_images/Table conv 1.png")
            score = calculate_cwssim("/home/lingjun/code/InternVL/internvl_chat/test_images/6_annotation.png", "/home/lingjun/code/InternVL/internvl_chat/test_images/Table conv 1.png")
            print(f"测试2（不同图像）: 得分为{score:.4f}")
        except AssertionError:
            print(f"测试2（不同图像）: 失败，得分为{score:.4f}")

    finally:

        print("清理完成")


run_tests()
